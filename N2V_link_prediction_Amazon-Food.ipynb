# %%
import random

from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
import pickle
import sklearn.metrics as metrics

# %% [markdown]
# ### functions

# %%
def edge_features(node_emb_1, node_emb_2, operator):
    node_emb_1 = np.asfarray(node_emb_1,float)
    node_emb_2 = np.asfarray(node_emb_2, float)
    # combine two nodes' embeddings with specificed operator
    if operator == 'Average':
        edge = [((x + y) / 2.0) for x,y in zip(node_emb_1, node_emb_2)]
    elif operator == 'Hadamard':
        edge = [(x * y) for x,y in zip(node_emb_1, node_emb_2)]
    elif operator == 'Weighted-L1':
        edge = [abs(x - y) for x,y in zip(node_emb_1, node_emb_2)]
    elif operator == 'Weighted-L2':
        edge = [abs(x - y)**2 for x,y in zip(node_emb_1, node_emb_2)]
    elif operator == 'Concat':
        edge = np.concatenate((node_emb_1, node_emb_2), axis=None) 
    else:
        print("Generate edge features: Operator not supported")
        print("Use default operator: Weighted-L1")
        edge = [abs(x - y) for x,y in zip(node_emb_1, node_emb_2)]
        
    return edge
def generate_edge_features(edge_list, node_embeddings, operator):
    edge_features_mtx = []
    
    # generate features for each edge in the list
    for node_index_1, node_index_2 in edge_list:
        node_emb_1 = node_embeddings[node_index_1-1]
        node_emb_2 = node_embeddings[node_index_2-1]
        
        edge_features_mtx.append(edge_features(node_emb_1, node_emb_2, operator))
        
    return edge_features_mtx

def generate_train_set(graph_train, num_edge_sample, node_embeddings, edge_operator,):
    edge_list = list(graph_train.edges)
    num_nodes = graph_train.number_of_nodes()
    
    train_edges = []
    train_edges_labels = [1] * num_edge_sample + [0] * num_edge_sample
    
    random.seed(0)
    
    # sample edges with label 1 (true edges)
    for edge_num in range(num_edge_sample):
        rand_index = random.randint(0, len(edge_list) - 1)
        
        #train_edges.append(tuple(edge_list[rand_index]))
        train_edges.append(edge_list[rand_index])
    non_edge_num = 0
    
    # sample edges with label 0 (non-exist edges)
    while(non_edge_num < num_edge_sample):
        rand_nodes = tuple(np.random.randint(low=0,high=num_nodes, size=2))
        
        if rand_nodes not in edge_list:
            train_edges.append(rand_nodes)
            non_edge_num += 1

    train_edges_features_mtx = generate_edge_features(train_edges, node_embeddings, edge_operator)
            
    return train_edges, train_edges_features_mtx, train_edges_labels

def generate_test_set(graph_test, node_embeddings, edge_operator):
    edge_list = graph_test.edges
    nodes_with_edge = set()
    
    for edge in edge_list:
        nodes_with_edge.add(edge[0])
        nodes_with_edge.add(edge[1])
    
    num_nodes = graph_test.number_of_nodes()
    
    test_edges = []
    test_edges_labels = []
    
    num_edge_sample = len(edge_list)
    non_edge_num = 0 
    # sample edges with label 0 (non-exist edges)
    
    while(non_edge_num < num_edge_sample):
        rand_nodes = tuple(np.random.randint(low=0,high=num_nodes, size=2))
        
        if rand_nodes not in edge_list:
            test_edges.append(rand_nodes)
            test_edges_labels.append(0)
            non_edge_num += 1
        
    for edge in edge_list:
        test_edges.append(edge)
        test_edges_labels.append(1)
    
    test_edges_features_mtx = generate_edge_features(test_edges, node_embeddings, edge_operator)
    
    return test_edges, test_edges_features_mtx, test_edges_labels

def build_clf(feature_mtx, response_vec):
   
    logistic_regression_model = LogisticRegression(random_state = 0,max_iter=5000,solver='liblinear',verbose=1,tol=1e-6)
    binary_clf = logistic_regression_model.fit(feature_mtx, response_vec)
    
    return binary_clf

def pred_links(feature_mtx, LR_clf):
    predict_edges_labels = LR_clf.predict(feature_mtx)
    
    return predict_edges_labels

def precision_recall(predict_labels, true_labels):
    true_positive  = false_positive = 0
    true_negative =  false_negative = 0
    
    for p_label, true_label in zip(predict_labels, true_labels):
        
        #print(p_label,true_label)
        if p_label == true_label and true_label == 1:
            true_positive += 1
        elif p_label == true_label and true_label == 0:
            true_negative += 1
        elif p_label != true_label and true_label == 1:
            false_negative += 1
        elif p_label != true_label and true_label == 0:
            false_positive += 1

    print("TP: ", true_positive)
    print("TN: ", true_negative)
    print("FP: ", false_positive)
    print("FN: ", false_negative)
    
    precision = true_positive / (true_positive + false_positive)
    recall = true_positive / (true_positive + false_negative)
    if (precision + recall) != 0.0:
        f1 = 2 * (precision * recall) / (precision + recall)
        print("F1: {}".format(f1))
    else:
        print("F1: Divide-by-zero")
    
    cm = metrics.confusion_matrix(true_labels, predict_labels)
    print(cm)
    print(metrics.classification_report(true_labels, predict_labels))
    map = metrics.average_precision_score(true_labels, predict_labels)
    print('Mean Average Precision: {}'.format(map))
    fpr, tpr, thresholds = metrics.roc_curve(true_labels, predict_labels)
    roc_auc = metrics.auc(fpr, tpr)
    print('Area Under ROC Curve: {}'.format(roc_auc))
    
    return precision, recall

# %% [markdown]
# ### Amazon-Food - Monthly
# ### load data

# %%
# load the training and testing graph
with open('../data/amazon_food/amazon_food_monthly_dir.pkl', 'rb') as file:
    graphs = pickle.load(file)
    
graphs = graphs[-20:]
graph_train = graphs[-2]
graph_test = graphs[-1]

# parameters
num_edge_sample = 400

# %%
num_snapshots = len(graphs)
num_snapshots
# Out:
# 20

# %%
emb_list = []
for i in range(num_snapshots):
    file = '../data/amazon_food/N2V_Embeddings/amazon_month/amazon_month_' + str(i) + '.npy'
    node_embedding = np.load(file)
    emb_list.append(node_embedding)
print(len(emb_list))
# Out:
# 20

# %% [markdown]
# ### independent / no combination

# %%
node_embeddings_training = emb_list[-3]
node_embeddings_testing = emb_list[-2]

# %%
for edge_operator in ['Average','Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  1288
# TN:  1541
# FP:  1244
# FN:  1497
# F1: 0.48448373142749673
# [[1541 1244]
#  [1497 1288]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.55      0.53      2785
#            1       0.51      0.46      0.48      2785
#
#    micro avg       0.51      0.51      0.51      5570
#    macro avg       0.51      0.51      0.51      5570
# weighted avg       0.51      0.51      0.51      5570
#
# Mean Average Precision: 0.5040183674106091
# Area Under ROC Curve: 0.5078994614003591
# Precision:  0.5086887835703001
# Recall:  0.46247755834829446
# [LibLinear]Edge Operator: Hadamard
# TP:  1379
# TN:  1366
# FP:  1419
# FN:  1406
# F1: 0.4939996417696579
# [[1366 1419]
#  [1406 1379]]
#               precision    recall  f1-score   support
#
#            0       0.49      0.49      0.49      2785
#            1       0.49      0.50      0.49      2785
#
#    micro avg       0.49      0.49      0.49      5570
#    macro avg       0.49      0.49      0.49      5570
# weighted avg       0.49      0.49      0.49      5570
#
# Mean Average Precision: 0.49646066759662905
# Area Under ROC Curve: 0.492818671454219
# Precision:  0.49285203716940673
# Recall:  0.4951526032315978
# [LibLinear]Edge Operator: Weighted-L1
# TP:  1383
# TN:  1421
# FP:  1364
# FN:  1402
# F1: 0.5
# [[1421 1364]
#  [1402 1383]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.51      0.51      2785
#            1       0.50      0.50      0.50      2785
#
#    micro avg       0.50      0.50      0.50      5570
#    macro avg       0.50      0.50      0.50      5570
# weighted avg       0.50      0.50      0.50      5570
#
# Mean Average Precision: 0.5017173623061293
# Area Under ROC Curve: 0.503411131059246
# Precision:  0.5034583181652712
# Recall:  0.49658886894075405
# [LibLinear]Edge Operator: Weighted-L2
# TP:  1295
# TN:  1504
# FP:  1281
# FN:  1490
# F1: 0.48311882111546345
# [[1504 1281]
#  [1490 1295]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.54      0.52      2785
#            1       0.50      0.46      0.48      2785
#
#    micro avg       0.50      0.50      0.50      5570
#    macro avg       0.50      0.50      0.50      5570
# weighted avg       0.50      0.50      0.50      5570
#
# Mean Average Precision: 0.5012635625634221
# Area Under ROC Curve: 0.5025134649910233
# Precision:  0.5027173913043478
# Recall:  0.4649910233393178
# [LibLinear]Edge Operator: Concat
# TP:  1216
# TN:  1667
# FP:  1118
# FN:  1569
# F1: 0.4750927915608517
# [[1667 1118]
#  [1569 1216]]
#               precision    recall  f1-score   support
#
#            0       0.52      0.60      0.55      2785
#            1       0.52      0.44      0.48      2785
#
#    micro avg       0.52      0.52      0.52      5570
#    macro avg       0.52      0.52      0.51      5570
# weighted avg       0.52      0.52      0.51      5570
#
# Mean Average Precision: 0.5091665012868855
# Area Under ROC Curve: 0.5175942549371634
# Precision:  0.5209940017137961
# Recall:  0.43662477558348295

# %% [markdown]
# ### sum

# %%
for i in range(len(emb_list)):
    emb_list[i] = np.asfarray(emb_list[i],float)
node_embeddings_training = np.sum(np.asarray(emb_list[0:-2]),axis=0)
node_embeddings_testing = np.sum(np.asarray(emb_list[0:-1]),axis=0)

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  1294
# TN:  1549
# FP:  1236
# FN:  1491
# F1: 0.4869238005644403
# [[1549 1236]
#  [1491 1294]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.56      0.53      2785
#            1       0.51      0.46      0.49      2785
#
#    micro avg       0.51      0.51      0.51      5570
#    macro avg       0.51      0.51      0.51      5570
# weighted avg       0.51      0.51      0.51      5570
#
# Mean Average Precision: 0.5053258208499798
# Area Under ROC Curve: 0.5104129263913824
# Precision:  0.5114624505928854
# Recall:  0.46463195691202874
# [LibLinear]Edge Operator: Hadamard
# TP:  1305
# TN:  1466
# FP:  1319
# FN:  1480
# F1: 0.4825291181364393
# [[1466 1319]
#  [1480 1305]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.53      0.51      2785
#            1       0.50      0.47      0.48      2785
#
#    micro avg       0.50      0.50      0.50      5570
#    macro avg       0.50      0.50      0.50      5570
# weighted avg       0.50      0.50      0.50      5570
#
# Mean Average Precision: 0.49874997263213205
# Area Under ROC Curve: 0.49748653500897666
# Precision:  0.4973323170731707
# Recall:  0.46858168761220825
# [LibLinear]Edge Operator: Weighted-L1
# TP:  1430
# TN:  1401
# FP:  1384
# FN:  1355
# F1: 0.5108055009823184
# [[1401 1384]
#  [1355 1430]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.50      0.51      2785
#            1       0.51      0.51      0.51      2785
#
#    micro avg       0.51      0.51      0.51      5570
#    macro avg       0.51      0.51      0.51      5570
# weighted avg       0.51      0.51      0.51      5570
#
# Mean Average Precision: 0.5041967643189541
# Area Under ROC Curve: 0.5082585278276481
# Precision:  0.5081734186211798
# Recall:  0.5134649910233393
# [LibLinear]Edge Operator: Weighted-L2
# TP:  1406
# TN:  1378
# FP:  1407
# FN:  1379
# F1: 0.5023222579492675
# [[1378 1407]
#  [1379 1406]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.49      0.50      2785
#            1       0.50      0.50      0.50      2785
#
#    micro avg       0.50      0.50      0.50      5570
#    macro avg       0.50      0.50      0.50      5570
# weighted avg       0.50      0.50      0.50      5570
#
# Mean Average Precision: 0.4999102653045204
# Area Under ROC Curve: 0.4998204667863555
# Precision:  0.49982225382154283
# Recall:  0.5048473967684022
# [LibLinear]Edge Operator: Concat
# TP:  1286
# TN:  1571
# FP:  1214
# FN:  1499
# F1: 0.48666035950804165
# [[1571 1214]
#  [1499 1286]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.56      0.54      2785
#            1       0.51      0.46      0.49      2785
#
#    micro avg       0.51      0.51      0.51      5570
#    macro avg       0.51      0.51      0.51      5570
# weighted avg       0.51      0.51      0.51      5570
#
# Mean Average Precision: 0.5066493357271096
# Area Under ROC Curve: 0.5129263913824057
# Precision:  0.5144
# Recall:  0.46175942549371635

# %% [markdown]
# ### expdecay

# %%
exps = [np.exp(-i * 0.3) for i in range(1,21)]
node_embeddings_training = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-2],exps[:-1]):
    node_embeddings_training += e * c
print(len(emb_list))
print(len(exps))
# Out:
# 20
# 20

# %%
node_embeddings_testing = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-1],exps[:-1]):
    node_embeddings_testing += e * c

# %%
for edge_operator in [ 'Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  1278
# TN:  1525
# FP:  1260
# FN:  1507
# F1: 0.4801803494270148
# [[1525 1260]
#  [1507 1278]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.55      0.52      2785
#            1       0.50      0.46      0.48      2785
#
#    micro avg       0.50      0.50      0.50      5570
#    macro avg       0.50      0.50      0.50      5570
# weighted avg       0.50      0.50      0.50      5570
#
# Mean Average Precision: 0.5016272584896291
# Area Under ROC Curve: 0.5032315978456015
# Precision:  0.5035460992907801
# Recall:  0.45888689407540395
# [LibLinear]Edge Operator: Hadamard
# TP:  1344
# TN:  1430
# FP:  1355
# FN:  1441
# F1: 0.49015317286652077
# [[1430 1355]
#  [1441 1344]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.51      0.51      2785
#            1       0.50      0.48      0.49      2785
#
#    micro avg       0.50      0.50      0.50      5570
#    macro avg       0.50      0.50      0.50      5570
# weighted avg       0.50      0.50      0.50      5570
#
# Mean Average Precision: 0.4990165916893217
# Area Under ROC Curve: 0.4980251346499103
# Precision:  0.4979622082252686
# Recall:  0.4825852782764811
# [LibLinear]Edge Operator: Weighted-L1
# TP:  1332
# TN:  1425
# FP:  1360
# FN:  1453
# F1: 0.48639766295417197
# [[1425 1360]
#  [1453 1332]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.51      0.50      2785
#            1       0.49      0.48      0.49      2785
#
#    micro avg       0.49      0.49      0.49      5570
#    macro avg       0.49      0.49      0.49      5570
# weighted avg       0.49      0.49      0.49      5570
#
# Mean Average Precision: 0.4975126780326574
# Area Under ROC Curve: 0.4949730700179533
# Precision:  0.4947994056463596
# Recall:  0.47827648114901256
# [LibLinear]Edge Operator: Weighted-L2
# TP:  1279
# TN:  1451
# FP:  1334
# FN:  1506
# F1: 0.4738792145238977
# [[1451 1334]
#  [1506 1279]]
#               precision    recall  f1-score   support
#
#            0       0.49      0.52      0.51      2785
#            1       0.49      0.46      0.47      2785
#
#    micro avg       0.49      0.49      0.49      5570
#    macro avg       0.49      0.49      0.49      5570
# weighted avg       0.49      0.49      0.49      5570
#
# Mean Average Precision: 0.49516675701728885
# Area Under ROC Curve: 0.4901256732495512
# Precision:  0.4894756984309223
# Recall:  0.459245960502693
# [LibLinear]Edge Operator: Concat
# TP:  1243
# TN:  1651
# FP:  1134
# FN:  1542
# F1: 0.48159628051142966
# [[1651 1134]
#  [1542 1243]]
#               precision    recall  f1-score   support
#
#            0       0.52      0.59      0.55      2785
#            1       0.52      0.45      0.48      2785
#
#    micro avg       0.52      0.52      0.52      5570
#    macro avg       0.52      0.52      0.52      5570
# weighted avg       0.52      0.52      0.52      5570
#
# Mean Average Precision: 0.510233242119081
# Area Under ROC Curve: 0.5195691202872531
# Precision:  0.5229280605805637
# Recall:  0.44631956912028725

# %% [markdown]
# ### Amazon-Food - Weekly
# ### load data

# %%
# load the training and testing graph
with open('../data/amazon_food/amazon_food_weekly_dir.pkl', 'rb') as file:
    graphs = pickle.load(file)
    
graphs = graphs[-20:]
graph_train = graphs[-2]
graph_test = graphs[-1]

# parameters
num_edge_sample = 400

# %%
num_snapshots = len(graphs)
num_snapshots
# Out:
# 20

# %%
emb_list = []
for i in range(num_snapshots):
    file = '../data/amazon_food/N2V_Embeddings/amazon_week/amazon_week_' + str(i) + '.npy'
    node_embedding = np.load(file)
    emb_list.append(node_embedding)
print(len(emb_list))
# Out:
# 20

# %% [markdown]
# ### independent / no combination

# %%
node_embeddings_training = emb_list[-3]
node_embeddings_testing = emb_list[-2]

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  582
# TN:  744
# FP:  534
# FN:  696
# F1: 0.4862155388471178
# [[744 534]
#  [696 582]]
#               precision    recall  f1-score   support
#
#            0       0.52      0.58      0.55      1278
#            1       0.52      0.46      0.49      1278
#
#    micro avg       0.52      0.52      0.52      2556
#    macro avg       0.52      0.52      0.52      2556
# weighted avg       0.52      0.52      0.52      2556
#
# Mean Average Precision: 0.5097935281942552
# Area Under ROC Curve: 0.5187793427230047
# Precision:  0.521505376344086
# Recall:  0.45539906103286387
# [LibLinear]Edge Operator: Hadamard
# TP:  574
# TN:  704
# FP:  574
# FN:  704
# F1: 0.47320692497938993
# [[704 574]
#  [704 574]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.55      0.52      1278
#            1       0.50      0.45      0.47      1278
#
#    micro avg       0.50      0.50      0.50      2556
#    macro avg       0.50      0.50      0.50      2556
# weighted avg       0.50      0.50      0.50      2556
#
# Mean Average Precision: 0.5
# Area Under ROC Curve: 0.49999999999999994
# Precision:  0.5
# Recall:  0.4491392801251956
# [LibLinear]Edge Operator: Weighted-L1
# TP:  627
# TN:  648
# FP:  630
# FN:  651
# F1: 0.49467455621301776
# [[648 630]
#  [651 627]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.51      0.50      1278
#            1       0.50      0.49      0.49      1278
#
#    micro avg       0.50      0.50      0.50      2556
#    macro avg       0.50      0.50      0.50      2556
# weighted avg       0.50      0.50      0.50      2556
#
# Mean Average Precision: 0.4994145461472094
# Area Under ROC Curve: 0.49882629107981213
# Precision:  0.4988066825775656
# Recall:  0.49061032863849763
# [LibLinear]Edge Operator: Weighted-L2
# TP:  1084
# TN:  199
# FP:  1079
# FN:  194
# F1: 0.6300494042429526
# [[ 199 1079]
#  [ 194 1084]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.16      0.24      1278
#            1       0.50      0.85      0.63      1278
#
#    micro avg       0.50      0.50      0.50      2556
#    macro avg       0.50      0.50      0.43      2556
# weighted avg       0.50      0.50      0.43      2556
#
# Mean Average Precision: 0.5009803517256
# Area Under ROC Curve: 0.5019561815336464
# Precision:  0.5011558021266759
# Recall:  0.8482003129890454
# [LibLinear]Edge Operator: Concat
# TP:  529
# TN:  769
# FP:  509
# FN:  749
# F1: 0.4568221070811744
# [[769 509]
#  [749 529]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.60      0.55      1278
#            1       0.51      0.41      0.46      1278
#
#    micro avg       0.51      0.51      0.51      2556
#    macro avg       0.51      0.51      0.50      2556
# weighted avg       0.51      0.51      0.50      2556
#
# Mean Average Precision: 0.5039877457853522
# Area Under ROC Curve: 0.5078247261345853
# Precision:  0.5096339113680154
# Recall:  0.4139280125195618

# %% [markdown]
# ### sum

# %%
for i in range(len(emb_list)):
    emb_list[i] = np.asfarray(emb_list[i],float)
node_embeddings_training = np.sum(np.asarray(emb_list[0:-2]),axis=0)
node_embeddings_testing = np.sum(np.asarray(emb_list[0:-1]),axis=0)

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  599
# TN:  755
# FP:  523
# FN:  679
# F1: 0.49916666666666676
# [[755 523]
#  [679 599]]
#               precision    recall  f1-score   support
#
#            0       0.53      0.59      0.56      1278
#            1       0.53      0.47      0.50      1278
#
#    micro avg       0.53      0.53      0.53      2556
#    macro avg       0.53      0.53      0.53      2556
# weighted avg       0.53      0.53      0.53      2556
#
# Mean Average Precision: 0.5158740121457603
# Area Under ROC Curve: 0.5297339593114241
# Precision:  0.533868092691622
# Recall:  0.46870109546165883
# [LibLinear]Edge Operator: Hadamard
# TP:  605
# TN:  666
# FP:  612
# FN:  673
# F1: 0.4849699398797595
# [[666 612]
#  [673 605]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.52      0.51      1278
#            1       0.50      0.47      0.48      1278
#
#    micro avg       0.50      0.50      0.50      2556
#    macro avg       0.50      0.50      0.50      2556
# weighted avg       0.50      0.50      0.50      2556
#
# Mean Average Precision: 0.49863854908874405
# Area Under ROC Curve: 0.49726134585289516
# Precision:  0.4971240755957272
# Recall:  0.47339593114241
# [LibLinear]Edge Operator: Weighted-L1
# TP:  559
# TN:  715
# FP:  563
# FN:  719
# F1: 0.46583333333333327
# [[715 563]
#  [719 559]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.56      0.53      1278
#            1       0.50      0.44      0.47      1278
#
#    micro avg       0.50      0.50      0.50      2556
#    macro avg       0.50      0.50      0.50      2556
# weighted avg       0.50      0.50      0.50      2556
#
# Mean Average Precision: 0.49922031695022584
# Area Under ROC Curve: 0.4984350547730829
# Precision:  0.4982174688057041
# Recall:  0.43740219092331767
# [LibLinear]Edge Operator: Weighted-L2
# TP:  574
# TN:  674
# FP:  604
# FN:  704
# F1: 0.46742671009771986
# [[674 604]
#  [704 574]]
#               precision    recall  f1-score   support
#
#            0       0.49      0.53      0.51      1278
#            1       0.49      0.45      0.47      1278
#
#    micro avg       0.49      0.49      0.49      2556
#    macro avg       0.49      0.49      0.49      2556
# weighted avg       0.49      0.49      0.49      2556
#
# Mean Average Precision: 0.494280908996708
# Area Under ROC Curve: 0.4882629107981221
# Precision:  0.4872665534804754
# Recall:  0.4491392801251956
# [LibLinear]Edge Operator: Concat
# TP:  568
# TN:  735
# FP:  543
# FN:  710
# F1: 0.47551276684805355
# [[735 543]
#  [710 568]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.58      0.54      1278
#            1       0.51      0.44      0.48      1278
#
#    micro avg       0.51      0.51      0.51      2556
#    macro avg       0.51      0.51      0.51      2556
# weighted avg       0.51      0.51      0.51      2556
#
# Mean Average Precision: 0.505000500050005
# Area Under ROC Curve: 0.5097809076682316
# Precision:  0.5112511251125113
# Recall:  0.4444444444444444

# %% [markdown]
# ### expdecay

# %%
exps = [np.exp(-i * 0.3) for i in range(1,21)]
node_embeddings_training = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-2],exps[:-1]):
    node_embeddings_training += e * c 
node_embeddings_testing = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-1],exps[:-1]):
    node_embeddings_testing += e * c 
print(len(emb_list))
print(len(exps))

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  604
# TN:  746
# FP:  532
# FN:  674
# F1: 0.500414250207125
# [[746 532]
#  [674 604]]
#               precision    recall  f1-score   support
#
#            0       0.53      0.58      0.55      1278
#            1       0.53      0.47      0.50      1278
#
#    micro avg       0.53      0.53      0.53      2556
#    macro avg       0.53      0.53      0.53      2556
# weighted avg       0.53      0.53      0.53      2556
#
# Mean Average Precision: 0.5149771870660583
# Area Under ROC Curve: 0.528169014084507
# Precision:  0.5316901408450704
# Recall:  0.4726134585289515
# [LibLinear]Edge Operator: Hadamard
# TP:  636
# TN:  653
# FP:  625
# FN:  642
# F1: 0.5009846396218983
# [[653 625]
#  [642 636]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.51      0.51      1278
#            1       0.50      0.50      0.50      1278
#
#    micro avg       0.50      0.50      0.50      2556
#    macro avg       0.50      0.50      0.50      2556
# weighted avg       0.50      0.50      0.50      2556
#
# Mean Average Precision: 0.5021705703424884
# Area Under ROC Curve: 0.5043035993740219
# Precision:  0.5043616177636796
# Recall:  0.49765258215962443
# [LibLinear]Edge Operator: Weighted-L1
# TP:  606
# TN:  659
# FP:  619
# FN:  672
# F1: 0.4842189372752697
# [[659 619]
#  [672 606]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.52      0.51      1278
#            1       0.49      0.47      0.48      1278
#
#    micro avg       0.49      0.49      0.49      2556
#    macro avg       0.49      0.49      0.49      2556
# weighted avg       0.49      0.49      0.49      2556
#
# Mean Average Precision: 0.49748395132700973
# Area Under ROC Curve: 0.49491392801251954
# Precision:  0.4946938775510204
# Recall:  0.47417840375586856
# [LibLinear]Edge Operator: Weighted-L2
# TP:  613
# TN:  696
# FP:  582
# FN:  665
# F1: 0.49575414476344526
# [[696 582]
#  [665 613]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.54      0.53      1278
#            1       0.51      0.48      0.50      1278
#
#    micro avg       0.51      0.51      0.51      2556
#    macro avg       0.51      0.51      0.51      2556
# weighted avg       0.51      0.51      0.51      2556
#
# Mean Average Precision: 0.5062214757629927
# Area Under ROC Curve: 0.5121283255086071
# Precision:  0.5129707112970712
# Recall:  0.47965571205007823
# [LibLinear]Edge Operator: Concat
# TP:  532
# TN:  770
# FP:  508
# FN:  746
# F1: 0.45901639344262296
# [[770 508]
#  [746 532]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.60      0.55      1278
#            1       0.51      0.42      0.46      1278
#
#    micro avg       0.51      0.51      0.51      2556
#    macro avg       0.51      0.51      0.51      2556
# weighted avg       0.51      0.51      0.51      2556
#
# Mean Average Precision: 0.5048031780426147
# Area Under ROC Curve: 0.5093896713615024
# Precision:  0.5115384615384615
# Recall:  0.4162754303599374

# %% [markdown]
# ### Amazon-Food - Equal Monthly
# ### load data

# %%
# load the training and testing graph
with open('../data/amazon_food/amazon_food_equal_monthly_dir.pkl', 'rb') as file:
    graphs = pickle.load(file)
    
graphs = graphs[-20:]
graph_train = graphs[-2]
graph_test = graphs[-1]

# parameters
num_edge_sample = 400

# %%
num_snapshots = len(graphs)
num_snapshots
# Out:
# 20

# %%
emb_list = []
for i in range(num_snapshots):
    file = '../data/amazon_food/N2V_Embeddings/amazon_equal_month/amazon_equal_month_' + str(i) + '.npy'
    node_embedding = np.load(file)
    emb_list.append(node_embedding)
print(len(emb_list))
# Out:
# 20

# %% [markdown]
# ### independent / no combination

# %%
node_embeddings_training = emb_list[-3]
node_embeddings_testing = emb_list[-2]

# %%
for edge_operator in ['Average','Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  251
# TN:  410
# FP:  220
# FN:  379
# F1: 0.4559491371480472
# [[410 220]
#  [379 251]]
#               precision    recall  f1-score   support
#
#            0       0.52      0.65      0.58       630
#            1       0.53      0.40      0.46       630
#
#    micro avg       0.52      0.52      0.52      1260
#    macro avg       0.53      0.52      0.52      1260
# weighted avg       0.53      0.52      0.52      1260
#
# Mean Average Precision: 0.5131112459137936
# Area Under ROC Curve: 0.5246031746031745
# Precision:  0.5329087048832272
# Recall:  0.3984126984126984
# [LibLinear]Edge Operator: Hadamard
# TP:  303
# TN:  296
# FP:  334
# FN:  327
# F1: 0.478295185477506
# [[296 334]
#  [327 303]]
#               precision    recall  f1-score   support
#
#            0       0.48      0.47      0.47       630
#            1       0.48      0.48      0.48       630
#
#    micro avg       0.48      0.48      0.48      1260
#    macro avg       0.48      0.48      0.48      1260
# weighted avg       0.48      0.48      0.48      1260
#
# Mean Average Precision: 0.4882970770725873
# Area Under ROC Curve: 0.47539682539682543
# Precision:  0.47566718995290425
# Recall:  0.48095238095238096
# [LibLinear]Edge Operator: Weighted-L1
# TP:  289
# TN:  314
# FP:  316
# FN:  341
# F1: 0.4680161943319838
# [[314 316]
#  [341 289]]
#               precision    recall  f1-score   support
#
#            0       0.48      0.50      0.49       630
#            1       0.48      0.46      0.47       630
#
#    micro avg       0.48      0.48      0.48      1260
#    macro avg       0.48      0.48      0.48      1260
# weighted avg       0.48      0.48      0.48      1260
#
# Mean Average Precision: 0.4897638724911453
# Area Under ROC Curve: 0.47857142857142854
# Precision:  0.47768595041322315
# Recall:  0.4587301587301587
# [LibLinear]Edge Operator: Weighted-L2
# TP:  396
# TN:  236
# FP:  394
# FN:  234
# F1: 0.5577464788732395
# [[236 394]
#  [234 396]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.37      0.43       630
#            1       0.50      0.63      0.56       630
#
#    micro avg       0.50      0.50      0.50      1260
#    macro avg       0.50      0.50      0.49      1260
# weighted avg       0.50      0.50      0.49      1260
#
# Mean Average Precision: 0.5007956600361664
# Area Under ROC Curve: 0.5015873015873016
# Precision:  0.5012658227848101
# Recall:  0.6285714285714286
# [LibLinear]Edge Operator: Concat
# TP:  284
# TN:  413
# FP:  217
# FN:  346
# F1: 0.502210433244916
# [[413 217]
#  [346 284]]
#               precision    recall  f1-score   support
#
#            0       0.54      0.66      0.59       630
#            1       0.57      0.45      0.50       630
#
#    micro avg       0.55      0.55      0.55      1260
#    macro avg       0.56      0.55      0.55      1260
# weighted avg       0.56      0.55      0.55      1260
#
# Mean Average Precision: 0.5301428888255235
# Area Under ROC Curve: 0.5531746031746032
# Precision:  0.5668662674650699
# Recall:  0.4507936507936508

# %% [markdown]
# ### sum

# %%
for i in range(len(emb_list)):
    emb_list[i] = np.asfarray(emb_list[i],float)
node_embeddings_training = np.sum(np.asarray(emb_list[0:-2]),axis=0)
node_embeddings_testing = np.sum(np.asarray(emb_list[0:-1]),axis=0)

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  286
# TN:  377
# FP:  253
# FN:  344
# F1: 0.4893071000855432
# [[377 253]
#  [344 286]]
#               precision    recall  f1-score   support
#
#            0       0.52      0.60      0.56       630
#            1       0.53      0.45      0.49       630
#
#    micro avg       0.53      0.53      0.53      1260
#    macro avg       0.53      0.53      0.52      1260
# weighted avg       0.53      0.53      0.52      1260
#
# Mean Average Precision: 0.5138969873663751
# Area Under ROC Curve: 0.5261904761904762
# Precision:  0.5306122448979592
# Recall:  0.45396825396825397
# [LibLinear]Edge Operator: Hadamard
# TP:  284
# TN:  353
# FP:  277
# FN:  346
# F1: 0.4769101595298068
# [[353 277]
#  [346 284]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.56      0.53       630
#            1       0.51      0.45      0.48       630
#
#    micro avg       0.51      0.51      0.51      1260
#    macro avg       0.51      0.51      0.50      1260
# weighted avg       0.51      0.51      0.50      1260
#
# Mean Average Precision: 0.5028124381065557
# Area Under ROC Curve: 0.5055555555555555
# Precision:  0.5062388591800356
# Recall:  0.4507936507936508
# [LibLinear]Edge Operator: Weighted-L1
# TP:  288
# TN:  335
# FP:  295
# FN:  342
# F1: 0.4748557295960429
# [[335 295]
#  [342 288]]
#               precision    recall  f1-score   support
#
#            0       0.49      0.53      0.51       630
#            1       0.49      0.46      0.47       630
#
#    micro avg       0.49      0.49      0.49      1260
#    macro avg       0.49      0.49      0.49      1260
# weighted avg       0.49      0.49      0.49      1260
#
# Mean Average Precision: 0.4972555746140652
# Area Under ROC Curve: 0.4944444444444444
# Precision:  0.4939965694682676
# Recall:  0.45714285714285713
# [LibLinear]Edge Operator: Weighted-L2
# TP:  317
# TN:  317
# FP:  313
# FN:  313
# F1: 0.5031746031746032
# [[317 313]
#  [313 317]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50       630
#            1       0.50      0.50      0.50       630
#
#    micro avg       0.50      0.50      0.50      1260
#    macro avg       0.50      0.50      0.50      1260
# weighted avg       0.50      0.50      0.50      1260
#
# Mean Average Precision: 0.5015973796926179
# Area Under ROC Curve: 0.5031746031746032
# Precision:  0.5031746031746032
# Recall:  0.5031746031746032
# [LibLinear]Edge Operator: Concat
# TP:  306
# TN:  407
# FP:  223
# FN:  324
# F1: 0.5280414150129421
# [[407 223]
#  [324 306]]
#               precision    recall  f1-score   support
#
#            0       0.56      0.65      0.60       630
#            1       0.58      0.49      0.53       630
#
#    micro avg       0.57      0.57      0.57      1260
#    macro avg       0.57      0.57      0.56      1260
# weighted avg       0.57      0.57      0.56      1260
#
# Mean Average Precision: 0.538104239805563
# Area Under ROC Curve: 0.5658730158730159
# Precision:  0.5784499054820416
# Recall:  0.4857142857142857

# %% [markdown]
# ### expdecay

# %%
exps = [np.exp(-i * 0.3) for i in range(1,21)]
node_embeddings_training = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-2],exps[:-1]):
    node_embeddings_training += e * c 
node_embeddings_testing = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-1],exps[:-1]):
    node_embeddings_testing += e * c 
print(len(emb_list))
print(len(exps))
# Out:
# 20
# 20

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  291
# TN:  402
# FP:  228
# FN:  339
# F1: 0.5065274151436031
# [[402 228]
#  [339 291]]
#               precision    recall  f1-score   support
#
#            0       0.54      0.64      0.59       630
#            1       0.56      0.46      0.51       630
#
#    micro avg       0.55      0.55      0.55      1260
#    macro avg       0.55      0.55      0.55      1260
# weighted avg       0.55      0.55      0.55      1260
#
# Mean Average Precision: 0.5280346820809249
# Area Under ROC Curve: 0.55
# Precision:  0.5606936416184971
# Recall:  0.46190476190476193
# [LibLinear]Edge Operator: Hadamard
# TP:  320
# TN:  318
# FP:  312
# FN:  310
# F1: 0.5071315372424723
# [[318 312]
#  [310 320]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.50      0.51       630
#            1       0.51      0.51      0.51       630
#
#    micro avg       0.51      0.51      0.51      1260
#    macro avg       0.51      0.51      0.51      1260
# weighted avg       0.51      0.51      0.51      1260
#
# Mean Average Precision: 0.5032147880249147
# Area Under ROC Curve: 0.5063492063492063
# Precision:  0.5063291139240507
# Recall:  0.5079365079365079
# [LibLinear]Edge Operator: Weighted-L1
# TP:  283
# TN:  352
# FP:  278
# FN:  347
# F1: 0.47523089840470195
# [[352 278]
#  [347 283]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.56      0.53       630
#            1       0.50      0.45      0.48       630
#
#    micro avg       0.50      0.50      0.50      1260
#    macro avg       0.50      0.50      0.50      1260
# weighted avg       0.50      0.50      0.50      1260
#
# Mean Average Precision: 0.5020018108253403
# Area Under ROC Curve: 0.503968253968254
# Precision:  0.5044563279857398
# Recall:  0.4492063492063492
# [LibLinear]Edge Operator: Weighted-L2
# TP:  259
# TN:  341
# FP:  289
# FN:  371
# F1: 0.4397283531409168
# [[341 289]
#  [371 259]]
#               precision    recall  f1-score   support
#
#            0       0.48      0.54      0.51       630
#            1       0.47      0.41      0.44       630
#
#    micro avg       0.48      0.48      0.48      1260
#    macro avg       0.48      0.48      0.47      1260
# weighted avg       0.48      0.48      0.47      1260
#
# Mean Average Precision: 0.4887469586374696
# Area Under ROC Curve: 0.4761904761904762
# Precision:  0.4726277372262774
# Recall:  0.4111111111111111
# [LibLinear]Edge Operator: Concat
# TP:  268
# TN:  418
# FP:  212
# FN:  362
# F1: 0.48288288288288284
# [[418 212]
#  [362 268]]
#               precision    recall  f1-score   support
#
#            0       0.54      0.66      0.59       630
#            1       0.56      0.43      0.48       630
#
#    micro avg       0.54      0.54      0.54      1260
#    macro avg       0.55      0.54      0.54      1260
# weighted avg       0.55      0.54      0.54      1260
#
# Mean Average Precision: 0.5248148148148148
# Area Under ROC Curve: 0.5444444444444444
# Precision:  0.5583333333333333
# Recall:  0.4253968253968254

# %% [markdown]
# ### Amazon-Food - Equal Weekly
# ### load data

# %%
# load the training and testing graph
with open('../data/amazon_food/amazon_food_equal_weekly_dir.pkl', 'rb') as file:
    graphs = pickle.load(file)
    
graphs = graphs[-20:]
graph_train = graphs[-2]
graph_test = graphs[-1]

# parameters
num_edge_sample = 400

# %%
num_snapshots = len(graphs)
num_snapshots
# Out:
# 20

# %%
emb_list = []
for i in range(num_snapshots):
    file = '../data/amazon_food/N2V_Embeddings/amazon_equal_week/amazon_equal_week_' + str(i) + '.npy'
    node_embedding = np.load(file)
    emb_list.append(node_embedding)
print(len(emb_list))
# Out:
# 20

# %% [markdown]
# ### independent / no combination

# %%
node_embeddings_training = emb_list[-3]
node_embeddings_testing = emb_list[-2]

# %%
for edge_operator in ['Average','Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  142
# TN:  206
# FP:  114
# FN:  178
# F1: 0.4930555555555555
# [[206 114]
#  [178 142]]
#               precision    recall  f1-score   support
#
#            0       0.54      0.64      0.59       320
#            1       0.55      0.44      0.49       320
#
#    micro avg       0.54      0.54      0.54       640
#    macro avg       0.55      0.54      0.54       640
# weighted avg       0.55      0.54      0.54       640
#
# Mean Average Precision: 0.524267578125
# Area Under ROC Curve: 0.5437500000000001
# Precision:  0.5546875
# Recall:  0.44375
# [LibLinear]Edge Operator: Hadamard
# TP:  177
# TN:  165
# FP:  155
# FN:  143
# F1: 0.5429447852760735
# [[165 155]
#  [143 177]]
#               precision    recall  f1-score   support
#
#            0       0.54      0.52      0.53       320
#            1       0.53      0.55      0.54       320
#
#    micro avg       0.53      0.53      0.53       640
#    macro avg       0.53      0.53      0.53       640
# weighted avg       0.53      0.53      0.53       640
#
# Mean Average Precision: 0.5183264307228915
# Area Under ROC Curve: 0.534375
# Precision:  0.5331325301204819
# Recall:  0.553125
# [LibLinear]Edge Operator: Weighted-L1
# TP:  154
# TN:  196
# FP:  124
# FN:  166
# F1: 0.5150501672240803
# [[196 124]
#  [166 154]]
#               precision    recall  f1-score   support
#
#            0       0.54      0.61      0.57       320
#            1       0.55      0.48      0.52       320
#
#    micro avg       0.55      0.55      0.55       640
#    macro avg       0.55      0.55      0.54       640
# weighted avg       0.55      0.55      0.54       640
#
# Mean Average Precision: 0.5259667266187051
# Area Under ROC Curve: 0.546875
# Precision:  0.5539568345323741
# Recall:  0.48125
# [LibLinear]Edge Operator: Weighted-L2
# TP:  157
# TN:  186
# FP:  134
# FN:  163
# F1: 0.5139116202945989
# [[186 134]
#  [163 157]]
#               precision    recall  f1-score   support
#
#            0       0.53      0.58      0.56       320
#            1       0.54      0.49      0.51       320
#
#    micro avg       0.54      0.54      0.54       640
#    macro avg       0.54      0.54      0.53       640
# weighted avg       0.54      0.54      0.53       640
#
# Mean Average Precision: 0.5193889604810996
# Area Under ROC Curve: 0.5359375000000001
# Precision:  0.5395189003436426
# Recall:  0.490625
# [LibLinear]Edge Operator: Concat
# TP:  119
# TN:  225
# FP:  95
# FN:  201
# F1: 0.4456928838951311
# [[225  95]
#  [201 119]]
#               precision    recall  f1-score   support
#
#            0       0.53      0.70      0.60       320
#            1       0.56      0.37      0.45       320
#
#    micro avg       0.54      0.54      0.54       640
#    macro avg       0.54      0.54      0.52       640
# weighted avg       0.54      0.54      0.52       640
#
# Mean Average Precision: 0.5208528037383178
# Area Under ROC Curve: 0.5375
# Precision:  0.5560747663551402
# Recall:  0.371875

# %% [markdown]
# ### sum

# %%
for i in range(len(emb_list)):
    emb_list[i] = np.asfarray(emb_list[i],float)
node_embeddings_training = np.sum(np.asarray(emb_list[0:-2]),axis=0)
node_embeddings_testing = np.sum(np.asarray(emb_list[0:-1]),axis=0)

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  143
# TN:  201
# FP:  119
# FN:  177
# F1: 0.49140893470790376
# [[201 119]
#  [177 143]]
#               precision    recall  f1-score   support
#
#            0       0.53      0.63      0.58       320
#            1       0.55      0.45      0.49       320
#
#    micro avg       0.54      0.54      0.54       640
#    macro avg       0.54      0.54      0.53       640
# weighted avg       0.54      0.54      0.53       640
#
# Mean Average Precision: 0.5204675572519084
# Area Under ROC Curve: 0.5375
# Precision:  0.5458015267175572
# Recall:  0.446875
# [LibLinear]Edge Operator: Hadamard
# TP:  159
# TN:  190
# FP:  130
# FN:  161
# F1: 0.5221674876847291
# [[190 130]
#  [161 159]]
#               precision    recall  f1-score   support
#
#            0       0.54      0.59      0.57       320
#            1       0.55      0.50      0.52       320
#
#    micro avg       0.55      0.55      0.55       640
#    macro avg       0.55      0.55      0.54       640
# weighted avg       0.55      0.55      0.54       640
#
# Mean Average Precision: 0.524929714532872
# Area Under ROC Curve: 0.5453125
# Precision:  0.5501730103806228
# Recall:  0.496875
# [LibLinear]Edge Operator: Weighted-L1
# TP:  150
# TN:  177
# FP:  143
# FN:  170
# F1: 0.4893964110929853
# [[177 143]
#  [170 150]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.55      0.53       320
#            1       0.51      0.47      0.49       320
#
#    micro avg       0.51      0.51      0.51       640
#    macro avg       0.51      0.51      0.51       640
# weighted avg       0.51      0.51      0.51       640
#
# Mean Average Precision: 0.5055994027303754
# Area Under ROC Curve: 0.5109375
# Precision:  0.5119453924914675
# Recall:  0.46875
# [LibLinear]Edge Operator: Weighted-L2
# TP:  142
# TN:  199
# FP:  121
# FN:  178
# F1: 0.4871355060034305
# [[199 121]
#  [178 142]]
#               precision    recall  f1-score   support
#
#            0       0.53      0.62      0.57       320
#            1       0.54      0.44      0.49       320
#
#    micro avg       0.53      0.53      0.53       640
#    macro avg       0.53      0.53      0.53       640
# weighted avg       0.53      0.53      0.53       640
#
# Mean Average Precision: 0.5177162547528517
# Area Under ROC Curve: 0.5328125
# Precision:  0.5399239543726235
# Recall:  0.44375
# [LibLinear]Edge Operator: Concat
# TP:  127
# TN:  219
# FP:  101
# FN:  193
# F1: 0.46350364963503643
# [[219 101]
#  [193 127]]
#               precision    recall  f1-score   support
#
#            0       0.53      0.68      0.60       320
#            1       0.56      0.40      0.46       320
#
#    micro avg       0.54      0.54      0.54       640
#    macro avg       0.54      0.54      0.53       640
# weighted avg       0.54      0.54      0.53       640
#
# Mean Average Precision: 0.5226288377192982
# Area Under ROC Curve: 0.5406249999999999
# Precision:  0.5570175438596491
# Recall:  0.396875

# %% [markdown]
# ### expdecay

# %%
exps = [np.exp(-i * 0.3) for i in range(1,21)]
node_embeddings_training = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-2],exps[:-1]):
    node_embeddings_training += e * c 
node_embeddings_testing = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-1],exps[:-1]):
    node_embeddings_testing += e * c 
print(len(exps))
print(len(emb_list))
# Out:
# 20
# 20

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  144
# TN:  197
# FP:  123
# FN:  176
# F1: 0.4906303236797275
# [[197 123]
#  [176 144]]
#               precision    recall  f1-score   support
#
#            0       0.53      0.62      0.57       320
#            1       0.54      0.45      0.49       320
#
#    micro avg       0.53      0.53      0.53       640
#    macro avg       0.53      0.53      0.53       640
# weighted avg       0.53      0.53      0.53       640
#
# Mean Average Precision: 0.5176966292134831
# Area Under ROC Curve: 0.5328124999999999
# Precision:  0.5393258426966292
# Recall:  0.45
# [LibLinear]Edge Operator: Hadamard
# TP:  161
# TN:  150
# FP:  170
# FN:  159
# F1: 0.4946236559139785
# [[150 170]
#  [159 161]]
#               precision    recall  f1-score   support
#
#            0       0.49      0.47      0.48       320
#            1       0.49      0.50      0.49       320
#
#    micro avg       0.49      0.49      0.49       640
#    macro avg       0.49      0.49      0.49       640
# weighted avg       0.49      0.49      0.49       640
#
# Mean Average Precision: 0.4931599320241692
# Area Under ROC Curve: 0.4859375
# Precision:  0.486404833836858
# Recall:  0.503125
# [LibLinear]Edge Operator: Weighted-L1
# TP:  146
# TN:  180
# FP:  140
# FN:  174
# F1: 0.4818481848184819
# [[180 140]
#  [174 146]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.56      0.53       320
#            1       0.51      0.46      0.48       320
#
#    micro avg       0.51      0.51      0.51       640
#    macro avg       0.51      0.51      0.51       640
# weighted avg       0.51      0.51      0.51       640
#
# Mean Average Precision: 0.5047858391608392
# Area Under ROC Curve: 0.509375
# Precision:  0.5104895104895105
# Recall:  0.45625
# [LibLinear]Edge Operator: Weighted-L2
# TP:  146
# TN:  190
# FP:  130
# FN:  174
# F1: 0.4899328859060403
# [[190 130]
#  [174 146]]
#               precision    recall  f1-score   support
#
#            0       0.52      0.59      0.56       320
#            1       0.53      0.46      0.49       320
#
#    micro avg       0.53      0.53      0.53       640
#    macro avg       0.53      0.53      0.52       640
# weighted avg       0.53      0.53      0.52       640
#
# Mean Average Precision: 0.5132246376811593
# Area Under ROC Curve: 0.525
# Precision:  0.5289855072463768
# Recall:  0.45625
# [LibLinear]Edge Operator: Concat
# TP:  121
# TN:  216
# FP:  104
# FN:  199
# F1: 0.44403669724770645
# [[216 104]
#  [199 121]]
#               precision    recall  f1-score   support
#
#            0       0.52      0.68      0.59       320
#            1       0.54      0.38      0.44       320
#
#    micro avg       0.53      0.53      0.53       640
#    macro avg       0.53      0.53      0.52       640
# weighted avg       0.53      0.53      0.52       640
#
# Mean Average Precision: 0.5142847222222222
# Area Under ROC Curve: 0.5265625
# Precision:  0.5377777777777778
# Recall:  0.378125
