# %%
import random

from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
import pickle
import sklearn.metrics as metrics

# %% [markdown]
# ### functions

# %%
def edge_features(node_emb_1, node_emb_2, operator):
    node_emb_1 = np.asfarray(node_emb_1,float)
    node_emb_2 = np.asfarray(node_emb_2, float)
    # combine two nodes' embeddings with specificed operator
    if operator == 'Average':
        edge = [((x + y) / 2.0) for x,y in zip(node_emb_1, node_emb_2)]
    elif operator == 'Hadamard':
        edge = [(x * y) for x,y in zip(node_emb_1, node_emb_2)]
    elif operator == 'Weighted-L1':
        edge = [abs(x - y) for x,y in zip(node_emb_1, node_emb_2)]
    elif operator == 'Weighted-L2':
        edge = [abs(x - y)**2 for x,y in zip(node_emb_1, node_emb_2)]
    elif operator == 'Concat':
        edge = np.concatenate((node_emb_1, node_emb_2), axis=None) 
    else:
        print("Generate edge features: Operator not supported")
        print("Use default operator: Weighted-L1")
        edge = [abs(x - y) for x,y in zip(node_emb_1, node_emb_2)]
        
    return edge
def generate_edge_features(edge_list, node_embeddings, operator):
    edge_features_mtx = []
    
    # generate features for each edge in the list
    for node_index_1, node_index_2 in edge_list:
        node_emb_1 = node_embeddings[node_index_1-1]
        node_emb_2 = node_embeddings[node_index_2-1]
        
        edge_features_mtx.append(edge_features(node_emb_1, node_emb_2, operator))
        
    return edge_features_mtx

def generate_train_set(graph_train, num_edge_sample, node_embeddings, edge_operator,):
    edge_list = list(graph_train.edges)
    num_nodes = graph_train.number_of_nodes()
    
    train_edges = []
    train_edges_labels = [1] * num_edge_sample + [0] * num_edge_sample
    
    random.seed(0)
    
    # sample edges with label 1 (true edges)
    for edge_num in range(num_edge_sample):
        rand_index = random.randint(0, len(edge_list) - 1)
        
        #train_edges.append(tuple(edge_list[rand_index]))
        train_edges.append(edge_list[rand_index])
    non_edge_num = 0
    
    # sample edges with label 0 (non-exist edges)
    while(non_edge_num < num_edge_sample):
        rand_nodes = tuple(np.random.randint(low=0,high=num_nodes, size=2))
        
        if rand_nodes not in edge_list:
            train_edges.append(rand_nodes)
            non_edge_num += 1

    train_edges_features_mtx = generate_edge_features(train_edges, node_embeddings, edge_operator)
            
    return train_edges, train_edges_features_mtx, train_edges_labels

def generate_test_set(graph_test, node_embeddings, edge_operator):
    edge_list = graph_test.edges
    nodes_with_edge = set()
    
    for edge in edge_list:
        nodes_with_edge.add(edge[0])
        nodes_with_edge.add(edge[1])
    
    num_nodes = graph_test.number_of_nodes()
    
    test_edges = []
    test_edges_labels = []
    
    num_edge_sample = len(edge_list)
    non_edge_num = 0 
    # sample edges with label 0 (non-exist edges)
    
    while(non_edge_num < num_edge_sample):
        rand_nodes = tuple(np.random.randint(low=0,high=num_nodes, size=2))
        
        if rand_nodes not in edge_list:
            test_edges.append(rand_nodes)
            test_edges_labels.append(0)
            non_edge_num += 1
        
    for edge in edge_list:
        test_edges.append(edge)
        test_edges_labels.append(1)
    
    test_edges_features_mtx = generate_edge_features(test_edges, node_embeddings, edge_operator)
    
    return test_edges, test_edges_features_mtx, test_edges_labels

def build_clf(feature_mtx, response_vec):
   
    logistic_regression_model = LogisticRegression(random_state = 0,max_iter=5000,solver='liblinear',verbose=1,tol=1e-6)
    binary_clf = logistic_regression_model.fit(feature_mtx, response_vec)
    
    return binary_clf

def pred_links(feature_mtx, LR_clf):
    predict_edges_labels = LR_clf.predict(feature_mtx)
    
    return predict_edges_labels

def precision_recall(predict_labels, true_labels):
    true_positive  = false_positive = 0
    true_negative =  false_negative = 0
    
    for p_label, true_label in zip(predict_labels, true_labels):
        
        #print(p_label,true_label)
        if p_label == true_label and true_label == 1:
            true_positive += 1
        elif p_label == true_label and true_label == 0:
            true_negative += 1
        elif p_label != true_label and true_label == 1:
            false_negative += 1
        elif p_label != true_label and true_label == 0:
            false_positive += 1

    print("TP: ", true_positive)
    print("TN: ", true_negative)
    print("FP: ", false_positive)
    print("FN: ", false_negative)
    
    precision = recall = 0
    try:
        precision = true_positive / (true_positive + false_positive)
        recall = true_positive / (true_positive + false_negative)
        if (precision + recall) != 0.0:
            f1 = 2 * (precision * recall) / (precision + recall)
            print("F1: {}".format(f1))            
    except:
        print("F1: Divide-by-zero")
    
    cm = metrics.confusion_matrix(true_labels, predict_labels)
    print(cm)
    print(metrics.classification_report(true_labels, predict_labels))
    map = metrics.average_precision_score(true_labels, predict_labels)
    print('Mean Average Precision: {}'.format(map))
    fpr, tpr, thresholds = metrics.roc_curve(true_labels, predict_labels)
    roc_auc = metrics.auc(fpr, tpr)
    print('Area Under ROC Curve: {}'.format(roc_auc))
    
    return precision, recall

# %% [markdown]
# ### RM- Monthly
# ### load data

# %%
# load the training and testing graph
with open('../RM_monthly.pkl', 'rb') as file:
    graphs = pickle.load(file)
graph_train = graphs[-2]
graph_test = graphs[-1]

# parameters
num_edge_sample = 400

# %%
num_snapshots = len(graphs)
num_snapshots
# Out:
# 11

# %%
emb_list = []
for i in range(num_snapshots):
    file = '../RM_N2V_1_4_emb/rm-month/rm_month_' + str(i) + '.npy'
    node_embedding = np.load(file)
    emb_list.append(node_embedding)
print(len(emb_list))
# Out:
# 11

# %% [markdown]
# ### independent / no combination

# %%
node_embeddings_training = emb_list[-3]
node_embeddings_testing = emb_list[-2]

# %%
for edge_operator in ['Average','Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  0
# TN:  222
# FP:  0
# FN:  222
# F1: Divide-by-zero
# [[222   0]
#  [222   0]]
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67       222
#            1       0.00      0.00      0.00       222
#
#     accuracy                           0.50       444
#    macro avg       0.25      0.50      0.33       444
# weighted avg       0.25      0.50      0.33       444
#
# Mean Average Precision: 0.5
# Area Under ROC Curve: 0.5
# Precision:  0
# Recall:  0
# /usr/local/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [LibLinear]Edge Operator: Hadamard
# TP:  103
# TN:  222
# FP:  0
# FN:  119
# F1: 0.6338461538461538
# [[222   0]
#  [119 103]]
#               precision    recall  f1-score   support
#
#            0       0.65      1.00      0.79       222
#            1       1.00      0.46      0.63       222
#
#     accuracy                           0.73       444
#    macro avg       0.83      0.73      0.71       444
# weighted avg       0.83      0.73      0.71       444
#
# Mean Average Precision: 0.7319819819819819
# Area Under ROC Curve: 0.7319819819819819
# Precision:  1.0
# Recall:  0.46396396396396394
# [LibLinear]Edge Operator: Weighted-L1
# TP:  204
# TN:  203
# FP:  19
# FN:  18
# F1: 0.9168539325842698
# [[203  19]
#  [ 18 204]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.91      0.92       222
#            1       0.91      0.92      0.92       222
#
#     accuracy                           0.92       444
#    macro avg       0.92      0.92      0.92       444
# weighted avg       0.92      0.92      0.92       444
#
# Mean Average Precision: 0.8811659192825112
# Area Under ROC Curve: 0.9166666666666666
# Precision:  0.9147982062780269
# Recall:  0.918918918918919
# [LibLinear]Edge Operator: Weighted-L2
# TP:  129
# TN:  202
# FP:  20
# FN:  93
# F1: 0.6954177897574124
# [[202  20]
#  [ 93 129]]
#               precision    recall  f1-score   support
#
#            0       0.68      0.91      0.78       222
#            1       0.87      0.58      0.70       222
#
#     accuracy                           0.75       444
#    macro avg       0.78      0.75      0.74       444
# weighted avg       0.78      0.75      0.74       444
#
# Mean Average Precision: 0.7125430799927444
# Area Under ROC Curve: 0.7454954954954955
# Precision:  0.8657718120805369
# Recall:  0.581081081081081
# [LibLinear]Edge Operator: Concat
# TP:  0
# TN:  222
# FP:  0
# FN:  222
# F1: Divide-by-zero
# [[222   0]
#  [222   0]]
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67       222
#            1       0.00      0.00      0.00       222
#
#     accuracy                           0.50       444
#    macro avg       0.25      0.50      0.33       444
# weighted avg       0.25      0.50      0.33       444
#
# Mean Average Precision: 0.5
# Area Under ROC Curve: 0.5
# Precision:  0
# Recall:  0
# /usr/local/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### sum

# %%
for i in range(len(emb_list)):
    emb_list[i] = np.asfarray(emb_list[i],float)
node_embeddings_training = np.sum(np.asarray(emb_list[0:-2]),axis=0)
node_embeddings_testing = np.sum(np.asarray(emb_list[0:-1]),axis=0)

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  222
# TN:  217
# FP:  5
# FN:  0
# F1: 0.9888641425389755
# [[217   5]
#  [  0 222]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       222
#            1       0.98      1.00      0.99       222
#
#     accuracy                           0.99       444
#    macro avg       0.99      0.99      0.99       444
# weighted avg       0.99      0.99      0.99       444
#
# Mean Average Precision: 0.9779735682819384
# Area Under ROC Curve: 0.9887387387387387
# Precision:  0.9779735682819384
# Recall:  1.0
# [LibLinear]Edge Operator: Hadamard
# TP:  148
# TN:  203
# FP:  19
# FN:  74
# F1: 0.7609254498714653
# [[203  19]
#  [ 74 148]]
#               precision    recall  f1-score   support
#
#            0       0.73      0.91      0.81       222
#            1       0.89      0.67      0.76       222
#
#     accuracy                           0.79       444
#    macro avg       0.81      0.79      0.79       444
# weighted avg       0.81      0.79      0.79       444
#
# Mean Average Precision: 0.7574850299401197
# Area Under ROC Curve: 0.7905405405405405
# Precision:  0.8862275449101796
# Recall:  0.6666666666666666
# [LibLinear]Edge Operator: Weighted-L1
# TP:  174
# TN:  200
# FP:  22
# FN:  48
# F1: 0.8325358851674641
# [[200  22]
#  [ 48 174]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.90      0.85       222
#            1       0.89      0.78      0.83       222
#
#     accuracy                           0.84       444
#    macro avg       0.85      0.84      0.84       444
# weighted avg       0.85      0.84      0.84       444
#
# Mean Average Precision: 0.8039161610590182
# Area Under ROC Curve: 0.8423423423423423
# Precision:  0.8877551020408163
# Recall:  0.7837837837837838
# [LibLinear]Edge Operator: Weighted-L2
# TP:  166
# TN:  199
# FP:  23
# FN:  56
# F1: 0.8077858880778588
# [[199  23]
#  [ 56 166]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.90      0.83       222
#            1       0.88      0.75      0.81       222
#
#     accuracy                           0.82       444
#    macro avg       0.83      0.82      0.82       444
# weighted avg       0.83      0.82      0.82       444
#
# Mean Average Precision: 0.7828781162114495
# Area Under ROC Curve: 0.822072072072072
# Precision:  0.8783068783068783
# Recall:  0.7477477477477478
# [LibLinear]Edge Operator: Concat
# TP:  222
# TN:  218
# FP:  4
# FN:  0
# F1: 0.9910714285714286
# [[218   4]
#  [  0 222]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       222
#            1       0.98      1.00      0.99       222
#
#     accuracy                           0.99       444
#    macro avg       0.99      0.99      0.99       444
# weighted avg       0.99      0.99      0.99       444
#
# Mean Average Precision: 0.9823008849557522
# Area Under ROC Curve: 0.990990990990991
# Precision:  0.9823008849557522
# Recall:  1.0

# %% [markdown]
# ### expdecay

# %%
exps = [np.exp(-i * 0.5) for i in range(1,17)]
node_embeddings_training = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-2],exps[:-1]):
    node_embeddings_training += e * c

# %%
node_embeddings_testing = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-1],exps[:-1]):
    node_embeddings_testing += e * c

# %%
for edge_operator in [ 'Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  222
# TN:  208
# FP:  14
# FN:  0
# F1: 0.9694323144104803
# [[208  14]
#  [  0 222]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97       222
#            1       0.94      1.00      0.97       222
#
#     accuracy                           0.97       444
#    macro avg       0.97      0.97      0.97       444
# weighted avg       0.97      0.97      0.97       444
#
# Mean Average Precision: 0.940677966101695
# Area Under ROC Curve: 0.9684684684684685
# Precision:  0.940677966101695
# Recall:  1.0
# [LibLinear]Edge Operator: Hadamard
# TP:  93
# TN:  208
# FP:  14
# FN:  129
# F1: 0.5653495440729484
# [[208  14]
#  [129  93]]
#               precision    recall  f1-score   support
#
#            0       0.62      0.94      0.74       222
#            1       0.87      0.42      0.57       222
#
#     accuracy                           0.68       444
#    macro avg       0.74      0.68      0.65       444
# weighted avg       0.74      0.68      0.65       444
#
# Mean Average Precision: 0.6546476382924982
# Area Under ROC Curve: 0.6779279279279279
# Precision:  0.8691588785046729
# Recall:  0.4189189189189189
# [LibLinear]Edge Operator: Weighted-L1
# TP:  182
# TN:  208
# FP:  14
# FN:  40
# F1: 0.8708133971291867
# [[208  14]
#  [ 40 182]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.94      0.89       222
#            1       0.93      0.82      0.87       222
#
#     accuracy                           0.88       444
#    macro avg       0.88      0.88      0.88       444
# weighted avg       0.88      0.88      0.88       444
#
# Mean Average Precision: 0.8513513513513513
# Area Under ROC Curve: 0.8783783783783783
# Precision:  0.9285714285714286
# Recall:  0.8198198198198198
# [LibLinear]Edge Operator: Weighted-L2
# TP:  163
# TN:  200
# FP:  22
# FN:  59
# F1: 0.800982800982801
# [[200  22]
#  [ 59 163]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83       222
#            1       0.88      0.73      0.80       222
#
#     accuracy                           0.82       444
#    macro avg       0.83      0.82      0.82       444
# weighted avg       0.83      0.82      0.82       444
#
# Mean Average Precision: 0.7798027757487217
# Area Under ROC Curve: 0.8175675675675675
# Precision:  0.8810810810810811
# Recall:  0.7342342342342343
# [LibLinear]Edge Operator: Concat
# TP:  222
# TN:  207
# FP:  15
# FN:  0
# F1: 0.9673202614379084
# [[207  15]
#  [  0 222]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.93      0.97       222
#            1       0.94      1.00      0.97       222
#
#     accuracy                           0.97       444
#    macro avg       0.97      0.97      0.97       444
# weighted avg       0.97      0.97      0.97       444
#
# Mean Average Precision: 0.9367088607594937
# Area Under ROC Curve: 0.9662162162162162
# Precision:  0.9367088607594937
# Recall:  1.0

# %% [markdown]
# ### RM - Weekly
# ### load data

# %%
# load the training and testing graph
with open('../RM_weekly.pkl', 'rb') as file:
    graphs = pickle.load(file)
graph_train = graphs[-2]
graph_test = graphs[-1]

# parameters
num_edge_sample = 400

# %%
num_snapshots = len(graphs)
num_snapshots
# Out:
# 51

# %%
emb_list = []
for i in range(num_snapshots):
    file = '../RM_N2V_1_4_emb/rm-week/rm_week_' + str(i) + '.npy'
    node_embedding = np.load(file)
    emb_list.append(node_embedding)
print(len(emb_list))
# Out:
# 51

# %% [markdown]
# ### independent / no combination

# %%
node_embeddings_training = emb_list[-3]
node_embeddings_testing = emb_list[-2]

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  0
# TN:  14
# FP:  0
# FN:  14
# F1: Divide-by-zero
# [[14  0]
#  [14  0]]
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67        14
#            1       0.00      0.00      0.00        14
#
#     accuracy                           0.50        28
#    macro avg       0.25      0.50      0.33        28
# weighted avg       0.25      0.50      0.33        28
#
# Mean Average Precision: 0.5
# Area Under ROC Curve: 0.5
# Precision:  0
# Recall:  0
# [LibLinear]Edge Operator: Hadamard
# TP:  10
# TN:  14
# FP:  0
# FN:  4
# F1: 0.8333333333333333
# [[14  0]
#  [ 4 10]]
#               precision    recall  f1-score   support
#
#            0       0.78      1.00      0.88        14
#            1       1.00      0.71      0.83        14
#
#     accuracy                           0.86        28
#    macro avg       0.89      0.86      0.85        28
# weighted avg       0.89      0.86      0.85        28
#
# Mean Average Precision: 0.8571428571428572
# Area Under ROC Curve: 0.8571428571428572
# Precision:  1.0
# Recall:  0.7142857142857143
# /usr/local/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [LibLinear]Edge Operator: Weighted-L1
# TP:  4
# TN:  14
# FP:  0
# FN:  10
# F1: 0.4444444444444445
# [[14  0]
#  [10  4]]
#               precision    recall  f1-score   support
#
#            0       0.58      1.00      0.74        14
#            1       1.00      0.29      0.44        14
#
#     accuracy                           0.64        28
#    macro avg       0.79      0.64      0.59        28
# weighted avg       0.79      0.64      0.59        28
#
# Mean Average Precision: 0.6428571428571428
# Area Under ROC Curve: 0.6428571428571428
# Precision:  1.0
# Recall:  0.2857142857142857
# [LibLinear]Edge Operator: Weighted-L2
# TP:  4
# TN:  14
# FP:  0
# FN:  10
# F1: 0.4444444444444445
# [[14  0]
#  [10  4]]
#               precision    recall  f1-score   support
#
#            0       0.58      1.00      0.74        14
#            1       1.00      0.29      0.44        14
#
#     accuracy                           0.64        28
#    macro avg       0.79      0.64      0.59        28
# weighted avg       0.79      0.64      0.59        28
#
# Mean Average Precision: 0.6428571428571428
# Area Under ROC Curve: 0.6428571428571428
# Precision:  1.0
# Recall:  0.2857142857142857
# [LibLinear]Edge Operator: Concat
# TP:  0
# TN:  14
# FP:  0
# FN:  14
# F1: Divide-by-zero
# [[14  0]
#  [14  0]]
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67        14
#            1       0.00      0.00      0.00        14
#
#     accuracy                           0.50        28
#    macro avg       0.25      0.50      0.33        28
# weighted avg       0.25      0.50      0.33        28
#
# Mean Average Precision: 0.5
# Area Under ROC Curve: 0.5
# Precision:  0
# Recall:  0
# /usr/local/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### sum

# %%
for i in range(len(emb_list)):
    emb_list[i] = np.asfarray(emb_list[i],float)
node_embeddings_training = np.sum(np.asarray(emb_list[0:-2]),axis=0)
node_embeddings_testing = np.sum(np.asarray(emb_list[0:-1]),axis=0)

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  14
# TN:  14
# FP:  0
# FN:  0
# F1: 1.0
# [[14  0]
#  [ 0 14]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      1.00      1.00        14
#
#     accuracy                           1.00        28
#    macro avg       1.00      1.00      1.00        28
# weighted avg       1.00      1.00      1.00        28
#
# Mean Average Precision: 1.0
# Area Under ROC Curve: 1.0
# Precision:  1.0
# Recall:  1.0
# [LibLinear]Edge Operator: Hadamard
# TP:  8
# TN:  14
# FP:  0
# FN:  6
# F1: 0.7272727272727273
# [[14  0]
#  [ 6  8]]
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.82        14
#            1       1.00      0.57      0.73        14
#
#     accuracy                           0.79        28
#    macro avg       0.85      0.79      0.78        28
# weighted avg       0.85      0.79      0.78        28
#
# Mean Average Precision: 0.7857142857142857
# Area Under ROC Curve: 0.7857142857142857
# Precision:  1.0
# Recall:  0.5714285714285714
# [LibLinear]Edge Operator: Weighted-L1
# TP:  13
# TN:  14
# FP:  0
# FN:  1
# F1: 0.962962962962963
# [[14  0]
#  [ 1 13]]
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.97        14
#            1       1.00      0.93      0.96        14
#
#     accuracy                           0.96        28
#    macro avg       0.97      0.96      0.96        28
# weighted avg       0.97      0.96      0.96        28
#
# Mean Average Precision: 0.9642857142857143
# Area Under ROC Curve: 0.9642857142857143
# Precision:  1.0
# Recall:  0.9285714285714286
# [LibLinear]Edge Operator: Weighted-L2
# TP:  13
# TN:  14
# FP:  0
# FN:  1
# F1: 0.962962962962963
# [[14  0]
#  [ 1 13]]
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.97        14
#            1       1.00      0.93      0.96        14
#
#     accuracy                           0.96        28
#    macro avg       0.97      0.96      0.96        28
# weighted avg       0.97      0.96      0.96        28
#
# Mean Average Precision: 0.9642857142857143
# Area Under ROC Curve: 0.9642857142857143
# Precision:  1.0
# Recall:  0.9285714285714286
# [LibLinear]Edge Operator: Concat
# TP:  14
# TN:  14
# FP:  0
# FN:  0
# F1: 1.0
# [[14  0]
#  [ 0 14]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      1.00      1.00        14
#
#     accuracy                           1.00        28
#    macro avg       1.00      1.00      1.00        28
# weighted avg       1.00      1.00      1.00        28
#
# Mean Average Precision: 1.0
# Area Under ROC Curve: 1.0
# Precision:  1.0
# Recall:  1.0

# %% [markdown]
# ### expdecay

# %%
exps = [np.exp(-i * 0.3) for i in range(1,74)]
node_embeddings_training = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-2],exps[:-1]):
    node_embeddings_training += e * c 
node_embeddings_testing = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-1],exps[:-1]):
    node_embeddings_testing += e * c

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  14
# TN:  13
# FP:  1
# FN:  0
# F1: 0.9655172413793104
# [[13  1]
#  [ 0 14]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.93      0.96        14
#            1       0.93      1.00      0.97        14
#
#     accuracy                           0.96        28
#    macro avg       0.97      0.96      0.96        28
# weighted avg       0.97      0.96      0.96        28
#
# Mean Average Precision: 0.9333333333333333
# Area Under ROC Curve: 0.9642857142857143
# Precision:  0.9333333333333333
# Recall:  1.0
# [LibLinear]Edge Operator: Hadamard
# TP:  6
# TN:  14
# FP:  0
# FN:  8
# F1: 0.6
# [[14  0]
#  [ 8  6]]
#               precision    recall  f1-score   support
#
#            0       0.64      1.00      0.78        14
#            1       1.00      0.43      0.60        14
#
#     accuracy                           0.71        28
#    macro avg       0.82      0.71      0.69        28
# weighted avg       0.82      0.71      0.69        28
#
# Mean Average Precision: 0.7142857142857142
# Area Under ROC Curve: 0.7142857142857143
# Precision:  1.0
# Recall:  0.42857142857142855
# [LibLinear]Edge Operator: Weighted-L1
# TP:  10
# TN:  12
# FP:  2
# FN:  4
# F1: 0.7692307692307692
# [[12  2]
#  [ 4 10]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.86      0.80        14
#            1       0.83      0.71      0.77        14
#
#     accuracy                           0.79        28
#    macro avg       0.79      0.79      0.78        28
# weighted avg       0.79      0.79      0.78        28
#
# Mean Average Precision: 0.7380952380952381
# Area Under ROC Curve: 0.7857142857142858
# Precision:  0.8333333333333334
# Recall:  0.7142857142857143
# [LibLinear]Edge Operator: Weighted-L2
# TP:  8
# TN:  14
# FP:  0
# FN:  6
# F1: 0.7272727272727273
# [[14  0]
#  [ 6  8]]
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.82        14
#            1       1.00      0.57      0.73        14
#
#     accuracy                           0.79        28
#    macro avg       0.85      0.79      0.78        28
# weighted avg       0.85      0.79      0.78        28
#
# Mean Average Precision: 0.7857142857142857
# Area Under ROC Curve: 0.7857142857142857
# Precision:  1.0
# Recall:  0.5714285714285714
# [LibLinear]Edge Operator: Concat
# TP:  14
# TN:  14
# FP:  0
# FN:  0
# F1: 1.0
# [[14  0]
#  [ 0 14]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      1.00      1.00        14
#
#     accuracy                           1.00        28
#    macro avg       1.00      1.00      1.00        28
# weighted avg       1.00      1.00      1.00        28
#
# Mean Average Precision: 1.0
# Area Under ROC Curve: 1.0
# Precision:  1.0
# Recall:  1.0

# %% [markdown]
# # RM - Equal
# ### load data

# %%
# load the training and testing graph
with open('../RM_equaledge.pkl', 'rb') as file:
    graphs = pickle.load(file)
graph_train = graphs[-2]
graph_test = graphs[-1]

# parameters
num_edge_sample = 400

# %%
num_snapshots = len(graphs)
num_snapshots
# Out:
# 51

# %%
emb_list = []
for i in range(num_snapshots):
    file = '../RM_N2V_1_4_emb/rm-equal/msg_equal_' + str(i) + '.npy'
    node_embedding = np.load(file)
    emb_list.append(node_embedding)
print(len(emb_list))
# Out:
# 51

# %% [markdown]
# ### independent / no combination

# %%
node_embeddings_training = emb_list[-3]
node_embeddings_testing = emb_list[-2]

# %%
for edge_operator in ['Average','Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  127
# TN:  320
# FP:  2
# FN:  195
# F1: 0.5631929046563193
# [[320   2]
#  [195 127]]
#               precision    recall  f1-score   support
#
#            0       0.62      0.99      0.76       322
#            1       0.98      0.39      0.56       322
#
#     accuracy                           0.69       644
#    macro avg       0.80      0.69      0.66       644
# weighted avg       0.80      0.69      0.66       644
#
# Mean Average Precision: 0.6910900861861429
# Area Under ROC Curve: 0.6940993788819875
# Precision:  0.9844961240310077
# Recall:  0.3944099378881988
# [LibLinear]Edge Operator: Hadamard
# TP:  123
# TN:  320
# FP:  2
# FN:  199
# F1: 0.5503355704697986
# [[320   2]
#  [199 123]]
#               precision    recall  f1-score   support
#
#            0       0.62      0.99      0.76       322
#            1       0.98      0.38      0.55       322
#
#     accuracy                           0.69       644
#    macro avg       0.80      0.69      0.66       644
# weighted avg       0.80      0.69      0.66       644
#
# Mean Average Precision: 0.6848819875776397
# Area Under ROC Curve: 0.6878881987577641
# Precision:  0.984
# Recall:  0.38198757763975155
# [LibLinear]Edge Operator: Weighted-L1
# TP:  307
# TN:  296
# FP:  26
# FN:  15
# F1: 0.9374045801526717
# [[296  26]
#  [ 15 307]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.94       322
#            1       0.92      0.95      0.94       322
#
#     accuracy                           0.94       644
#    macro avg       0.94      0.94      0.94       644
# weighted avg       0.94      0.94      0.94       644
#
# Mean Average Precision: 0.9022671740063044
# Area Under ROC Curve: 0.936335403726708
# Precision:  0.9219219219219219
# Recall:  0.953416149068323
# [LibLinear]Edge Operator: Weighted-L2
# TP:  210
# TN:  300
# FP:  22
# FN:  112
# F1: 0.7581227436823105
# [[300  22]
#  [112 210]]
#               precision    recall  f1-score   support
#
#            0       0.73      0.93      0.82       322
#            1       0.91      0.65      0.76       322
#
#     accuracy                           0.79       644
#    macro avg       0.82      0.79      0.79       644
# weighted avg       0.82      0.79      0.79       644
#
# Mean Average Precision: 0.7642428785607196
# Area Under ROC Curve: 0.7919254658385093
# Precision:  0.9051724137931034
# Recall:  0.6521739130434783
# [LibLinear]Edge Operator: Concat
# TP:  104
# TN:  322
# FP:  0
# FN:  218
# F1: 0.48826291079812206
# [[322   0]
#  [218 104]]
#               precision    recall  f1-score   support
#
#            0       0.60      1.00      0.75       322
#            1       1.00      0.32      0.49       322
#
#     accuracy                           0.66       644
#    macro avg       0.80      0.66      0.62       644
# weighted avg       0.80      0.66      0.62       644
#
# Mean Average Precision: 0.6614906832298137
# Area Under ROC Curve: 0.6614906832298136
# Precision:  1.0
# Recall:  0.32298136645962733

# %% [markdown]
# ### sum

# %%
for i in range(len(emb_list)):
    emb_list[i] = np.asfarray(emb_list[i],float)
node_embeddings_training = np.sum(np.asarray(emb_list[0:-2]),axis=0)
node_embeddings_testing = np.sum(np.asarray(emb_list[0:-1]),axis=0)

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  321
# TN:  314
# FP:  8
# FN:  1
# F1: 0.9861751152073733
# [[314   8]
#  [  1 321]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       322
#            1       0.98      1.00      0.99       322
#
#     accuracy                           0.99       644
#    macro avg       0.99      0.99      0.99       644
# weighted avg       0.99      0.99      0.99       644
#
# Mean Average Precision: 0.9742066114142235
# Area Under ROC Curve: 0.9860248447204969
# Precision:  0.9756838905775076
# Recall:  0.9968944099378882
# [LibLinear]Edge Operator: Hadamard
# TP:  215
# TN:  293
# FP:  29
# FN:  107
# F1: 0.7597173144876324
# [[293  29]
#  [107 215]]
#               precision    recall  f1-score   support
#
#            0       0.73      0.91      0.81       322
#            1       0.88      0.67      0.76       322
#
#     accuracy                           0.79       644
#    macro avg       0.81      0.79      0.79       644
# weighted avg       0.81      0.79      0.79       644
#
# Mean Average Precision: 0.7544929233275633
# Area Under ROC Curve: 0.7888198757763975
# Precision:  0.8811475409836066
# Recall:  0.6677018633540373
# [LibLinear]Edge Operator: Weighted-L1
# TP:  295
# TN:  311
# FP:  11
# FN:  27
# F1: 0.9394904458598725
# [[311  11]
#  [ 27 295]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94       322
#            1       0.96      0.92      0.94       322
#
#     accuracy                           0.94       644
#    macro avg       0.94      0.94      0.94       644
# weighted avg       0.94      0.94      0.94       644
#
# Mean Average Precision: 0.9251410709211221
# Area Under ROC Curve: 0.9409937888198757
# Precision:  0.9640522875816994
# Recall:  0.9161490683229814
# [LibLinear]Edge Operator: Weighted-L2
# TP:  296
# TN:  308
# FP:  14
# FN:  26
# F1: 0.9367088607594936
# [[308  14]
#  [ 26 296]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94       322
#            1       0.95      0.92      0.94       322
#
#     accuracy                           0.94       644
#    macro avg       0.94      0.94      0.94       644
# weighted avg       0.94      0.94      0.94       644
#
# Mean Average Precision: 0.9181126026848326
# Area Under ROC Curve: 0.937888198757764
# Precision:  0.9548387096774194
# Recall:  0.9192546583850931
# [LibLinear]Edge Operator: Concat
# TP:  320
# TN:  317
# FP:  5
# FN:  2
# F1: 0.9891808346213292
# [[317   5]
#  [  2 320]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       322
#            1       0.98      0.99      0.99       322
#
#     accuracy                           0.99       644
#    macro avg       0.99      0.99      0.99       644
# weighted avg       0.99      0.99      0.99       644
#
# Mean Average Precision: 0.9816053511705687
# Area Under ROC Curve: 0.9891304347826088
# Precision:  0.9846153846153847
# Recall:  0.9937888198757764

# %% [markdown]
# ### expdecay

# %%
exps = [np.exp(-i * 0.3) for i in range(1,17)]
node_embeddings_training = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-2],exps[:-1]):
    node_embeddings_training += e * c 
node_embeddings_testing = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-1],exps[:-1]):
    node_embeddings_testing += e * c

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  319
# TN:  317
# FP:  5
# FN:  3
# F1: 0.9876160990712074
# [[317   5]
#  [  3 319]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       322
#            1       0.98      0.99      0.99       322
#
#     accuracy                           0.99       644
#    macro avg       0.99      0.99      0.99       644
# weighted avg       0.99      0.99      0.99       644
#
# Mean Average Precision: 0.9800532934590906
# Area Under ROC Curve: 0.9875776397515529
# Precision:  0.9845679012345679
# Recall:  0.9906832298136646
# [LibLinear]Edge Operator: Hadamard
# TP:  106
# TN:  318
# FP:  4
# FN:  216
# F1: 0.49074074074074076
# [[318   4]
#  [216 106]]
#               precision    recall  f1-score   support
#
#            0       0.60      0.99      0.74       322
#            1       0.96      0.33      0.49       322
#
#     accuracy                           0.66       644
#    macro avg       0.78      0.66      0.62       644
# weighted avg       0.78      0.66      0.62       644
#
# Mean Average Precision: 0.6526256352343309
# Area Under ROC Curve: 0.6583850931677019
# Precision:  0.9636363636363636
# Recall:  0.32919254658385094
# [LibLinear]Edge Operator: Weighted-L1
# TP:  309
# TN:  307
# FP:  15
# FN:  13
# F1: 0.9566563467492261
# [[307  15]
#  [ 13 309]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96       322
#            1       0.95      0.96      0.96       322
#
#     accuracy                           0.96       644
#    macro avg       0.96      0.96      0.96       644
# weighted avg       0.96      0.96      0.96       644
#
# Mean Average Precision: 0.9353864734299517
# Area Under ROC Curve: 0.9565217391304348
# Precision:  0.9537037037037037
# Recall:  0.9596273291925466
# [LibLinear]Edge Operator: Weighted-L2
# TP:  300
# TN:  307
# FP:  15
# FN:  22
# F1: 0.9419152276295133
# [[307  15]
#  [ 22 300]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94       322
#            1       0.95      0.93      0.94       322
#
#     accuracy                           0.94       644
#    macro avg       0.94      0.94      0.94       644
# weighted avg       0.94      0.94      0.94       644
#
# Mean Average Precision: 0.9214729370008873
# Area Under ROC Curve: 0.9425465838509316
# Precision:  0.9523809523809523
# Recall:  0.9316770186335404
# [LibLinear]Edge Operator: Concat
# TP:  322
# TN:  313
# FP:  9
# FN:  0
# F1: 0.9862174578866768
# [[313   9]
#  [  0 322]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99       322
#            1       0.97      1.00      0.99       322
#
#     accuracy                           0.99       644
#    macro avg       0.99      0.99      0.99       644
# weighted avg       0.99      0.99      0.99       644
#
# Mean Average Precision: 0.972809667673716
# Area Under ROC Curve: 0.9860248447204969
# Precision:  0.972809667673716
# Recall:  1.0

# %% [markdown]
# ### Email-EU - Equal Weekly
# ### load data

# %%
# load the training and testing graph
with open('../data/email_EU/email_equal_weekly_dir.pkl', 'rb') as file:
    graphs = pickle.load(file)
graph_train = graphs[-2]
graph_test = graphs[-1]

# parameters
num_edge_sample = 400

# %%
num_snapshots = len(graphs)
num_snapshots
# Out:
# 74

# %%
emb_list = []
for i in range(num_snapshots):
    file = '../data/email_EU/embeddings/em-email-equal-week-' + str(i) + '.npy'
    node_embedding = np.load(file)
    emb_list.append(node_embedding)
print(len(emb_list))
# Out:
# 74

# %%
node_embeddings_training = emb_list[-3]
node_embeddings_testing = emb_list[-2]

# %%
for edge_operator in ['Average','Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  242
# TN:  1948
# FP:  197
# FN:  1903
# F1: 0.1873065015479876
# [[1948  197]
#  [1903  242]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.91      0.65      2145
#            1       0.55      0.11      0.19      2145
#
#    micro avg       0.51      0.51      0.51      4290
#    macro avg       0.53      0.51      0.42      4290
# weighted avg       0.53      0.51      0.42      4290
#
# Mean Average Precision: 0.5057823725249693
# Area Under ROC Curve: 0.5104895104895105
# Precision:  0.55125284738041
# Recall:  0.11282051282051282
# [LibLinear]Edge Operator: Hadamard
# TP:  1673
# TN:  427
# FP:  1718
# FN:  472
# F1: 0.604407514450867
# [[ 427 1718]
#  [ 472 1673]]
#               precision    recall  f1-score   support
#
#            0       0.47      0.20      0.28      2145
#            1       0.49      0.78      0.60      2145
#
#    micro avg       0.49      0.49      0.49      4290
#    macro avg       0.48      0.49      0.44      4290
# weighted avg       0.48      0.49      0.44      4290
#
# Mean Average Precision: 0.49482484486907957
# Area Under ROC Curve: 0.48951048951048953
# Precision:  0.493364789147744
# Recall:  0.77995337995338
# [LibLinear]Edge Operator: Weighted-L1
# TP:  1154
# TN:  992
# FP:  1153
# FN:  991
# F1: 0.5184186882300089
# [[ 992 1153]
#  [ 991 1154]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.46      0.48      2145
#            1       0.50      0.54      0.52      2145
#
#    micro avg       0.50      0.50      0.50      4290
#    macro avg       0.50      0.50      0.50      4290
# weighted avg       0.50      0.50      0.50      4290
#
# Mean Average Precision: 0.5001166006367567
# Area Under ROC Curve: 0.5002331002331002
# Precision:  0.5002167316861725
# Recall:  0.5379953379953379
# [LibLinear]Edge Operator: Weighted-L2
# TP:  1175
# TN:  1016
# FP:  1129
# FN:  970
# F1: 0.5282085861991458
# [[1016 1129]
#  [ 970 1175]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.47      0.49      2145
#            1       0.51      0.55      0.53      2145
#
#    micro avg       0.51      0.51      0.51      4290
#    macro avg       0.51      0.51      0.51      4290
# weighted avg       0.51      0.51      0.51      4290
#
# Mean Average Precision: 0.5054683453120953
# Area Under ROC Curve: 0.5107226107226107
# Precision:  0.5099826388888888
# Recall:  0.5477855477855478
# [LibLinear]Edge Operator: Concat
# TP:  893
# TN:  1278
# FP:  867
# FN:  1252
# F1: 0.4573623559539053
# [[1278  867]
#  [1252  893]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.60      0.55      2145
#            1       0.51      0.42      0.46      2145
#
#    micro avg       0.51      0.51      0.51      4290
#    macro avg       0.51      0.51      0.50      4290
# weighted avg       0.51      0.51      0.50      4290
#
# Mean Average Precision: 0.5030750688705234
# Area Under ROC Curve: 0.5060606060606061
# Precision:  0.5073863636363637
# Recall:  0.41631701631701634

# %% [markdown]
# ### sum

# %%
for i in range(len(emb_list)):
    emb_list[i] = np.asfarray(emb_list[i],float)
node_embeddings_training = np.sum(np.asarray(emb_list[0:-2]),axis=0)
node_embeddings_testing = np.sum(np.asarray(emb_list[0:-1]),axis=0)

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  1281
# TN:  1369
# FP:  776
# FN:  864
# F1: 0.609709662065683
# [[1369  776]
#  [ 864 1281]]
#               precision    recall  f1-score   support
#
#            0       0.61      0.64      0.63      2145
#            1       0.62      0.60      0.61      2145
#
#    micro avg       0.62      0.62      0.62      4290
#    macro avg       0.62      0.62      0.62      4290
# weighted avg       0.62      0.62      0.62      4290
#
# Mean Average Precision: 0.5733075869196433
# Area Under ROC Curve: 0.6177156177156178
# Precision:  0.6227515799708313
# Recall:  0.5972027972027972
# [LibLinear]Edge Operator: Hadamard
# TP:  1237
# TN:  1017
# FP:  1128
# FN:  908
# F1: 0.5485587583148559
# [[1017 1128]
#  [ 908 1237]]
#               precision    recall  f1-score   support
#
#            0       0.53      0.47      0.50      2145
#            1       0.52      0.58      0.55      2145
#
#    micro avg       0.53      0.53      0.53      4290
#    macro avg       0.53      0.53      0.52      4290
# weighted avg       0.53      0.53      0.52      4290
#
# Mean Average Precision: 0.5132894730357733
# Area Under ROC Curve: 0.5254079254079254
# Precision:  0.5230443974630021
# Recall:  0.5766899766899767
# [LibLinear]Edge Operator: Weighted-L1
# TP:  1136
# TN:  1247
# FP:  898
# FN:  1009
# F1: 0.5436707346255085
# [[1247  898]
#  [1009 1136]]
#               precision    recall  f1-score   support
#
#            0       0.55      0.58      0.57      2145
#            1       0.56      0.53      0.54      2145
#
#    micro avg       0.56      0.56      0.56      4290
#    macro avg       0.56      0.56      0.56      4290
# weighted avg       0.56      0.56      0.56      4290
#
# Mean Average Precision: 0.5309846823121159
# Area Under ROC Curve: 0.5554778554778556
# Precision:  0.5585054080629301
# Recall:  0.5296037296037296
# [LibLinear]Edge Operator: Weighted-L2
# TP:  1253
# TN:  1155
# FP:  990
# FN:  892
# F1: 0.5711030082041932
# [[1155  990]
#  [ 892 1253]]
#               precision    recall  f1-score   support
#
#            0       0.56      0.54      0.55      2145
#            1       0.56      0.58      0.57      2145
#
#    micro avg       0.56      0.56      0.56      4290
#    macro avg       0.56      0.56      0.56      4290
# weighted avg       0.56      0.56      0.56      4290
#
# Mean Average Precision: 0.5342468202031287
# Area Under ROC Curve: 0.5613053613053613
# Precision:  0.5586268390548372
# Recall:  0.5841491841491842
# [LibLinear]Edge Operator: Concat
# TP:  1261
# TN:  1259
# FP:  886
# FN:  884
# F1: 0.587604846225536
# [[1259  886]
#  [ 884 1261]]
#               precision    recall  f1-score   support
#
#            0       0.59      0.59      0.59      2145
#            1       0.59      0.59      0.59      2145
#
#    micro avg       0.59      0.59      0.59      4290
#    macro avg       0.59      0.59      0.59      4290
# weighted avg       0.59      0.59      0.59      4290
#
# Mean Average Precision: 0.5513401363424653
# Area Under ROC Curve: 0.5874125874125874
# Precision:  0.5873311597578016
# Recall:  0.5878787878787879

# %% [markdown]
# ### expdecay

# %%
exps = [np.exp(-i * 0.3) for i in range(1,28)]
node_embeddings_training = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-2],exps[:-1]):
    node_embeddings_training += e * c 
node_embeddings_testing = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-1],exps[:-1]):
    node_embeddings_testing += e * c

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  1306
# TN:  1276
# FP:  869
# FN:  839
# F1: 0.6046296296296296
# [[1276  869]
#  [ 839 1306]]
#               precision    recall  f1-score   support
#
#            0       0.60      0.59      0.60      2145
#            1       0.60      0.61      0.60      2145
#
#    micro avg       0.60      0.60      0.60      4290
#    macro avg       0.60      0.60      0.60      4290
# weighted avg       0.60      0.60      0.60      4290
#
# Mean Average Precision: 0.5611657155105432
# Area Under ROC Curve: 0.6018648018648018
# Precision:  0.6004597701149426
# Recall:  0.6088578088578088
# [LibLinear]Edge Operator: Hadamard
# TP:  1529
# TN:  696
# FP:  1449
# FN:  616
# F1: 0.5969158696076519
# [[ 696 1449]
#  [ 616 1529]]
#               precision    recall  f1-score   support
#
#            0       0.53      0.32      0.40      2145
#            1       0.51      0.71      0.60      2145
#
#    micro avg       0.52      0.52      0.52      4290
#    macro avg       0.52      0.52      0.50      4290
# weighted avg       0.52      0.52      0.50      4290
#
# Mean Average Precision: 0.5095744864045737
# Area Under ROC Curve: 0.5186480186480187
# Precision:  0.5134318334452653
# Recall:  0.7128205128205128
# [LibLinear]Edge Operator: Weighted-L1
# TP:  1092
# TN:  1305
# FP:  840
# FN:  1053
# F1: 0.5356880058866813
# [[1305  840]
#  [1053 1092]]
#               precision    recall  f1-score   support
#
#            0       0.55      0.61      0.58      2145
#            1       0.57      0.51      0.54      2145
#
#    micro avg       0.56      0.56      0.56      4290
#    macro avg       0.56      0.56      0.56      4290
# weighted avg       0.56      0.56      0.56      4290
#
# Mean Average Precision: 0.533201581027668
# Area Under ROC Curve: 0.5587412587412587
# Precision:  0.5652173913043478
# Recall:  0.509090909090909
# [LibLinear]Edge Operator: Weighted-L2
# TP:  1348
# TN:  1133
# FP:  1012
# FN:  797
# F1: 0.5984461709211987
# [[1133 1012]
#  [ 797 1348]]
#               precision    recall  f1-score   support
#
#            0       0.59      0.53      0.56      2145
#            1       0.57      0.63      0.60      2145
#
#    micro avg       0.58      0.58      0.58      4290
#    macro avg       0.58      0.58      0.58      4290
# weighted avg       0.58      0.58      0.58      4290
#
# Mean Average Precision: 0.5447362806684841
# Area Under ROC Curve: 0.5783216783216782
# Precision:  0.5711864406779661
# Recall:  0.6284382284382284
# [LibLinear]Edge Operator: Concat
# TP:  1233
# TN:  1351
# FP:  794
# FN:  912
# F1: 0.5910834132310643
# [[1351  794]
#  [ 912 1233]]
#               precision    recall  f1-score   support
#
#            0       0.60      0.63      0.61      2145
#            1       0.61      0.57      0.59      2145
#
#    micro avg       0.60      0.60      0.60      4290
#    macro avg       0.60      0.60      0.60      4290
# weighted avg       0.60      0.60      0.60      4290
#
# Mean Average Precision: 0.5622467320543295
# Area Under ROC Curve: 0.6023310023310023
# Precision:  0.6082881105081401
# Recall:  0.5748251748251748
