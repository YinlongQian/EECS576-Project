# %%
import random

from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
import pickle
import sklearn.metrics as metrics

# %% [markdown]
# ### functions

# %%
def edge_features(node_emb_1, node_emb_2, operator):
    node_emb_1 = np.asfarray(node_emb_1,float)
    node_emb_2 = np.asfarray(node_emb_2, float)
    # combine two nodes' embeddings with specificed operator
    if operator == 'Average':
        edge = [((x + y) / 2.0) for x,y in zip(node_emb_1, node_emb_2)]
    elif operator == 'Hadamard':
        edge = [(x * y) for x,y in zip(node_emb_1, node_emb_2)]
    elif operator == 'Weighted-L1':
        edge = [abs(x - y) for x,y in zip(node_emb_1, node_emb_2)]
    elif operator == 'Weighted-L2':
        edge = [abs(x - y)**2 for x,y in zip(node_emb_1, node_emb_2)]
    elif operator == 'Concat':
        edge = np.concatenate((node_emb_1, node_emb_2), axis=None) 
    else:
        print("Generate edge features: Operator not supported")
        print("Use default operator: Weighted-L1")
        edge = [abs(x - y) for x,y in zip(node_emb_1, node_emb_2)]
        
    return edge
def generate_edge_features(edge_list, node_embeddings, operator):
    edge_features_mtx = []
    
    # generate features for each edge in the list
    for node_index_1, node_index_2 in edge_list:
        node_emb_1 = node_embeddings[node_index_1-1]
        node_emb_2 = node_embeddings[node_index_2-1]
        
        edge_features_mtx.append(edge_features(node_emb_1, node_emb_2, operator))
        
    return edge_features_mtx

def generate_train_set(graph_train, num_edge_sample, node_embeddings, edge_operator,):
    edge_list = list(graph_train.edges)
    num_nodes = graph_train.number_of_nodes()
    
    train_edges = []
    train_edges_labels = [1] * num_edge_sample + [0] * num_edge_sample
    
    random.seed(0)
    
    # sample edges with label 1 (true edges)
    for edge_num in range(num_edge_sample):
        rand_index = random.randint(0, len(edge_list) - 1)
        
        #train_edges.append(tuple(edge_list[rand_index]))
        train_edges.append(edge_list[rand_index])
    non_edge_num = 0
    
    # sample edges with label 0 (non-exist edges)
    while(non_edge_num < num_edge_sample):
        rand_nodes = tuple(np.random.randint(low=0,high=num_nodes, size=2))
        
        if rand_nodes not in edge_list:
            train_edges.append(rand_nodes)
            non_edge_num += 1

    train_edges_features_mtx = generate_edge_features(train_edges, node_embeddings, edge_operator)
            
    return train_edges, train_edges_features_mtx, train_edges_labels

def generate_test_set(graph_test, node_embeddings, edge_operator):
    edge_list = graph_test.edges
    nodes_with_edge = set()
    
    for edge in edge_list:
        nodes_with_edge.add(edge[0])
        nodes_with_edge.add(edge[1])
    
    num_nodes = graph_test.number_of_nodes()
    
    test_edges = []
    test_edges_labels = []
    
    num_edge_sample = len(edge_list)
    non_edge_num = 0 
    # sample edges with label 0 (non-exist edges)
    
    while(non_edge_num < num_edge_sample):
        rand_nodes = tuple(np.random.randint(low=0,high=num_nodes, size=2))
        
        if rand_nodes not in edge_list:
            test_edges.append(rand_nodes)
            test_edges_labels.append(0)
            non_edge_num += 1
        
    for edge in edge_list:
        test_edges.append(edge)
        test_edges_labels.append(1)
    
    test_edges_features_mtx = generate_edge_features(test_edges, node_embeddings, edge_operator)
    
    return test_edges, test_edges_features_mtx, test_edges_labels

def build_clf(feature_mtx, response_vec):
   
    logistic_regression_model = LogisticRegression(random_state = 0,max_iter=5000,solver='liblinear',verbose=1,tol=1e-6)
    binary_clf = logistic_regression_model.fit(feature_mtx, response_vec)
    
    return binary_clf

def pred_links(feature_mtx, LR_clf):
    predict_edges_labels = LR_clf.predict(feature_mtx)
    
    return predict_edges_labels

def precision_recall(predict_labels, true_labels):
    true_positive  = false_positive = 0
    true_negative =  false_negative = 0
    
    for p_label, true_label in zip(predict_labels, true_labels):
        
        #print(p_label,true_label)
        if p_label == true_label and true_label == 1:
            true_positive += 1
        elif p_label == true_label and true_label == 0:
            true_negative += 1
        elif p_label != true_label and true_label == 1:
            false_negative += 1
        elif p_label != true_label and true_label == 0:
            false_positive += 1

    print("TP: ", true_positive)
    print("TN: ", true_negative)
    print("FP: ", false_positive)
    print("FN: ", false_negative)
    
    precision = recall = 0
    try:
        precision = true_positive / (true_positive + false_positive)
        recall = true_positive / (true_positive + false_negative)
        if (precision + recall) != 0.0:
            f1 = 2 * (precision * recall) / (precision + recall)
            print("F1: {}".format(f1))            
    except:
        print("F1: Divide-by-zero")
    
    cm = metrics.confusion_matrix(true_labels, predict_labels)
    print(cm)
    print(metrics.classification_report(true_labels, predict_labels))
    map = metrics.average_precision_score(true_labels, predict_labels)
    print('Mean Average Precision: {}'.format(map))
    fpr, tpr, thresholds = metrics.roc_curve(true_labels, predict_labels)
    roc_auc = metrics.auc(fpr, tpr)
    print('Area Under ROC Curve: {}'.format(roc_auc))
    
    return precision, recall

# %% [markdown]
# ### RM - Monthly
# ### load data

# %%
# load the training and testing graph
with open('../RM_monthly.pkl', 'rb') as file:
    graphs = pickle.load(file)
graph_train = graphs[-2]
graph_test = graphs[-1]

# parameters
num_edge_sample = 400

# %%
num_snapshots = len(graphs)
num_snapshots
# Out:
# 11

# %%
emb_list = []
for i in range(num_snapshots):
    file = '../RM_emb/em-vc-month/em-vc-month-' + str(i) + '.npy'
    node_embedding = np.load(file)
    emb_list.append(node_embedding)
print(len(emb_list))
# Out:
# 11

# %% [markdown]
# ### independent / no combination

# %%
node_embeddings_training = emb_list[-3]
node_embeddings_testing = emb_list[-2]

# %%
for edge_operator in ['Average','Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  4
# TN:  221
# FP:  1
# FN:  218
# F1: 0.035242290748898675
# [[221   1]
#  [218   4]]
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67       222
#            1       0.80      0.02      0.04       222
#
#     accuracy                           0.51       444
#    macro avg       0.65      0.51      0.35       444
# weighted avg       0.65      0.51      0.35       444
#
# Mean Average Precision: 0.5054054054054054
# Area Under ROC Curve: 0.5067567567567568
# Precision:  0.8
# Recall:  0.018018018018018018
# [LibLinear]Edge Operator: Hadamard
# TP:  17
# TN:  218
# FP:  4
# FN:  205
# F1: 0.13991769547325103
# [[218   4]
#  [205  17]]
#               precision    recall  f1-score   support
#
#            0       0.52      0.98      0.68       222
#            1       0.81      0.08      0.14       222
#
#     accuracy                           0.53       444
#    macro avg       0.66      0.53      0.41       444
# weighted avg       0.66      0.53      0.41       444
#
# Mean Average Precision: 0.5237022737022737
# Area Under ROC Curve: 0.5292792792792792
# Precision:  0.8095238095238095
# Recall:  0.07657657657657657
# [LibLinear]Edge Operator: Weighted-L1
# TP:  11
# TN:  210
# FP:  12
# FN:  211
# F1: 0.08979591836734693
# [[210  12]
#  [211  11]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.95      0.65       222
#            1       0.48      0.05      0.09       222
#
#     accuracy                           0.50       444
#    macro avg       0.49      0.50      0.37       444
# weighted avg       0.49      0.50      0.37       444
#
# Mean Average Precision: 0.4989228358793576
# Area Under ROC Curve: 0.4977477477477477
# Precision:  0.4782608695652174
# Recall:  0.04954954954954955
# [LibLinear]Edge Operator: Weighted-L2
# TP:  3
# TN:  222
# FP:  0
# FN:  219
# F1: 0.026666666666666665
# [[222   0]
#  [219   3]]
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67       222
#            1       1.00      0.01      0.03       222
#
#     accuracy                           0.51       444
#    macro avg       0.75      0.51      0.35       444
# weighted avg       0.75      0.51      0.35       444
#
# Mean Average Precision: 0.5067567567567568
# Area Under ROC Curve: 0.5067567567567568
# Precision:  1.0
# Recall:  0.013513513513513514
# [LibLinear]Edge Operator: Concat
# TP:  1
# TN:  222
# FP:  0
# FN:  221
# F1: 0.008968609865470852
# [[222   0]
#  [221   1]]
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67       222
#            1       1.00      0.00      0.01       222
#
#     accuracy                           0.50       444
#    macro avg       0.75      0.50      0.34       444
# weighted avg       0.75      0.50      0.34       444
#
# Mean Average Precision: 0.5022522522522522
# Area Under ROC Curve: 0.5022522522522522
# Precision:  1.0
# Recall:  0.0045045045045045045

# %% [markdown]
# ### sum

# %%
for i in range(len(emb_list)):
    emb_list[i] = np.asfarray(emb_list[i],float)
node_embeddings_training = np.sum(np.asarray(emb_list[0:-2]),axis=0)
node_embeddings_testing = np.sum(np.asarray(emb_list[0:-1]),axis=0)

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  204
# TN:  218
# FP:  4
# FN:  18
# F1: 0.9488372093023255
# [[218   4]
#  [ 18 204]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95       222
#            1       0.98      0.92      0.95       222
#
#     accuracy                           0.95       444
#    macro avg       0.95      0.95      0.95       444
# weighted avg       0.95      0.95      0.95       444
#
# Mean Average Precision: 0.9417879417879418
# Area Under ROC Curve: 0.9504504504504504
# Precision:  0.9807692307692307
# Recall:  0.918918918918919
# [LibLinear]Edge Operator: Hadamard
# TP:  100
# TN:  177
# FP:  45
# FN:  122
# F1: 0.5449591280653951
# [[177  45]
#  [122 100]]
#               precision    recall  f1-score   support
#
#            0       0.59      0.80      0.68       222
#            1       0.69      0.45      0.54       222
#
#     accuracy                           0.62       444
#    macro avg       0.64      0.62      0.61       444
# weighted avg       0.64      0.62      0.61       444
#
# Mean Average Precision: 0.5854302578440509
# Area Under ROC Curve: 0.6238738738738738
# Precision:  0.6896551724137931
# Recall:  0.45045045045045046
# [LibLinear]Edge Operator: Weighted-L1
# TP:  183
# TN:  209
# FP:  13
# FN:  39
# F1: 0.8755980861244019
# [[209  13]
#  [ 39 183]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.94      0.89       222
#            1       0.93      0.82      0.88       222
#
#     accuracy                           0.88       444
#    macro avg       0.89      0.88      0.88       444
# weighted avg       0.89      0.88      0.88       444
#
# Mean Average Precision: 0.8574875896304468
# Area Under ROC Curve: 0.882882882882883
# Precision:  0.9336734693877551
# Recall:  0.8243243243243243
# [LibLinear]Edge Operator: Weighted-L2
# TP:  146
# TN:  221
# FP:  1
# FN:  76
# F1: 0.7913279132791328
# [[221   1]
#  [ 76 146]]
#               precision    recall  f1-score   support
#
#            0       0.74      1.00      0.85       222
#            1       0.99      0.66      0.79       222
#
#     accuracy                           0.83       444
#    macro avg       0.87      0.83      0.82       444
# weighted avg       0.87      0.83      0.82       444
#
# Mean Average Precision: 0.82435496721211
# Area Under ROC Curve: 0.8265765765765767
# Precision:  0.9931972789115646
# Recall:  0.6576576576576577
# [LibLinear]Edge Operator: Concat
# TP:  221
# TN:  218
# FP:  4
# FN:  1
# F1: 0.988814317673378
# [[218   4]
#  [  1 221]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       222
#            1       0.98      1.00      0.99       222
#
#     accuracy                           0.99       444
#    macro avg       0.99      0.99      0.99       444
# weighted avg       0.99      0.99      0.99       444
#
# Mean Average Precision: 0.9800500500500501
# Area Under ROC Curve: 0.9887387387387386
# Precision:  0.9822222222222222
# Recall:  0.9954954954954955

# %% [markdown]
# ### expdecay

# %%
exps = [np.exp(-i * 0.9) for i in range(1,17)]
node_embeddings_training = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-2],exps[:-1]):
    node_embeddings_training += e * c

# %%
node_embeddings_testing = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-1],exps[:-1]):
    node_embeddings_testing += e * c

# %%
for edge_operator in [ 'Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  119
# TN:  219
# FP:  3
# FN:  103
# F1: 0.6918604651162791
# [[219   3]
#  [103 119]]
#               precision    recall  f1-score   support
#
#            0       0.68      0.99      0.81       222
#            1       0.98      0.54      0.69       222
#
#     accuracy                           0.76       444
#    macro avg       0.83      0.76      0.75       444
# weighted avg       0.83      0.76      0.75       444
#
# Mean Average Precision: 0.7548368040171318
# Area Under ROC Curve: 0.7612612612612614
# Precision:  0.9754098360655737
# Recall:  0.536036036036036
# [LibLinear]Edge Operator: Hadamard
# TP:  61
# TN:  212
# FP:  10
# FN:  161
# F1: 0.416382252559727
# [[212  10]
#  [161  61]]
#               precision    recall  f1-score   support
#
#            0       0.57      0.95      0.71       222
#            1       0.86      0.27      0.42       222
#
#     accuracy                           0.61       444
#    macro avg       0.71      0.61      0.56       444
# weighted avg       0.71      0.61      0.56       444
#
# Mean Average Precision: 0.5986867148838979
# Area Under ROC Curve: 0.6148648648648649
# Precision:  0.8591549295774648
# Recall:  0.2747747747747748
# [LibLinear]Edge Operator: Weighted-L1
# TP:  118
# TN:  222
# FP:  0
# FN:  104
# F1: 0.6941176470588236
# [[222   0]
#  [104 118]]
#               precision    recall  f1-score   support
#
#            0       0.68      1.00      0.81       222
#            1       1.00      0.53      0.69       222
#
#     accuracy                           0.77       444
#    macro avg       0.84      0.77      0.75       444
# weighted avg       0.84      0.77      0.75       444
#
# Mean Average Precision: 0.7657657657657657
# Area Under ROC Curve: 0.7657657657657657
# Precision:  1.0
# Recall:  0.5315315315315315
# [LibLinear]Edge Operator: Weighted-L2
# TP:  116
# TN:  220
# FP:  2
# FN:  106
# F1: 0.6823529411764706
# [[220   2]
#  [106 116]]
#               precision    recall  f1-score   support
#
#            0       0.67      0.99      0.80       222
#            1       0.98      0.52      0.68       222
#
#     accuracy                           0.76       444
#    macro avg       0.83      0.76      0.74       444
# weighted avg       0.83      0.76      0.74       444
#
# Mean Average Precision: 0.7524049473202016
# Area Under ROC Curve: 0.7567567567567567
# Precision:  0.9830508474576272
# Recall:  0.5225225225225225
# [LibLinear]Edge Operator: Concat
# TP:  148
# TN:  221
# FP:  1
# FN:  74
# F1: 0.7978436657681941
# [[221   1]
#  [ 74 148]]
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.85       222
#            1       0.99      0.67      0.80       222
#
#     accuracy                           0.83       444
#    macro avg       0.87      0.83      0.83       444
# weighted avg       0.87      0.83      0.83       444
#
# Mean Average Precision: 0.8288590604026846
# Area Under ROC Curve: 0.831081081081081
# Precision:  0.9932885906040269
# Recall:  0.6666666666666666

# %% [markdown]
# ### RM - Weekly
# ### load data

# %%
# load the training and testing graph
with open('../.pkl', 'rb') as file:
    graphs = pickle.load(file)
graph_train = graphs[-2]
graph_test = graphs[-1]

# parameters
num_edge_sample = 400

# %%
num_snapshots = len(graphs)
num_snapshots
# Out:
# 74

# %%
emb_list = []
for i in range(num_snapshots):
    file = '../data/email_EU/embeddings/em-email-week-' + str(i) + '.npy'
    node_embedding = np.load(file)
    emb_list.append(node_embedding)
print(len(emb_list))
# Out:
# 74

# %% [markdown]
# ### independent / no combination

# %%
node_embeddings_training = emb_list[-3]
node_embeddings_testing = emb_list[-2]

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  758
# TN:  1905
# FP:  780
# FN:  1927
# F1: 0.35898650248638403
# [[1905  780]
#  [1927  758]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.71      0.58      2685
#            1       0.49      0.28      0.36      2685
#
#    micro avg       0.50      0.50      0.50      5370
#    macro avg       0.49      0.50      0.47      5370
# weighted avg       0.49      0.50      0.47      5370
#
# Mean Average Precision: 0.49798088402312124
# Area Under ROC Curve: 0.4959031657355679
# Precision:  0.4928478543563069
# Recall:  0.2823091247672253
# [LibLinear]Edge Operator: Hadamard
# TP:  1765
# TN:  1024
# FP:  1661
# FN:  920
# F1: 0.5776468663066602
# [[1024 1661]
#  [ 920 1765]]
#               precision    recall  f1-score   support
#
#            0       0.53      0.38      0.44      2685
#            1       0.52      0.66      0.58      2685
#
#    micro avg       0.52      0.52      0.52      5370
#    macro avg       0.52      0.52      0.51      5370
# weighted avg       0.52      0.52      0.51      5370
#
# Mean Average Precision: 0.5099773775086125
# Area Under ROC Curve: 0.5193668528864059
# Precision:  0.51517805020432
# Recall:  0.6573556797020484
# [LibLinear]Edge Operator: Weighted-L1
# TP:  1603
# TN:  1107
# FP:  1578
# FN:  1082
# F1: 0.5465393794749404
# [[1107 1578]
#  [1082 1603]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.41      0.45      2685
#            1       0.50      0.60      0.55      2685
#
#    micro avg       0.50      0.50      0.50      5370
#    macro avg       0.50      0.50      0.50      5370
# weighted avg       0.50      0.50      0.50      5370
#
# Mean Average Precision: 0.5023460408840432
# Area Under ROC Curve: 0.5046554934823091
# Precision:  0.5039295818924866
# Recall:  0.5970204841713221
# [LibLinear]Edge Operator: Weighted-L2
# TP:  1242
# TN:  1496
# FP:  1189
# FN:  1443
# F1: 0.48553557466770925
# [[1496 1189]
#  [1443 1242]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.56      0.53      2685
#            1       0.51      0.46      0.49      2685
#
#    micro avg       0.51      0.51      0.51      5370
#    macro avg       0.51      0.51      0.51      5370
# weighted avg       0.51      0.51      0.51      5370
#
# Mean Average Precision: 0.5050424107604522
# Area Under ROC Curve: 0.5098696461824954
# Precision:  0.5109008638420404
# Recall:  0.46256983240223465
# [LibLinear]Edge Operator: Concat
# TP:  1219
# TN:  1466
# FP:  1219
# FN:  1466
# F1: 0.4758930314268983
# [[1466 1219]
#  [1466 1219]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.55      0.52      2685
#            1       0.50      0.45      0.48      2685
#
#    micro avg       0.50      0.50      0.50      5370
#    macro avg       0.50      0.50      0.50      5370
# weighted avg       0.50      0.50      0.50      5370
#
# Mean Average Precision: 0.5
# Area Under ROC Curve: 0.5
# Precision:  0.5
# Recall:  0.45400372439478587

# %% [markdown]
# ### sum

# %%
for i in range(len(emb_list)):
    emb_list[i] = np.asfarray(emb_list[i],float)
node_embeddings_training = np.sum(np.asarray(emb_list[0:-2]),axis=0)
node_embeddings_testing = np.sum(np.asarray(emb_list[0:-1]),axis=0)

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  1672
# TN:  1563
# FP:  1122
# FN:  1013
# F1: 0.610330352254061
# [[1563 1122]
#  [1013 1672]]
#               precision    recall  f1-score   support
#
#            0       0.61      0.58      0.59      2685
#            1       0.60      0.62      0.61      2685
#
#    micro avg       0.60      0.60      0.60      5370
#    macro avg       0.60      0.60      0.60      5370
# weighted avg       0.60      0.60      0.60      5370
#
# Mean Average Precision: 0.5612912212789044
# Area Under ROC Curve: 0.6024208566108008
# Precision:  0.5984251968503937
# Recall:  0.6227188081936685
# [LibLinear]Edge Operator: Hadamard
# TP:  1382
# TN:  1425
# FP:  1260
# FN:  1303
# F1: 0.5188661535573493
# [[1425 1260]
#  [1303 1382]]
#               precision    recall  f1-score   support
#
#            0       0.52      0.53      0.53      2685
#            1       0.52      0.51      0.52      2685
#
#    micro avg       0.52      0.52      0.52      5370
#    macro avg       0.52      0.52      0.52      5370
# weighted avg       0.52      0.52      0.52      5370
#
# Mean Average Precision: 0.5118839488734481
# Area Under ROC Curve: 0.5227188081936686
# Precision:  0.5230885692657078
# Recall:  0.5147113594040968
# [LibLinear]Edge Operator: Weighted-L1
# TP:  1476
# TN:  1480
# FP:  1205
# FN:  1209
# F1: 0.5501304509877003
# [[1480 1205]
#  [1209 1476]]
#               precision    recall  f1-score   support
#
#            0       0.55      0.55      0.55      2685
#            1       0.55      0.55      0.55      2685
#
#    micro avg       0.55      0.55      0.55      5370
#    macro avg       0.55      0.55      0.55      5370
# weighted avg       0.55      0.55      0.55      5370
#
# Mean Average Precision: 0.5277833460790708
# Area Under ROC Curve: 0.5504655493482309
# Precision:  0.5505408429690414
# Recall:  0.5497206703910614
# [LibLinear]Edge Operator: Weighted-L2
# TP:  1564
# TN:  1426
# FP:  1259
# FN:  1121
# F1: 0.5679012345679013
# [[1426 1259]
#  [1121 1564]]
#               precision    recall  f1-score   support
#
#            0       0.56      0.53      0.55      2685
#            1       0.55      0.58      0.57      2685
#
#    micro avg       0.56      0.56      0.56      5370
#    macro avg       0.56      0.56      0.56      5370
# weighted avg       0.56      0.56      0.56      5370
#
# Mean Average Precision: 0.5314667162724918
# Area Under ROC Curve: 0.5567970204841713
# Precision:  0.5540205455189515
# Recall:  0.5824953445065177
# [LibLinear]Edge Operator: Concat
# TP:  1493
# TN:  1559
# FP:  1126
# FN:  1192
# F1: 0.5629713423831072
# [[1559 1126]
#  [1192 1493]]
#               precision    recall  f1-score   support
#
#            0       0.57      0.58      0.57      2685
#            1       0.57      0.56      0.56      2685
#
#    micro avg       0.57      0.57      0.57      5370
#    macro avg       0.57      0.57      0.57      5370
# weighted avg       0.57      0.57      0.57      5370
#
# Mean Average Precision: 0.53895974340214
# Area Under ROC Curve: 0.568342644320298
# Precision:  0.5700649102710958
# Recall:  0.5560521415270019

# %% [markdown]
# ### expdecay

# %%
exps = [np.exp(-i * 0.3) for i in range(1,74)]
node_embeddings_training = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-2],exps[:-1]):
    node_embeddings_training += e * c 
node_embeddings_testing = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-1],exps[:-1]):
    node_embeddings_testing += e * c

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  1378
# TN:  1756
# FP:  929
# FN:  1307
# F1: 0.5520833333333333
# [[1756  929]
#  [1307 1378]]
#               precision    recall  f1-score   support
#
#            0       0.57      0.65      0.61      2685
#            1       0.60      0.51      0.55      2685
#
#    micro avg       0.58      0.58      0.58      5370
#    macro avg       0.59      0.58      0.58      5370
# weighted avg       0.59      0.58      0.58      5370
#
# Mean Average Precision: 0.5499428909988949
# Area Under ROC Curve: 0.5836126629422719
# Precision:  0.5973125270914608
# Recall:  0.5132216014897579
# [LibLinear]Edge Operator: Hadamard
# TP:  1947
# TN:  878
# FP:  1807
# FN:  738
# F1: 0.604752290728374
# [[ 878 1807]
#  [ 738 1947]]
#               precision    recall  f1-score   support
#
#            0       0.54      0.33      0.41      2685
#            1       0.52      0.73      0.60      2685
#
#    micro avg       0.53      0.53      0.53      5370
#    macro avg       0.53      0.53      0.51      5370
# weighted avg       0.53      0.53      0.51      5370
#
# Mean Average Precision: 0.5135215174577286
# Area Under ROC Curve: 0.5260707635009311
# Precision:  0.5186467767714438
# Recall:  0.7251396648044692
# [LibLinear]Edge Operator: Weighted-L1
# TP:  1439
# TN:  1497
# FP:  1188
# FN:  1246
# F1: 0.5417921686746988
# [[1497 1188]
#  [1246 1439]]
#               precision    recall  f1-score   support
#
#            0       0.55      0.56      0.55      2685
#            1       0.55      0.54      0.54      2685
#
#    micro avg       0.55      0.55      0.55      5370
#    macro avg       0.55      0.55      0.55      5370
# weighted avg       0.55      0.55      0.55      5370
#
# Mean Average Precision: 0.5256035483118653
# Area Under ROC Curve: 0.5467411545623836
# Precision:  0.547773125237914
# Recall:  0.5359404096834265
# [LibLinear]Edge Operator: Weighted-L2
# TP:  1488
# TN:  1505
# FP:  1180
# FN:  1197
# F1: 0.5559499346161031
# [[1505 1180]
#  [1197 1488]]
#               precision    recall  f1-score   support
#
#            0       0.56      0.56      0.56      2685
#            1       0.56      0.55      0.56      2685
#
#    micro avg       0.56      0.56      0.56      5370
#    macro avg       0.56      0.56      0.56      5370
# weighted avg       0.56      0.56      0.56      5370
#
# Mean Average Precision: 0.5319884750362249
# Area Under ROC Curve: 0.5573556797020484
# Precision:  0.5577211394302849
# Recall:  0.5541899441340782
# [LibLinear]Edge Operator: Concat
# TP:  1460
# TN:  1693
# FP:  992
# FN:  1225
# F1: 0.5684251508662644
# [[1693  992]
#  [1225 1460]]
#               precision    recall  f1-score   support
#
#            0       0.58      0.63      0.60      2685
#            1       0.60      0.54      0.57      2685
#
#    micro avg       0.59      0.59      0.59      5370
#    macro avg       0.59      0.59      0.59      5370
# weighted avg       0.59      0.59      0.59      5370
#
# Mean Average Precision: 0.5518924239248316
# Area Under ROC Curve: 0.5871508379888268
# Precision:  0.5954323001631321
# Recall:  0.5437616387337058

# %% [markdown]
# ### Email-EU - Equal Monthly
# ### load data

# %%
# load the training and testing graph
with open('../RM_weekly.pkl', 'rb') as file:
    graphs = pickle.load(file)
graph_train = graphs[-2]
graph_test = graphs[-1]

# parameters
num_edge_sample = 400

# %%
num_snapshots = len(graphs)
num_snapshots
# Out:
# 51

# %%
emb_list = []
for i in range(num_snapshots):
    file = '../RM_emb/em-vc-week/em-vc-week-' + str(i) + '.npy'
    node_embedding = np.load(file)
    emb_list.append(node_embedding)
print(len(emb_list))
# Out:
# 51

# %% [markdown]
# ### independent / no combination

# %%
node_embeddings_training = emb_list[-3]
node_embeddings_testing = emb_list[-2]

# %%
for edge_operator in ['Average','Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  0
# TN:  14
# FP:  0
# FN:  14
# F1: Divide-by-zero
# [[14  0]
#  [14  0]]
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67        14
#            1       0.00      0.00      0.00        14
#
#     accuracy                           0.50        28
#    macro avg       0.25      0.50      0.33        28
# weighted avg       0.25      0.50      0.33        28
#
# Mean Average Precision: 0.5
# Area Under ROC Curve: 0.5
# Precision:  0
# Recall:  0
# [LibLinear]Edge Operator: Hadamard
# TP:  3
# TN:  14
# FP:  0
# FN:  11
# F1: 0.35294117647058826
# [[14  0]
#  [11  3]]
#               precision    recall  f1-score   support
#
#            0       0.56      1.00      0.72        14
#            1       1.00      0.21      0.35        14
#
#     accuracy                           0.61        28
#    macro avg       0.78      0.61      0.54        28
# weighted avg       0.78      0.61      0.54        28
#
# Mean Average Precision: 0.6071428571428571
# Area Under ROC Curve: 0.6071428571428571
# Precision:  1.0
# Recall:  0.21428571428571427
# /usr/local/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [LibLinear]Edge Operator: Weighted-L1
# TP:  0
# TN:  14
# FP:  0
# FN:  14
# F1: Divide-by-zero
# [[14  0]
#  [14  0]]
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67        14
#            1       0.00      0.00      0.00        14
#
#     accuracy                           0.50        28
#    macro avg       0.25      0.50      0.33        28
# weighted avg       0.25      0.50      0.33        28
#
# Mean Average Precision: 0.5
# Area Under ROC Curve: 0.5
# Precision:  0
# Recall:  0
# /usr/local/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [LibLinear]Edge Operator: Weighted-L2
# TP:  0
# TN:  14
# FP:  0
# FN:  14
# F1: Divide-by-zero
# [[14  0]
#  [14  0]]
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67        14
#            1       0.00      0.00      0.00        14
#
#     accuracy                           0.50        28
#    macro avg       0.25      0.50      0.33        28
# weighted avg       0.25      0.50      0.33        28
#
# Mean Average Precision: 0.5
# Area Under ROC Curve: 0.5
# Precision:  0
# Recall:  0
# [LibLinear]Edge Operator: Concat
# TP:  0
# TN:  14
# FP:  0
# FN:  14
# F1: Divide-by-zero
# [[14  0]
#  [14  0]]
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67        14
#            1       0.00      0.00      0.00        14
#
#     accuracy                           0.50        28
#    macro avg       0.25      0.50      0.33        28
# weighted avg       0.25      0.50      0.33        28
#
# Mean Average Precision: 0.5
# Area Under ROC Curve: 0.5
# Precision:  0
# Recall:  0
# /usr/local/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### sum

# %%
for i in range(len(emb_list)):
    emb_list[i] = np.asfarray(emb_list[i],float)
node_embeddings_training = np.sum(np.asarray(emb_list[0:-2]),axis=0)
node_embeddings_testing = np.sum(np.asarray(emb_list[0:-1]),axis=0)

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  14
# TN:  14
# FP:  0
# FN:  0
# F1: 1.0
# [[14  0]
#  [ 0 14]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      1.00      1.00        14
#
#     accuracy                           1.00        28
#    macro avg       1.00      1.00      1.00        28
# weighted avg       1.00      1.00      1.00        28
#
# Mean Average Precision: 1.0
# Area Under ROC Curve: 1.0
# Precision:  1.0
# Recall:  1.0
# [LibLinear]Edge Operator: Hadamard
# TP:  9
# TN:  13
# FP:  1
# FN:  5
# F1: 0.75
# [[13  1]
#  [ 5  9]]
#               precision    recall  f1-score   support
#
#            0       0.72      0.93      0.81        14
#            1       0.90      0.64      0.75        14
#
#     accuracy                           0.79        28
#    macro avg       0.81      0.79      0.78        28
# weighted avg       0.81      0.79      0.78        28
#
# Mean Average Precision: 0.7571428571428571
# Area Under ROC Curve: 0.7857142857142857
# Precision:  0.9
# Recall:  0.6428571428571429
# [LibLinear]Edge Operator: Weighted-L1
# TP:  14
# TN:  14
# FP:  0
# FN:  0
# F1: 1.0
# [[14  0]
#  [ 0 14]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      1.00      1.00        14
#
#     accuracy                           1.00        28
#    macro avg       1.00      1.00      1.00        28
# weighted avg       1.00      1.00      1.00        28
#
# Mean Average Precision: 1.0
# Area Under ROC Curve: 1.0
# Precision:  1.0
# Recall:  1.0
# [LibLinear]Edge Operator: Weighted-L2
# TP:  14
# TN:  14
# FP:  0
# FN:  0
# F1: 1.0
# [[14  0]
#  [ 0 14]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      1.00      1.00        14
#
#     accuracy                           1.00        28
#    macro avg       1.00      1.00      1.00        28
# weighted avg       1.00      1.00      1.00        28
#
# Mean Average Precision: 1.0
# Area Under ROC Curve: 1.0
# Precision:  1.0
# Recall:  1.0
# [LibLinear]Edge Operator: Concat
# TP:  14
# TN:  14
# FP:  0
# FN:  0
# F1: 1.0
# [[14  0]
#  [ 0 14]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      1.00      1.00        14
#
#     accuracy                           1.00        28
#    macro avg       1.00      1.00      1.00        28
# weighted avg       1.00      1.00      1.00        28
#
# Mean Average Precision: 1.0
# Area Under ROC Curve: 1.0
# Precision:  1.0
# Recall:  1.0

# %% [markdown]
# ### expdecay

# %%
exps = [np.exp(-i * 0.9) for i in range(1,17)]
node_embeddings_training = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-2],exps[:-1]):
    node_embeddings_training += e * c 
node_embeddings_testing = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-1],exps[:-1]):
    node_embeddings_testing += e * c

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  14
# TN:  14
# FP:  0
# FN:  0
# F1: 1.0
# [[14  0]
#  [ 0 14]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      1.00      1.00        14
#
#     accuracy                           1.00        28
#    macro avg       1.00      1.00      1.00        28
# weighted avg       1.00      1.00      1.00        28
#
# Mean Average Precision: 1.0
# Area Under ROC Curve: 1.0
# Precision:  1.0
# Recall:  1.0
# [LibLinear]Edge Operator: Hadamard
# TP:  10
# TN:  13
# FP:  1
# FN:  4
# F1: 0.8
# [[13  1]
#  [ 4 10]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.93      0.84        14
#            1       0.91      0.71      0.80        14
#
#     accuracy                           0.82        28
#    macro avg       0.84      0.82      0.82        28
# weighted avg       0.84      0.82      0.82        28
#
# Mean Average Precision: 0.7922077922077921
# Area Under ROC Curve: 0.8214285714285715
# Precision:  0.9090909090909091
# Recall:  0.7142857142857143
# [LibLinear]Edge Operator: Weighted-L1
# TP:  14
# TN:  14
# FP:  0
# FN:  0
# F1: 1.0
# [[14  0]
#  [ 0 14]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      1.00      1.00        14
#
#     accuracy                           1.00        28
#    macro avg       1.00      1.00      1.00        28
# weighted avg       1.00      1.00      1.00        28
#
# Mean Average Precision: 1.0
# Area Under ROC Curve: 1.0
# Precision:  1.0
# Recall:  1.0
# [LibLinear]Edge Operator: Weighted-L2
# TP:  13
# TN:  14
# FP:  0
# FN:  1
# F1: 0.962962962962963
# [[14  0]
#  [ 1 13]]
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.97        14
#            1       1.00      0.93      0.96        14
#
#     accuracy                           0.96        28
#    macro avg       0.97      0.96      0.96        28
# weighted avg       0.97      0.96      0.96        28
#
# Mean Average Precision: 0.9642857142857143
# Area Under ROC Curve: 0.9642857142857143
# Precision:  1.0
# Recall:  0.9285714285714286
# [LibLinear]Edge Operator: Concat
# TP:  14
# TN:  14
# FP:  0
# FN:  0
# F1: 1.0
# [[14  0]
#  [ 0 14]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      1.00      1.00        14
#
#     accuracy                           1.00        28
#    macro avg       1.00      1.00      1.00        28
# weighted avg       1.00      1.00      1.00        28
#
# Mean Average Precision: 1.0
# Area Under ROC Curve: 1.0
# Precision:  1.0
# Recall:  1.0

# %% [markdown]
# ### Email-EU - Equal Weekly
# ### load data

# %%
# load the training and testing graph
with open('../data/email_EU/email_equal_weekly_dir.pkl', 'rb') as file:
    graphs = pickle.load(file)
graph_train = graphs[-2]
graph_test = graphs[-1]

# parameters
num_edge_sample = 400

# %%
num_snapshots = len(graphs)
num_snapshots
# Out:
# 74

# %%
emb_list = []
for i in range(num_snapshots):
    file = '../data/email_EU/embeddings/em-email-equal-week-' + str(i) + '.npy'
    node_embedding = np.load(file)
    emb_list.append(node_embedding)
print(len(emb_list))
# Out:
# 74

# %%
node_embeddings_training = emb_list[-3]
node_embeddings_testing = emb_list[-2]

# %%
for edge_operator in ['Average','Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  242
# TN:  1948
# FP:  197
# FN:  1903
# F1: 0.1873065015479876
# [[1948  197]
#  [1903  242]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.91      0.65      2145
#            1       0.55      0.11      0.19      2145
#
#    micro avg       0.51      0.51      0.51      4290
#    macro avg       0.53      0.51      0.42      4290
# weighted avg       0.53      0.51      0.42      4290
#
# Mean Average Precision: 0.5057823725249693
# Area Under ROC Curve: 0.5104895104895105
# Precision:  0.55125284738041
# Recall:  0.11282051282051282
# [LibLinear]Edge Operator: Hadamard
# TP:  1673
# TN:  427
# FP:  1718
# FN:  472
# F1: 0.604407514450867
# [[ 427 1718]
#  [ 472 1673]]
#               precision    recall  f1-score   support
#
#            0       0.47      0.20      0.28      2145
#            1       0.49      0.78      0.60      2145
#
#    micro avg       0.49      0.49      0.49      4290
#    macro avg       0.48      0.49      0.44      4290
# weighted avg       0.48      0.49      0.44      4290
#
# Mean Average Precision: 0.49482484486907957
# Area Under ROC Curve: 0.48951048951048953
# Precision:  0.493364789147744
# Recall:  0.77995337995338
# [LibLinear]Edge Operator: Weighted-L1
# TP:  1154
# TN:  992
# FP:  1153
# FN:  991
# F1: 0.5184186882300089
# [[ 992 1153]
#  [ 991 1154]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.46      0.48      2145
#            1       0.50      0.54      0.52      2145
#
#    micro avg       0.50      0.50      0.50      4290
#    macro avg       0.50      0.50      0.50      4290
# weighted avg       0.50      0.50      0.50      4290
#
# Mean Average Precision: 0.5001166006367567
# Area Under ROC Curve: 0.5002331002331002
# Precision:  0.5002167316861725
# Recall:  0.5379953379953379
# [LibLinear]Edge Operator: Weighted-L2
# TP:  1175
# TN:  1016
# FP:  1129
# FN:  970
# F1: 0.5282085861991458
# [[1016 1129]
#  [ 970 1175]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.47      0.49      2145
#            1       0.51      0.55      0.53      2145
#
#    micro avg       0.51      0.51      0.51      4290
#    macro avg       0.51      0.51      0.51      4290
# weighted avg       0.51      0.51      0.51      4290
#
# Mean Average Precision: 0.5054683453120953
# Area Under ROC Curve: 0.5107226107226107
# Precision:  0.5099826388888888
# Recall:  0.5477855477855478
# [LibLinear]Edge Operator: Concat
# TP:  893
# TN:  1278
# FP:  867
# FN:  1252
# F1: 0.4573623559539053
# [[1278  867]
#  [1252  893]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.60      0.55      2145
#            1       0.51      0.42      0.46      2145
#
#    micro avg       0.51      0.51      0.51      4290
#    macro avg       0.51      0.51      0.50      4290
# weighted avg       0.51      0.51      0.50      4290
#
# Mean Average Precision: 0.5030750688705234
# Area Under ROC Curve: 0.5060606060606061
# Precision:  0.5073863636363637
# Recall:  0.41631701631701634

# %% [markdown]
# ### sum

# %%
for i in range(len(emb_list)):
    emb_list[i] = np.asfarray(emb_list[i],float)
node_embeddings_training = np.sum(np.asarray(emb_list[0:-2]),axis=0)
node_embeddings_testing = np.sum(np.asarray(emb_list[0:-1]),axis=0)

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  1281
# TN:  1369
# FP:  776
# FN:  864
# F1: 0.609709662065683
# [[1369  776]
#  [ 864 1281]]
#               precision    recall  f1-score   support
#
#            0       0.61      0.64      0.63      2145
#            1       0.62      0.60      0.61      2145
#
#    micro avg       0.62      0.62      0.62      4290
#    macro avg       0.62      0.62      0.62      4290
# weighted avg       0.62      0.62      0.62      4290
#
# Mean Average Precision: 0.5733075869196433
# Area Under ROC Curve: 0.6177156177156178
# Precision:  0.6227515799708313
# Recall:  0.5972027972027972
# [LibLinear]Edge Operator: Hadamard
# TP:  1237
# TN:  1017
# FP:  1128
# FN:  908
# F1: 0.5485587583148559
# [[1017 1128]
#  [ 908 1237]]
#               precision    recall  f1-score   support
#
#            0       0.53      0.47      0.50      2145
#            1       0.52      0.58      0.55      2145
#
#    micro avg       0.53      0.53      0.53      4290
#    macro avg       0.53      0.53      0.52      4290
# weighted avg       0.53      0.53      0.52      4290
#
# Mean Average Precision: 0.5132894730357733
# Area Under ROC Curve: 0.5254079254079254
# Precision:  0.5230443974630021
# Recall:  0.5766899766899767
# [LibLinear]Edge Operator: Weighted-L1
# TP:  1136
# TN:  1247
# FP:  898
# FN:  1009
# F1: 0.5436707346255085
# [[1247  898]
#  [1009 1136]]
#               precision    recall  f1-score   support
#
#            0       0.55      0.58      0.57      2145
#            1       0.56      0.53      0.54      2145
#
#    micro avg       0.56      0.56      0.56      4290
#    macro avg       0.56      0.56      0.56      4290
# weighted avg       0.56      0.56      0.56      4290
#
# Mean Average Precision: 0.5309846823121159
# Area Under ROC Curve: 0.5554778554778556
# Precision:  0.5585054080629301
# Recall:  0.5296037296037296
# [LibLinear]Edge Operator: Weighted-L2
# TP:  1253
# TN:  1155
# FP:  990
# FN:  892
# F1: 0.5711030082041932
# [[1155  990]
#  [ 892 1253]]
#               precision    recall  f1-score   support
#
#            0       0.56      0.54      0.55      2145
#            1       0.56      0.58      0.57      2145
#
#    micro avg       0.56      0.56      0.56      4290
#    macro avg       0.56      0.56      0.56      4290
# weighted avg       0.56      0.56      0.56      4290
#
# Mean Average Precision: 0.5342468202031287
# Area Under ROC Curve: 0.5613053613053613
# Precision:  0.5586268390548372
# Recall:  0.5841491841491842
# [LibLinear]Edge Operator: Concat
# TP:  1261
# TN:  1259
# FP:  886
# FN:  884
# F1: 0.587604846225536
# [[1259  886]
#  [ 884 1261]]
#               precision    recall  f1-score   support
#
#            0       0.59      0.59      0.59      2145
#            1       0.59      0.59      0.59      2145
#
#    micro avg       0.59      0.59      0.59      4290
#    macro avg       0.59      0.59      0.59      4290
# weighted avg       0.59      0.59      0.59      4290
#
# Mean Average Precision: 0.5513401363424653
# Area Under ROC Curve: 0.5874125874125874
# Precision:  0.5873311597578016
# Recall:  0.5878787878787879

# %% [markdown]
# ### expdecay

# %%
exps = [np.exp(-i * 0.3) for i in range(1,28)]
node_embeddings_training = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-2],exps[:-1]):
    node_embeddings_training += e * c 
node_embeddings_testing = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-1],exps[:-1]):
    node_embeddings_testing += e * c

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  1306
# TN:  1276
# FP:  869
# FN:  839
# F1: 0.6046296296296296
# [[1276  869]
#  [ 839 1306]]
#               precision    recall  f1-score   support
#
#            0       0.60      0.59      0.60      2145
#            1       0.60      0.61      0.60      2145
#
#    micro avg       0.60      0.60      0.60      4290
#    macro avg       0.60      0.60      0.60      4290
# weighted avg       0.60      0.60      0.60      4290
#
# Mean Average Precision: 0.5611657155105432
# Area Under ROC Curve: 0.6018648018648018
# Precision:  0.6004597701149426
# Recall:  0.6088578088578088
# [LibLinear]Edge Operator: Hadamard
# TP:  1529
# TN:  696
# FP:  1449
# FN:  616
# F1: 0.5969158696076519
# [[ 696 1449]
#  [ 616 1529]]
#               precision    recall  f1-score   support
#
#            0       0.53      0.32      0.40      2145
#            1       0.51      0.71      0.60      2145
#
#    micro avg       0.52      0.52      0.52      4290
#    macro avg       0.52      0.52      0.50      4290
# weighted avg       0.52      0.52      0.50      4290
#
# Mean Average Precision: 0.5095744864045737
# Area Under ROC Curve: 0.5186480186480187
# Precision:  0.5134318334452653
# Recall:  0.7128205128205128
# [LibLinear]Edge Operator: Weighted-L1
# TP:  1092
# TN:  1305
# FP:  840
# FN:  1053
# F1: 0.5356880058866813
# [[1305  840]
#  [1053 1092]]
#               precision    recall  f1-score   support
#
#            0       0.55      0.61      0.58      2145
#            1       0.57      0.51      0.54      2145
#
#    micro avg       0.56      0.56      0.56      4290
#    macro avg       0.56      0.56      0.56      4290
# weighted avg       0.56      0.56      0.56      4290
#
# Mean Average Precision: 0.533201581027668
# Area Under ROC Curve: 0.5587412587412587
# Precision:  0.5652173913043478
# Recall:  0.509090909090909
# [LibLinear]Edge Operator: Weighted-L2
# TP:  1348
# TN:  1133
# FP:  1012
# FN:  797
# F1: 0.5984461709211987
# [[1133 1012]
#  [ 797 1348]]
#               precision    recall  f1-score   support
#
#            0       0.59      0.53      0.56      2145
#            1       0.57      0.63      0.60      2145
#
#    micro avg       0.58      0.58      0.58      4290
#    macro avg       0.58      0.58      0.58      4290
# weighted avg       0.58      0.58      0.58      4290
#
# Mean Average Precision: 0.5447362806684841
# Area Under ROC Curve: 0.5783216783216782
# Precision:  0.5711864406779661
# Recall:  0.6284382284382284
# [LibLinear]Edge Operator: Concat
# TP:  1233
# TN:  1351
# FP:  794
# FN:  912
# F1: 0.5910834132310643
# [[1351  794]
#  [ 912 1233]]
#               precision    recall  f1-score   support
#
#            0       0.60      0.63      0.61      2145
#            1       0.61      0.57      0.59      2145
#
#    micro avg       0.60      0.60      0.60      4290
#    macro avg       0.60      0.60      0.60      4290
# weighted avg       0.60      0.60      0.60      4290
#
# Mean Average Precision: 0.5622467320543295
# Area Under ROC Curve: 0.6023310023310023
# Precision:  0.6082881105081401
# Recall:  0.5748251748251748
