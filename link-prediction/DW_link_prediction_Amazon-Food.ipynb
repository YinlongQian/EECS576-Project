# %%
import random

from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
import pickle
import sklearn.metrics as metrics

# %% [markdown]
# ### functions

# %%
def edge_features(node_emb_1, node_emb_2, operator):
    node_emb_1 = np.asfarray(node_emb_1,float)
    node_emb_2 = np.asfarray(node_emb_2, float)
    # combine two nodes' embeddings with specificed operator
    if operator == 'Average':
        edge = [((x + y) / 2.0) for x,y in zip(node_emb_1, node_emb_2)]
    elif operator == 'Hadamard':
        edge = [(x * y) for x,y in zip(node_emb_1, node_emb_2)]
    elif operator == 'Weighted-L1':
        edge = [abs(x - y) for x,y in zip(node_emb_1, node_emb_2)]
    elif operator == 'Weighted-L2':
        edge = [abs(x - y)**2 for x,y in zip(node_emb_1, node_emb_2)]
    elif operator == 'Concat':
        edge = np.concatenate((node_emb_1, node_emb_2), axis=None) 
    else:
        print("Generate edge features: Operator not supported")
        print("Use default operator: Weighted-L1")
        edge = [abs(x - y) for x,y in zip(node_emb_1, node_emb_2)]
        
    return edge
def generate_edge_features(edge_list, node_embeddings, operator):
    edge_features_mtx = []
    
    # generate features for each edge in the list
    for node_index_1, node_index_2 in edge_list:
        node_emb_1 = node_embeddings[node_index_1-1]
        node_emb_2 = node_embeddings[node_index_2-1]
        
        edge_features_mtx.append(edge_features(node_emb_1, node_emb_2, operator))
        
    return edge_features_mtx

def generate_train_set(graph_train, num_edge_sample, node_embeddings, edge_operator,):
    edge_list = list(graph_train.edges)
    num_nodes = graph_train.number_of_nodes()
    
    train_edges = []
    train_edges_labels = [1] * num_edge_sample + [0] * num_edge_sample
    
    random.seed(0)
    
    # sample edges with label 1 (true edges)
    for edge_num in range(num_edge_sample):
        rand_index = random.randint(0, len(edge_list) - 1)
        
        #train_edges.append(tuple(edge_list[rand_index]))
        train_edges.append(edge_list[rand_index])
    non_edge_num = 0
    
    # sample edges with label 0 (non-exist edges)
    while(non_edge_num < num_edge_sample):
        rand_nodes = tuple(np.random.randint(low=0,high=num_nodes, size=2))
        
        if rand_nodes not in edge_list:
            train_edges.append(rand_nodes)
            non_edge_num += 1

    train_edges_features_mtx = generate_edge_features(train_edges, node_embeddings, edge_operator)
            
    return train_edges, train_edges_features_mtx, train_edges_labels

def generate_test_set(graph_test, node_embeddings, edge_operator):
    edge_list = graph_test.edges
    nodes_with_edge = set()
    
    for edge in edge_list:
        nodes_with_edge.add(edge[0])
        nodes_with_edge.add(edge[1])
    
    num_nodes = graph_test.number_of_nodes()
    
    test_edges = []
    test_edges_labels = []
    
    num_edge_sample = len(edge_list)
    non_edge_num = 0 
    # sample edges with label 0 (non-exist edges)
    
    while(non_edge_num < num_edge_sample):
        rand_nodes = tuple(np.random.randint(low=0,high=num_nodes, size=2))
        
        if rand_nodes not in edge_list:
            test_edges.append(rand_nodes)
            test_edges_labels.append(0)
            non_edge_num += 1
        
    for edge in edge_list:
        test_edges.append(edge)
        test_edges_labels.append(1)
    
    test_edges_features_mtx = generate_edge_features(test_edges, node_embeddings, edge_operator)
    
    return test_edges, test_edges_features_mtx, test_edges_labels

def build_clf(feature_mtx, response_vec):
   
    logistic_regression_model = LogisticRegression(random_state = 0,max_iter=5000,solver='liblinear',verbose=1,tol=1e-6)
    binary_clf = logistic_regression_model.fit(feature_mtx, response_vec)
    
    return binary_clf

def pred_links(feature_mtx, LR_clf):
    predict_edges_labels = LR_clf.predict(feature_mtx)
    
    return predict_edges_labels

def precision_recall(predict_labels, true_labels):
    true_positive  = false_positive = 0
    true_negative =  false_negative = 0
    
    for p_label, true_label in zip(predict_labels, true_labels):
        
        #print(p_label,true_label)
        if p_label == true_label and true_label == 1:
            true_positive += 1
        elif p_label == true_label and true_label == 0:
            true_negative += 1
        elif p_label != true_label and true_label == 1:
            false_negative += 1
        elif p_label != true_label and true_label == 0:
            false_positive += 1

    print("TP: ", true_positive)
    print("TN: ", true_negative)
    print("FP: ", false_positive)
    print("FN: ", false_negative)
    
    precision = true_positive / (true_positive + false_positive)
    recall = true_positive / (true_positive + false_negative)
    if (precision + recall) != 0.0:
        f1 = 2 * (precision * recall) / (precision + recall)
        print("F1: {}".format(f1))
    else:
        print("F1: Divide-by-zero")
    
    cm = metrics.confusion_matrix(true_labels, predict_labels)
    print(cm)
    print(metrics.classification_report(true_labels, predict_labels))
    map = metrics.average_precision_score(true_labels, predict_labels)
    print('Mean Average Precision: {}'.format(map))
    fpr, tpr, thresholds = metrics.roc_curve(true_labels, predict_labels)
    roc_auc = metrics.auc(fpr, tpr)
    print('Area Under ROC Curve: {}'.format(roc_auc))
    
    return precision, recall

# %% [markdown]
# ### Amazon-Food - Monthly
# ### load data

# %%
# load the training and testing graph
with open('../graphs/amazon_food/amazon_food_monthly_dir.pkl', 'rb') as file:
    graphs = pickle.load(file)
    
graphs = graphs[-20:]
graph_train = graphs[-2]
graph_test = graphs[-1]

# parameters
num_edge_sample = 400

# %%
num_snapshots = len(graphs)
num_snapshots
# Out:
# 20

# %%
emb_list = []
for i in range(num_snapshots):
    file = '../embeddings/amazon_food/amazon_month/amazon_month_' + str(i) + '.npy'
    node_embedding = np.load(file)
    emb_list.append(node_embedding)
print(len(emb_list))
# Out:
# 20

# %% [markdown]
# ### independent / no combination

# %%
node_embeddings_training = emb_list[-3]
node_embeddings_testing = emb_list[-2]

# %%
for edge_operator in ['Average','Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  1280
# TN:  1536
# FP:  1249
# FN:  1505
# F1: 0.48174633044787357
# [[1536 1249]
#  [1505 1280]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.55      0.53      2785
#            1       0.51      0.46      0.48      2785
#
#    micro avg       0.51      0.51      0.51      5570
#    macro avg       0.51      0.51      0.50      5570
# weighted avg       0.51      0.51      0.50      5570
#
# Mean Average Precision: 0.5028168754121846
# Area Under ROC Curve: 0.5055655296229803
# Precision:  0.5061289047054172
# Recall:  0.45960502692998206
# [LibLinear]Edge Operator: Hadamard
# TP:  1380
# TN:  1422
# FP:  1363
# FN:  1405
# F1: 0.4992764109985528
# [[1422 1363]
#  [1405 1380]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.51      0.51      2785
#            1       0.50      0.50      0.50      2785
#
#    micro avg       0.50      0.50      0.50      5570
#    macro avg       0.50      0.50      0.50      5570
# weighted avg       0.50      0.50      0.50      5570
#
# Mean Average Precision: 0.5015354900445135
# Area Under ROC Curve: 0.5030520646319568
# Precision:  0.5030987969376595
# Recall:  0.4955116696588869
# [LibLinear]Edge Operator: Weighted-L1
# TP:  1406
# TN:  1446
# FP:  1339
# FN:  1379
# F1: 0.508499095840868
# [[1446 1339]
#  [1379 1406]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.52      0.52      2785
#            1       0.51      0.50      0.51      2785
#
#    micro avg       0.51      0.51      0.51      5570
#    macro avg       0.51      0.51      0.51      5570
# weighted avg       0.51      0.51      0.51      5570
#
# Mean Average Precision: 0.5061611613084669
# Area Under ROC Curve: 0.5120287253141831
# Precision:  0.5122040072859745
# Recall:  0.5048473967684022
# [LibLinear]Edge Operator: Weighted-L2
# TP:  1879
# TN:  875
# FP:  1910
# FN:  906
# F1: 0.5716458777000304
# [[ 875 1910]
#  [ 906 1879]]
#               precision    recall  f1-score   support
#
#            0       0.49      0.31      0.38      2785
#            1       0.50      0.67      0.57      2785
#
#    micro avg       0.49      0.49      0.49      5570
#    macro avg       0.49      0.49      0.48      5570
# weighted avg       0.49      0.49      0.48      5570
#
# Mean Average Precision: 0.4972400025965743
# Area Under ROC Curve: 0.49443447037701976
# Precision:  0.4959092108735814
# Recall:  0.6746858168761221
# [LibLinear]Edge Operator: Concat
# TP:  1260
# TN:  1631
# FP:  1154
# FN:  1525
# F1: 0.48470859780727066
# [[1631 1154]
#  [1525 1260]]
#               precision    recall  f1-score   support
#
#            0       0.52      0.59      0.55      2785
#            1       0.52      0.45      0.48      2785
#
#    micro avg       0.52      0.52      0.52      5570
#    macro avg       0.52      0.52      0.52      5570
# weighted avg       0.52      0.52      0.52      5570
#
# Mean Average Precision: 0.5099330803704899
# Area Under ROC Curve: 0.5190305206463196
# Precision:  0.5219552609776305
# Recall:  0.4524236983842011

# %% [markdown]
# ### sum

# %%
for i in range(len(emb_list)):
    emb_list[i] = np.asfarray(emb_list[i],float)
node_embeddings_training = np.sum(np.asarray(emb_list[0:-2]),axis=0)
node_embeddings_testing = np.sum(np.asarray(emb_list[0:-1]),axis=0)

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  1329
# TN:  1493
# FP:  1292
# FN:  1456
# F1: 0.4916759156492786
# [[1493 1292]
#  [1456 1329]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.54      0.52      2785
#            1       0.51      0.48      0.49      2785
#
#    micro avg       0.51      0.51      0.51      5570
#    macro avg       0.51      0.51      0.51      5570
# weighted avg       0.51      0.51      0.51      5570
#
# Mean Average Precision: 0.5033682513218398
# Area Under ROC Curve: 0.5066427289048474
# Precision:  0.507058374666158
# Recall:  0.47719928186714544
# [LibLinear]Edge Operator: Hadamard
# TP:  1464
# TN:  1391
# FP:  1394
# FN:  1321
# F1: 0.5188729399255715
# [[1391 1394]
#  [1321 1464]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.50      0.51      2785
#            1       0.51      0.53      0.52      2785
#
#    micro avg       0.51      0.51      0.51      5570
#    macro avg       0.51      0.51      0.51      5570
# weighted avg       0.51      0.51      0.51      5570
#
# Mean Average Precision: 0.5064375660371907
# Area Under ROC Curve: 0.5125673249551167
# Precision:  0.5122463261021694
# Recall:  0.525673249551167
# [LibLinear]Edge Operator: Weighted-L1
# TP:  1370
# TN:  1418
# FP:  1367
# FN:  1415
# F1: 0.4961970300615719
# [[1418 1367]
#  [1415 1370]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.51      0.50      2785
#            1       0.50      0.49      0.50      2785
#
#    micro avg       0.50      0.50      0.50      5570
#    macro avg       0.50      0.50      0.50      5570
# weighted avg       0.50      0.50      0.50      5570
#
# Mean Average Precision: 0.5002695949974714
# Area Under ROC Curve: 0.5005385996409335
# Precision:  0.5005480453050786
# Recall:  0.4919210053859964
# [LibLinear]Edge Operator: Weighted-L2
# TP:  1507
# TN:  1297
# FP:  1488
# FN:  1278
# F1: 0.5214532871972319
# [[1297 1488]
#  [1278 1507]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.47      0.48      2785
#            1       0.50      0.54      0.52      2785
#
#    micro avg       0.50      0.50      0.50      5570
#    macro avg       0.50      0.50      0.50      5570
# weighted avg       0.50      0.50      0.50      5570
#
# Mean Average Precision: 0.501716385477891
# Area Under ROC Curve: 0.503411131059246
# Precision:  0.5031719532554257
# Recall:  0.541113105924596
# [LibLinear]Edge Operator: Concat
# TP:  1319
# TN:  1587
# FP:  1198
# FN:  1466
# F1: 0.49754809505846853
# [[1587 1198]
#  [1466 1319]]
#               precision    recall  f1-score   support
#
#            0       0.52      0.57      0.54      2785
#            1       0.52      0.47      0.50      2785
#
#    micro avg       0.52      0.52      0.52      5570
#    macro avg       0.52      0.52      0.52      5570
# weighted avg       0.52      0.52      0.52      5570
#
# Mean Average Precision: 0.5113839179040336
# Area Under ROC Curve: 0.5217235188509874
# Precision:  0.524036551450139
# Recall:  0.47360861759425493

# %% [markdown]
# ### expdecay

# %%
exps = [np.exp(-i * 0.3) for i in range(1,21)]
node_embeddings_training = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-2],exps[:-1]):
    node_embeddings_training += e * c
print(len(emb_list))
print(len(exps))
# Out:
# 20
# 20

# %%
node_embeddings_testing = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-1],exps[:-1]):
    node_embeddings_testing += e * c

# %%
for edge_operator in [ 'Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  1225
# TN:  1528
# FP:  1257
# FN:  1560
# F1: 0.4651604328839947
# [[1528 1257]
#  [1560 1225]]
#               precision    recall  f1-score   support
#
#            0       0.49      0.55      0.52      2785
#            1       0.49      0.44      0.47      2785
#
#    micro avg       0.49      0.49      0.49      5570
#    macro avg       0.49      0.49      0.49      5570
# weighted avg       0.49      0.49      0.49      5570
#
# Mean Average Precision: 0.49716450363623477
# Area Under ROC Curve: 0.4942549371633752
# Precision:  0.4935535858178888
# Recall:  0.4398563734290844
# [LibLinear]Edge Operator: Hadamard
# TP:  1447
# TN:  1365
# FP:  1420
# FN:  1338
# F1: 0.5120311394196745
# [[1365 1420]
#  [1338 1447]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.49      0.50      2785
#            1       0.50      0.52      0.51      2785
#
#    micro avg       0.50      0.50      0.50      5570
#    macro avg       0.50      0.50      0.50      5570
# weighted avg       0.50      0.50      0.50      5570
#
# Mean Average Precision: 0.5024465235869822
# Area Under ROC Curve: 0.5048473967684022
# Precision:  0.504708754795954
# Recall:  0.5195691202872531
# [LibLinear]Edge Operator: Weighted-L1
# TP:  1437
# TN:  1412
# FP:  1373
# FN:  1348
# F1: 0.5136729222520108
# [[1412 1373]
#  [1348 1437]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.51      0.51      2785
#            1       0.51      0.52      0.51      2785
#
#    micro avg       0.51      0.51      0.51      5570
#    macro avg       0.51      0.51      0.51      5570
# weighted avg       0.51      0.51      0.51      5570
#
# Mean Average Precision: 0.5058759112428681
# Area Under ROC Curve: 0.5114901256732496
# Precision:  0.5113879003558719
# Recall:  0.5159784560143627
# [LibLinear]Edge Operator: Weighted-L2
# TP:  1442
# TN:  1361
# FP:  1424
# FN:  1343
# F1: 0.5103521500619359
# [[1361 1424]
#  [1343 1442]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.49      0.50      2785
#            1       0.50      0.52      0.51      2785
#
#    micro avg       0.50      0.50      0.50      5570
#    macro avg       0.50      0.50      0.50      5570
# weighted avg       0.50      0.50      0.50      5570
#
# Mean Average Precision: 0.5016259469969844
# Area Under ROC Curve: 0.5032315978456015
# Precision:  0.5031402651779484
# Recall:  0.5177737881508079
# [LibLinear]Edge Operator: Concat
# TP:  1333
# TN:  1618
# FP:  1167
# FN:  1452
# F1: 0.5044465468306528
# [[1618 1167]
#  [1452 1333]]
#               precision    recall  f1-score   support
#
#            0       0.53      0.58      0.55      2785
#            1       0.53      0.48      0.50      2785
#
#    micro avg       0.53      0.53      0.53      5570
#    macro avg       0.53      0.53      0.53      5570
# weighted avg       0.53      0.53      0.53      5570
#
# Mean Average Precision: 0.5158907001795332
# Area Under ROC Curve: 0.529802513464991
# Precision:  0.5332
# Recall:  0.4786355475763016

# %% [markdown]
# ### Amazon-Food - Weekly
# ### load data

# %%
# load the training and testing graph
with open('../graphs/amazon_food/amazon_food_weekly_dir.pkl', 'rb') as file:
    graphs = pickle.load(file)
    
graphs = graphs[-20:]
graph_train = graphs[-2]
graph_test = graphs[-1]

# parameters
num_edge_sample = 400

# %%
num_snapshots = len(graphs)
num_snapshots
# Out:
# 20

# %%
emb_list = []
for i in range(num_snapshots):
    file = '../embeddings/amazon_food/amazon_week/amazon_week_' + str(i) + '.npy'
    node_embedding = np.load(file)
    emb_list.append(node_embedding)
print(len(emb_list))
# Out:
# 20

# %% [markdown]
# ### independent / no combination

# %%
node_embeddings_training = emb_list[-3]
node_embeddings_testing = emb_list[-2]

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  580
# TN:  730
# FP:  548
# FN:  698
# F1: 0.48212801330008315
# [[730 548]
#  [698 580]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.57      0.54      1278
#            1       0.51      0.45      0.48      1278
#
#    micro avg       0.51      0.51      0.51      2556
#    macro avg       0.51      0.51      0.51      2556
# weighted avg       0.51      0.51      0.51      2556
#
# Mean Average Precision: 0.5064373633447652
# Area Under ROC Curve: 0.5125195618153364
# Precision:  0.5141843971631206
# Recall:  0.4538341158059468
# [LibLinear]Edge Operator: Hadamard
# TP:  641
# TN:  609
# FP:  669
# FN:  637
# F1: 0.49536321483771256
# [[609 669]
#  [637 641]]
#               precision    recall  f1-score   support
#
#            0       0.49      0.48      0.48      1278
#            1       0.49      0.50      0.50      1278
#
#    micro avg       0.49      0.49      0.49      2556
#    macro avg       0.49      0.49      0.49      2556
# weighted avg       0.49      0.49      0.49      2556
#
# Mean Average Precision: 0.49463976394413983
# Area Under ROC Curve: 0.48904538341158066
# Precision:  0.48931297709923666
# Recall:  0.5015649452269171
# [LibLinear]Edge Operator: Weighted-L1
# TP:  594
# TN:  731
# FP:  547
# FN:  684
# F1: 0.49111202976436535
# [[731 547]
#  [684 594]]
#               precision    recall  f1-score   support
#
#            0       0.52      0.57      0.54      1278
#            1       0.52      0.46      0.49      1278
#
#    micro avg       0.52      0.52      0.52      2556
#    macro avg       0.52      0.52      0.52      2556
# weighted avg       0.52      0.52      0.52      2556
#
# Mean Average Precision: 0.5095727740677192
# Area Under ROC Curve: 0.5183881064162754
# Precision:  0.5205959684487291
# Recall:  0.4647887323943662
# [LibLinear]Edge Operator: Weighted-L2
# TP:  613
# TN:  718
# FP:  560
# FN:  665
# F1: 0.500203998368013
# [[718 560]
#  [665 613]]
#               precision    recall  f1-score   support
#
#            0       0.52      0.56      0.54      1278
#            1       0.52      0.48      0.50      1278
#
#    micro avg       0.52      0.52      0.52      2556
#    macro avg       0.52      0.52      0.52      2556
# weighted avg       0.52      0.52      0.52      2556
#
# Mean Average Precision: 0.5108362117385568
# Area Under ROC Curve: 0.520735524256651
# Precision:  0.5225916453537937
# Recall:  0.47965571205007823
# [LibLinear]Edge Operator: Concat
# TP:  530
# TN:  802
# FP:  476
# FN:  748
# F1: 0.46409807355516636
# [[802 476]
#  [748 530]]
#               precision    recall  f1-score   support
#
#            0       0.52      0.63      0.57      1278
#            1       0.53      0.41      0.46      1278
#
#    micro avg       0.52      0.52      0.52      2556
#    macro avg       0.52      0.52      0.52      2556
# weighted avg       0.52      0.52      0.52      2556
#
# Mean Average Precision: 0.511130400694425
# Area Under ROC Curve: 0.5211267605633803
# Precision:  0.5268389662027833
# Recall:  0.41471048513302033

# %% [markdown]
# ### sum

# %%
for i in range(len(emb_list)):
    emb_list[i] = np.asfarray(emb_list[i],float)
node_embeddings_training = np.sum(np.asarray(emb_list[0:-2]),axis=0)
node_embeddings_testing = np.sum(np.asarray(emb_list[0:-1]),axis=0)

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  569
# TN:  723
# FP:  555
# FN:  709
# F1: 0.47377185678601164
# [[723 555]
#  [709 569]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.57      0.53      1278
#            1       0.51      0.45      0.47      1278
#
#    micro avg       0.51      0.51      0.51      2556
#    macro avg       0.51      0.51      0.50      2556
# weighted avg       0.51      0.51      0.50      2556
#
# Mean Average Precision: 0.5027727654976916
# Area Under ROC Curve: 0.5054773082942097
# Precision:  0.5062277580071174
# Recall:  0.44522691705790296
# [LibLinear]Edge Operator: Hadamard
# TP:  572
# TN:  711
# FP:  567
# FN:  706
# F1: 0.4733140256516342
# [[711 567]
#  [706 572]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.56      0.53      1278
#            1       0.50      0.45      0.47      1278
#
#    micro avg       0.50      0.50      0.50      2556
#    macro avg       0.50      0.50      0.50      2556
# weighted avg       0.50      0.50      0.50      2556
#
# Mean Average Precision: 0.5009823844049567
# Area Under ROC Curve: 0.5019561815336463
# Precision:  0.5021949078138718
# Recall:  0.4475743348982786
# [LibLinear]Edge Operator: Weighted-L1
# TP:  652
# TN:  634
# FP:  644
# FN:  626
# F1: 0.5066045066045066
# [[634 644]
#  [626 652]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50      1278
#            1       0.50      0.51      0.51      1278
#
#    micro avg       0.50      0.50      0.50      2556
#    macro avg       0.50      0.50      0.50      2556
# weighted avg       0.50      0.50      0.50      2556
#
# Mean Average Precision: 0.5015746053826388
# Area Under ROC Curve: 0.5031298904538342
# Precision:  0.5030864197530864
# Recall:  0.5101721439749609
# [LibLinear]Edge Operator: Weighted-L2
# TP:  704
# TN:  636
# FP:  642
# FN:  574
# F1: 0.5365853658536586
# [[636 642]
#  [574 704]]
#               precision    recall  f1-score   support
#
#            0       0.53      0.50      0.51      1278
#            1       0.52      0.55      0.54      1278
#
#    micro avg       0.52      0.52      0.52      2556
#    macro avg       0.52      0.52      0.52      2556
# weighted avg       0.52      0.52      0.52      2556
#
# Mean Average Precision: 0.512686985376017
# Area Under ROC Curve: 0.5242566510172144
# Precision:  0.5230312035661219
# Recall:  0.5508607198748043
# [LibLinear]Edge Operator: Concat
# TP:  506
# TN:  800
# FP:  478
# FN:  772
# F1: 0.4473916887709991
# [[800 478]
#  [772 506]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.63      0.56      1278
#            1       0.51      0.40      0.45      1278
#
#    micro avg       0.51      0.51      0.51      2556
#    macro avg       0.51      0.51      0.50      2556
# weighted avg       0.51      0.51      0.50      2556
#
# Mean Average Precision: 0.5056331666603051
# Area Under ROC Curve: 0.5109546165884193
# Precision:  0.5142276422764228
# Recall:  0.39593114241001565

# %% [markdown]
# ### expdecay

# %%
exps = [np.exp(-i * 0.3) for i in range(1,21)]
node_embeddings_training = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-2],exps[:-1]):
    node_embeddings_training += e * c 
node_embeddings_testing = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-1],exps[:-1]):
    node_embeddings_testing += e * c 
print(len(emb_list))
print(len(exps))
# Out:
# 20
# 20

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  539
# TN:  766
# FP:  512
# FN:  739
# F1: 0.4628595963933018
# [[766 512]
#  [739 539]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.60      0.55      1278
#            1       0.51      0.42      0.46      1278
#
#    micro avg       0.51      0.51      0.51      2556
#    macro avg       0.51      0.51      0.51      2556
# weighted avg       0.51      0.51      0.51      2556
#
# Mean Average Precision: 0.5054173758057383
# Area Under ROC Curve: 0.5105633802816901
# Precision:  0.5128449096098954
# Recall:  0.4217527386541471
# [LibLinear]Edge Operator: Hadamard
# TP:  628
# TN:  648
# FP:  630
# FN:  650
# F1: 0.49526813880126186
# [[648 630]
#  [650 628]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.51      0.50      1278
#            1       0.50      0.49      0.50      1278
#
#    micro avg       0.50      0.50      0.50      2556
#    macro avg       0.50      0.50      0.50      2556
# weighted avg       0.50      0.50      0.50      2556
#
# Mean Average Precision: 0.4996093856905787
# Area Under ROC Curve: 0.49921752738654146
# Precision:  0.49920508744038156
# Recall:  0.49139280125195617
# [LibLinear]Edge Operator: Weighted-L1
# TP:  580
# TN:  718
# FP:  560
# FN:  698
# F1: 0.47973531844499584
# [[718 560]
#  [698 580]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.56      0.53      1278
#            1       0.51      0.45      0.48      1278
#
#    micro avg       0.51      0.51      0.51      2556
#    macro avg       0.51      0.51      0.51      2556
# weighted avg       0.51      0.51      0.51      2556
#
# Mean Average Precision: 0.5039810010158416
# Area Under ROC Curve: 0.5078247261345853
# Precision:  0.5087719298245614
# Recall:  0.4538341158059468
# [LibLinear]Edge Operator: Weighted-L2
# TP:  614
# TN:  710
# FP:  568
# FN:  664
# F1: 0.49918699186991866
# [[710 568]
#  [664 614]]
#               precision    recall  f1-score   support
#
#            0       0.52      0.56      0.54      1278
#            1       0.52      0.48      0.50      1278
#
#    micro avg       0.52      0.52      0.52      2556
#    macro avg       0.52      0.52      0.52      2556
# weighted avg       0.52      0.52      0.52      2556
#
# Mean Average Precision: 0.5093486279587659
# Area Under ROC Curve: 0.5179968701095462
# Precision:  0.5194585448392555
# Recall:  0.48043818466353677
# [LibLinear]Edge Operator: Concat
# TP:  490
# TN:  801
# FP:  477
# FN:  788
# F1: 0.4365256124721604
# [[801 477]
#  [788 490]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.63      0.56      1278
#            1       0.51      0.38      0.44      1278
#
#    micro avg       0.51      0.51      0.51      2556
#    macro avg       0.51      0.51      0.50      2556
# weighted avg       0.51      0.51      0.50      2556
#
# Mean Average Precision: 0.5025772236544627
# Area Under ROC Curve: 0.5050860719874805
# Precision:  0.5067218200620476
# Recall:  0.38341158059467917

# %% [markdown]
# ### Amazon-Food - Equal Monthly
# ### load data

# %%
# load the training and testing graph
with open('../graphs/amazon_food/amazon_food_equal_monthly_dir.pkl', 'rb') as file:
    graphs = pickle.load(file)
    
graphs = graphs[-20:]
graph_train = graphs[-2]
graph_test = graphs[-1]

# parameters
num_edge_sample = 400

# %%
num_snapshots = len(graphs)
num_snapshots
# Out:
# 20

# %%
emb_list = []
for i in range(num_snapshots):
    file = '../embeddings/amazon_food/amazon_equal_month/amazon_equal_month_' + str(i) + '.npy'
    node_embedding = np.load(file)
    emb_list.append(node_embedding)
print(len(emb_list))
# Out:
# 20

# %% [markdown]
# ### independent / no combination

# %%
node_embeddings_training = emb_list[-3]
node_embeddings_testing = emb_list[-2]

# %%
for edge_operator in ['Average','Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  298
# TN:  395
# FP:  235
# FN:  332
# F1: 0.5124677558039553
# [[395 235]
#  [332 298]]
#               precision    recall  f1-score   support
#
#            0       0.54      0.63      0.58       630
#            1       0.56      0.47      0.51       630
#
#    micro avg       0.55      0.55      0.55      1260
#    macro avg       0.55      0.55      0.55      1260
# weighted avg       0.55      0.55      0.55      1260
#
# Mean Average Precision: 0.5279549718574108
# Area Under ROC Curve: 0.55
# Precision:  0.5590994371482176
# Recall:  0.473015873015873
# [LibLinear]Edge Operator: Hadamard
# TP:  339
# TN:  322
# FP:  308
# FN:  291
# F1: 0.5309318715740016
# [[322 308]
#  [291 339]]
#               precision    recall  f1-score   support
#
#            0       0.53      0.51      0.52       630
#            1       0.52      0.54      0.53       630
#
#    micro avg       0.52      0.52      0.52      1260
#    macro avg       0.52      0.52      0.52      1260
# weighted avg       0.52      0.52      0.52      1260
#
# Mean Average Precision: 0.512890998748804
# Area Under ROC Curve: 0.5246031746031745
# Precision:  0.5239567233384853
# Recall:  0.5380952380952381
# [LibLinear]Edge Operator: Weighted-L1
# TP:  309
# TN:  375
# FP:  255
# FN:  321
# F1: 0.5175879396984925
# [[375 255]
#  [321 309]]
#               precision    recall  f1-score   support
#
#            0       0.54      0.60      0.57       630
#            1       0.55      0.49      0.52       630
#
#    micro avg       0.54      0.54      0.54      1260
#    macro avg       0.54      0.54      0.54      1260
# weighted avg       0.54      0.54      0.54      1260
#
# Mean Average Precision: 0.5234802431610942
# Area Under ROC Curve: 0.5428571428571428
# Precision:  0.5478723404255319
# Recall:  0.49047619047619045
# [LibLinear]Edge Operator: Weighted-L2
# TP:  310
# TN:  353
# FP:  277
# FN:  320
# F1: 0.5094494658997535
# [[353 277]
#  [320 310]]
#               precision    recall  f1-score   support
#
#            0       0.52      0.56      0.54       630
#            1       0.53      0.49      0.51       630
#
#    micro avg       0.53      0.53      0.53      1260
#    macro avg       0.53      0.53      0.53      1260
# weighted avg       0.53      0.53      0.53      1260
#
# Mean Average Precision: 0.5138314269489738
# Area Under ROC Curve: 0.5261904761904762
# Precision:  0.5281090289608177
# Recall:  0.49206349206349204
# [LibLinear]Edge Operator: Concat
# TP:  298
# TN:  407
# FP:  223
# FN:  332
# F1: 0.5178105994787141
# [[407 223]
#  [332 298]]
#               precision    recall  f1-score   support
#
#            0       0.55      0.65      0.59       630
#            1       0.57      0.47      0.52       630
#
#    micro avg       0.56      0.56      0.56      1260
#    macro avg       0.56      0.56      0.56      1260
# weighted avg       0.56      0.56      0.56      1260
#
# Mean Average Precision: 0.5340462480577644
# Area Under ROC Curve: 0.5595238095238095
# Precision:  0.5719769673704415
# Recall:  0.473015873015873

# %% [markdown]
# ### sum

# %%
for i in range(len(emb_list)):
    emb_list[i] = np.asfarray(emb_list[i],float)
node_embeddings_training = np.sum(np.asarray(emb_list[0:-2]),axis=0)
node_embeddings_testing = np.sum(np.asarray(emb_list[0:-1]),axis=0)

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  306
# TN:  371
# FP:  259
# FN:  324
# F1: 0.5121338912133891
# [[371 259]
#  [324 306]]
#               precision    recall  f1-score   support
#
#            0       0.53      0.59      0.56       630
#            1       0.54      0.49      0.51       630
#
#    micro avg       0.54      0.54      0.54      1260
#    macro avg       0.54      0.54      0.54      1260
# weighted avg       0.54      0.54      0.54      1260
#
# Mean Average Precision: 0.5202022756005057
# Area Under ROC Curve: 0.5373015873015874
# Precision:  0.5415929203539823
# Recall:  0.4857142857142857
# [LibLinear]Edge Operator: Hadamard
# TP:  275
# TN:  346
# FP:  284
# FN:  355
# F1: 0.46257359125315395
# [[346 284]
#  [355 275]]
#               precision    recall  f1-score   support
#
#            0       0.49      0.55      0.52       630
#            1       0.49      0.44      0.46       630
#
#    micro avg       0.49      0.49      0.49      1260
#    macro avg       0.49      0.49      0.49      1260
# weighted avg       0.49      0.49      0.49      1260
#
# Mean Average Precision: 0.4964860720674674
# Area Under ROC Curve: 0.4928571428571429
# Precision:  0.4919499105545617
# Recall:  0.4365079365079365
# [LibLinear]Edge Operator: Weighted-L1
# TP:  285
# TN:  360
# FP:  270
# FN:  345
# F1: 0.48101265822784806
# [[360 270]
#  [345 285]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.57      0.54       630
#            1       0.51      0.45      0.48       630
#
#    micro avg       0.51      0.51      0.51      1260
#    macro avg       0.51      0.51      0.51      1260
# weighted avg       0.51      0.51      0.51      1260
#
# Mean Average Precision: 0.5061132561132562
# Area Under ROC Curve: 0.5119047619047619
# Precision:  0.5135135135135135
# Recall:  0.4523809523809524
# [LibLinear]Edge Operator: Weighted-L2
# TP:  291
# TN:  379
# FP:  251
# FN:  339
# F1: 0.4965870307167236
# [[379 251]
#  [339 291]]
#               precision    recall  f1-score   support
#
#            0       0.53      0.60      0.56       630
#            1       0.54      0.46      0.50       630
#
#    micro avg       0.53      0.53      0.53      1260
#    macro avg       0.53      0.53      0.53      1260
# weighted avg       0.53      0.53      0.53      1260
#
# Mean Average Precision: 0.5170444561588473
# Area Under ROC Curve: 0.5317460317460319
# Precision:  0.5369003690036901
# Recall:  0.46190476190476193
# [LibLinear]Edge Operator: Concat
# TP:  294
# TN:  406
# FP:  224
# FN:  336
# F1: 0.5121951219512195
# [[406 224]
#  [336 294]]
#               precision    recall  f1-score   support
#
#            0       0.55      0.64      0.59       630
#            1       0.57      0.47      0.51       630
#
#    micro avg       0.56      0.56      0.56      1260
#    macro avg       0.56      0.56      0.55      1260
# weighted avg       0.56      0.56      0.55      1260
#
# Mean Average Precision: 0.5315315315315315
# Area Under ROC Curve: 0.5555555555555556
# Precision:  0.5675675675675675
# Recall:  0.4666666666666667

# %% [markdown]
# ### expdecay

# %%
exps = [np.exp(-i * 0.3) for i in range(1,21)]
node_embeddings_training = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-2],exps[:-1]):
    node_embeddings_training += e * c 
node_embeddings_testing = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-1],exps[:-1]):
    node_embeddings_testing += e * c 
print(len(emb_list))
print(len(exps))
# Out:
# 20
# 20

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  318
# TN:  411
# FP:  219
# FN:  312
# F1: 0.544987146529563
# [[411 219]
#  [312 318]]
#               precision    recall  f1-score   support
#
#            0       0.57      0.65      0.61       630
#            1       0.59      0.50      0.54       630
#
#    micro avg       0.58      0.58      0.58      1260
#    macro avg       0.58      0.58      0.58      1260
# weighted avg       0.58      0.58      0.58      1260
#
# Mean Average Precision: 0.5465283320031924
# Area Under ROC Curve: 0.5785714285714286
# Precision:  0.5921787709497207
# Recall:  0.5047619047619047
# [LibLinear]Edge Operator: Hadamard
# TP:  323
# TN:  299
# FP:  331
# FN:  307
# F1: 0.5031152647975078
# [[299 331]
#  [307 323]]
#               precision    recall  f1-score   support
#
#            0       0.49      0.47      0.48       630
#            1       0.49      0.51      0.50       630
#
#    micro avg       0.49      0.49      0.49      1260
#    macro avg       0.49      0.49      0.49      1260
# weighted avg       0.49      0.49      0.49      1260
#
# Mean Average Precision: 0.49686422989175283
# Area Under ROC Curve: 0.49365079365079356
# Precision:  0.4938837920489297
# Recall:  0.5126984126984127
# [LibLinear]Edge Operator: Weighted-L1
# TP:  281
# TN:  381
# FP:  249
# FN:  349
# F1: 0.4844827586206897
# [[381 249]
#  [349 281]]
#               precision    recall  f1-score   support
#
#            0       0.52      0.60      0.56       630
#            1       0.53      0.45      0.48       630
#
#    micro avg       0.53      0.53      0.53      1260
#    macro avg       0.53      0.53      0.52      1260
# weighted avg       0.53      0.53      0.52      1260
#
# Mean Average Precision: 0.513465109314166
# Area Under ROC Curve: 0.5253968253968254
# Precision:  0.530188679245283
# Recall:  0.44603174603174606
# [LibLinear]Edge Operator: Weighted-L2
# TP:  292
# TN:  365
# FP:  265
# FN:  338
# F1: 0.4919966301600674
# [[365 265]
#  [338 292]]
#               precision    recall  f1-score   support
#
#            0       0.52      0.58      0.55       630
#            1       0.52      0.46      0.49       630
#
#    micro avg       0.52      0.52      0.52      1260
#    macro avg       0.52      0.52      0.52      1260
# weighted avg       0.52      0.52      0.52      1260
#
# Mean Average Precision: 0.5112336496537574
# Area Under ROC Curve: 0.5214285714285714
# Precision:  0.5242369838420108
# Recall:  0.4634920634920635
# [LibLinear]Edge Operator: Concat
# TP:  315
# TN:  400
# FP:  230
# FN:  315
# F1: 0.5361702127659574
# [[400 230]
#  [315 315]]
#               precision    recall  f1-score   support
#
#            0       0.56      0.63      0.59       630
#            1       0.58      0.50      0.54       630
#
#    micro avg       0.57      0.57      0.57      1260
#    macro avg       0.57      0.57      0.57      1260
# weighted avg       0.57      0.57      0.57      1260
#
# Mean Average Precision: 0.5389908256880733
# Area Under ROC Curve: 0.5674603174603174
# Precision:  0.5779816513761468
# Recall:  0.5

# %% [markdown]
# ### Amazon-Food - Equal Weekly
# ### load data

# %%
# load the training and testing graph
with open('../graphs/amazon_food/amazon_food_equal_weekly_dir.pkl', 'rb') as file:
    graphs = pickle.load(file)
    
graphs = graphs[-20:]
graph_train = graphs[-2]
graph_test = graphs[-1]

# parameters
num_edge_sample = 400

# %%
num_snapshots = len(graphs)
num_snapshots
# Out:
# 20

# %%
emb_list = []
for i in range(num_snapshots):
    file = '../embeddings/amazon_food/amazon_equal_week/amazon_equal_week_' + str(i) + '.npy'
    node_embedding = np.load(file)
    emb_list.append(node_embedding)
print(len(emb_list))
# Out:
# 20

# %% [markdown]
# ### independent / no combination

# %%
node_embeddings_training = emb_list[-3]
node_embeddings_testing = emb_list[-2]

# %%
for edge_operator in ['Average','Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  143
# TN:  196
# FP:  124
# FN:  177
# F1: 0.48722316865417375
# [[196 124]
#  [177 143]]
#               precision    recall  f1-score   support
#
#            0       0.53      0.61      0.57       320
#            1       0.54      0.45      0.49       320
#
#    micro avg       0.53      0.53      0.53       640
#    macro avg       0.53      0.53      0.53       640
# weighted avg       0.53      0.53      0.53       640
#
# Mean Average Precision: 0.5159000468164794
# Area Under ROC Curve: 0.5296875
# Precision:  0.5355805243445693
# Recall:  0.446875
# [LibLinear]Edge Operator: Hadamard
# TP:  129
# TN:  193
# FP:  127
# FN:  191
# F1: 0.44791666666666674
# [[193 127]
#  [191 129]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.60      0.55       320
#            1       0.50      0.40      0.45       320
#
#    micro avg       0.50      0.50      0.50       640
#    macro avg       0.50      0.50      0.50       640
# weighted avg       0.50      0.50      0.50       640
#
# Mean Average Precision: 0.5015747070312501
# Area Under ROC Curve: 0.503125
# Precision:  0.50390625
# Recall:  0.403125
# [LibLinear]Edge Operator: Weighted-L1
# TP:  132
# TN:  192
# FP:  128
# FN:  188
# F1: 0.4551724137931034
# [[192 128]
#  [188 132]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.60      0.55       320
#            1       0.51      0.41      0.46       320
#
#    micro avg       0.51      0.51      0.51       640
#    macro avg       0.51      0.51      0.50       640
# weighted avg       0.51      0.51      0.50       640
#
# Mean Average Precision: 0.5031730769230769
# Area Under ROC Curve: 0.50625
# Precision:  0.5076923076923077
# Recall:  0.4125
# [LibLinear]Edge Operator: Weighted-L2
# TP:  233
# TN:  100
# FP:  220
# FN:  87
# F1: 0.6028460543337645
# [[100 220]
#  [ 87 233]]
#               precision    recall  f1-score   support
#
#            0       0.53      0.31      0.39       320
#            1       0.51      0.73      0.60       320
#
#    micro avg       0.52      0.52      0.52       640
#    macro avg       0.52      0.52      0.50       640
# weighted avg       0.52      0.52      0.50       640
#
# Mean Average Precision: 0.5104477097130242
# Area Under ROC Curve: 0.5203125
# Precision:  0.5143487858719646
# Recall:  0.728125
# [LibLinear]Edge Operator: Concat
# TP:  123
# TN:  219
# FP:  101
# FN:  197
# F1: 0.45220588235294124
# [[219 101]
#  [197 123]]
#               precision    recall  f1-score   support
#
#            0       0.53      0.68      0.60       320
#            1       0.55      0.38      0.45       320
#
#    micro avg       0.53      0.53      0.53       640
#    macro avg       0.54      0.53      0.52       640
# weighted avg       0.54      0.53      0.52       640
#
# Mean Average Precision: 0.5188755580357143
# Area Under ROC Curve: 0.5343749999999999
# Precision:  0.5491071428571429
# Recall:  0.384375

# %% [markdown]
# ### sum

# %%
for i in range(len(emb_list)):
    emb_list[i] = np.asfarray(emb_list[i],float)
node_embeddings_training = np.sum(np.asarray(emb_list[0:-2]),axis=0)
node_embeddings_testing = np.sum(np.asarray(emb_list[0:-1]),axis=0)

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  136
# TN:  208
# FP:  112
# FN:  184
# F1: 0.47887323943661964
# [[208 112]
#  [184 136]]
#               precision    recall  f1-score   support
#
#            0       0.53      0.65      0.58       320
#            1       0.55      0.42      0.48       320
#
#    micro avg       0.54      0.54      0.54       640
#    macro avg       0.54      0.54      0.53       640
# weighted avg       0.54      0.54      0.53       640
#
# Mean Average Precision: 0.5205645161290322
# Area Under ROC Curve: 0.5375
# Precision:  0.5483870967741935
# Recall:  0.425
# [LibLinear]Edge Operator: Hadamard
# TP:  130
# TN:  189
# FP:  131
# FN:  190
# F1: 0.44750430292598964
# [[189 131]
#  [190 130]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.59      0.54       320
#            1       0.50      0.41      0.45       320
#
#    micro avg       0.50      0.50      0.50       640
#    macro avg       0.50      0.50      0.49       640
# weighted avg       0.50      0.50      0.49       640
#
# Mean Average Precision: 0.4992217432950191
# Area Under ROC Curve: 0.4984374999999999
# Precision:  0.49808429118773945
# Recall:  0.40625
# [LibLinear]Edge Operator: Weighted-L1
# TP:  136
# TN:  192
# FP:  128
# FN:  184
# F1: 0.4657534246575342
# [[192 128]
#  [184 136]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.60      0.55       320
#            1       0.52      0.42      0.47       320
#
#    micro avg       0.51      0.51      0.51       640
#    macro avg       0.51      0.51      0.51       640
# weighted avg       0.51      0.51      0.51       640
#
# Mean Average Precision: 0.5064393939393939
# Area Under ROC Curve: 0.5125
# Precision:  0.5151515151515151
# Recall:  0.425
# [LibLinear]Edge Operator: Weighted-L2
# TP:  140
# TN:  198
# FP:  122
# FN:  180
# F1: 0.4810996563573883
# [[198 122]
#  [180 140]]
#               precision    recall  f1-score   support
#
#            0       0.52      0.62      0.57       320
#            1       0.53      0.44      0.48       320
#
#    micro avg       0.53      0.53      0.53       640
#    macro avg       0.53      0.53      0.52       640
# weighted avg       0.53      0.53      0.52       640
#
# Mean Average Precision: 0.5150286259541985
# Area Under ROC Curve: 0.5281250000000001
# Precision:  0.5343511450381679
# Recall:  0.4375
# [LibLinear]Edge Operator: Concat
# TP:  121
# TN:  205
# FP:  115
# FN:  199
# F1: 0.43525179856115104
# [[205 115]
#  [199 121]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.64      0.57       320
#            1       0.51      0.38      0.44       320
#
#    micro avg       0.51      0.51      0.51       640
#    macro avg       0.51      0.51      0.50       640
# weighted avg       0.51      0.51      0.50       640
#
# Mean Average Precision: 0.5048066737288135
# Area Under ROC Curve: 0.509375
# Precision:  0.5127118644067796
# Recall:  0.378125

# %% [markdown]
# ### expdecay

# %%
exps = [np.exp(-i * 0.3) for i in range(1,21)]
node_embeddings_training = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-2],exps[:-1]):
    node_embeddings_training += e * c 
node_embeddings_testing = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-1],exps[:-1]):
    node_embeddings_testing += e * c 
print(len(exps))
print(len(emb_list))
# Out:
# 20
# 20

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  156
# TN:  180
# FP:  140
# FN:  164
# F1: 0.5064935064935064
# [[180 140]
#  [164 156]]
#               precision    recall  f1-score   support
#
#            0       0.52      0.56      0.54       320
#            1       0.53      0.49      0.51       320
#
#    micro avg       0.53      0.53      0.53       640
#    macro avg       0.53      0.53      0.52       640
# weighted avg       0.53      0.53      0.52       640
#
# Mean Average Precision: 0.5131756756756756
# Area Under ROC Curve: 0.525
# Precision:  0.527027027027027
# Recall:  0.4875
# [LibLinear]Edge Operator: Hadamard
# TP:  140
# TN:  185
# FP:  135
# FN:  180
# F1: 0.47058823529411764
# [[185 135]
#  [180 140]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.58      0.54       320
#            1       0.51      0.44      0.47       320
#
#    micro avg       0.51      0.51      0.51       640
#    macro avg       0.51      0.51      0.51       640
# weighted avg       0.51      0.51      0.51       640
#
# Mean Average Precision: 0.5039772727272727
# Area Under ROC Curve: 0.5078125
# Precision:  0.509090909090909
# Recall:  0.4375
# [LibLinear]Edge Operator: Weighted-L1
# TP:  135
# TN:  179
# FP:  141
# FN:  185
# F1: 0.453020134228188
# [[179 141]
#  [185 135]]
#               precision    recall  f1-score   support
#
#            0       0.49      0.56      0.52       320
#            1       0.49      0.42      0.45       320
#
#    micro avg       0.49      0.49      0.49       640
#    macro avg       0.49      0.49      0.49       640
# weighted avg       0.49      0.49      0.49       640
#
# Mean Average Precision: 0.4954144021739131
# Area Under ROC Curve: 0.490625
# Precision:  0.4891304347826087
# Recall:  0.421875
# [LibLinear]Edge Operator: Weighted-L2
# TP:  143
# TN:  192
# FP:  128
# FN:  177
# F1: 0.48392554991539766
# [[192 128]
#  [177 143]]
#               precision    recall  f1-score   support
#
#            0       0.52      0.60      0.56       320
#            1       0.53      0.45      0.48       320
#
#    micro avg       0.52      0.52      0.52       640
#    macro avg       0.52      0.52      0.52       640
# weighted avg       0.52      0.52      0.52       640
#
# Mean Average Precision: 0.5123673892988929
# Area Under ROC Curve: 0.5234375
# Precision:  0.5276752767527675
# Recall:  0.446875
# [LibLinear]Edge Operator: Concat
# TP:  138
# TN:  217
# FP:  103
# FN:  182
# F1: 0.4919786096256684
# [[217 103]
#  [182 138]]
#               precision    recall  f1-score   support
#
#            0       0.54      0.68      0.60       320
#            1       0.57      0.43      0.49       320
#
#    micro avg       0.55      0.55      0.55       640
#    macro avg       0.56      0.55      0.55       640
# weighted avg       0.56      0.55      0.55       640
#
# Mean Average Precision: 0.5313148340248963
# Area Under ROC Curve: 0.5546875
# Precision:  0.5726141078838174
# Recall:  0.43125
