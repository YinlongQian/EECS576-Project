# %%
import random

from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
import pickle
import sklearn.metrics as metrics

# %% [markdown]
# ### functions

# %%
def edge_features(node_emb_1, node_emb_2, operator):
    node_emb_1 = np.asfarray(node_emb_1,float)
    node_emb_2 = np.asfarray(node_emb_2, float)
    # combine two nodes' embeddings with specificed operator
    if operator == 'Average':
        edge = [((x + y) / 2.0) for x,y in zip(node_emb_1, node_emb_2)]
    elif operator == 'Hadamard':
        edge = [(x * y) for x,y in zip(node_emb_1, node_emb_2)]
    elif operator == 'Weighted-L1':
        edge = [abs(x - y) for x,y in zip(node_emb_1, node_emb_2)]
    elif operator == 'Weighted-L2':
        edge = [abs(x - y)**2 for x,y in zip(node_emb_1, node_emb_2)]
    elif operator == 'Concat':
        edge = np.concatenate((node_emb_1, node_emb_2), axis=None) 
    else:
        print("Generate edge features: Operator not supported")
        print("Use default operator: Weighted-L1")
        edge = [abs(x - y) for x,y in zip(node_emb_1, node_emb_2)]
        
    return edge
def generate_edge_features(edge_list, node_embeddings, operator):
    edge_features_mtx = []
    
    # generate features for each edge in the list
    for node_index_1, node_index_2 in edge_list:
        node_emb_1 = node_embeddings[node_index_1-1]
        node_emb_2 = node_embeddings[node_index_2-1]
        
        edge_features_mtx.append(edge_features(node_emb_1, node_emb_2, operator))
        
    return edge_features_mtx

def generate_train_set(graph_train, num_edge_sample, node_embeddings, edge_operator,):
    edge_list = list(graph_train.edges)
    num_nodes = graph_train.number_of_nodes()
    
    train_edges = []
    train_edges_labels = [1] * num_edge_sample + [0] * num_edge_sample
    
    random.seed(0)
    
    # sample edges with label 1 (true edges)
    for edge_num in range(num_edge_sample):
        rand_index = random.randint(0, len(edge_list) - 1)
        
        #train_edges.append(tuple(edge_list[rand_index]))
        train_edges.append(edge_list[rand_index])
    non_edge_num = 0
    
    # sample edges with label 0 (non-exist edges)
    while(non_edge_num < num_edge_sample):
        rand_nodes = tuple(np.random.randint(low=0,high=num_nodes, size=2))
        
        if rand_nodes not in edge_list:
            train_edges.append(rand_nodes)
            non_edge_num += 1

    train_edges_features_mtx = generate_edge_features(train_edges, node_embeddings, edge_operator)
            
    return train_edges, train_edges_features_mtx, train_edges_labels

def generate_test_set(graph_test, node_embeddings, edge_operator):
    edge_list = graph_test.edges
    nodes_with_edge = set()
    
    for edge in edge_list:
        nodes_with_edge.add(edge[0])
        nodes_with_edge.add(edge[1])
    
    num_nodes = graph_test.number_of_nodes()
    
    test_edges = []
    test_edges_labels = []
    
    num_edge_sample = len(edge_list)
    non_edge_num = 0 
    # sample edges with label 0 (non-exist edges)
    
    while(non_edge_num < num_edge_sample):
        rand_nodes = tuple(np.random.randint(low=0,high=num_nodes, size=2))
        
        if rand_nodes not in edge_list:
            test_edges.append(rand_nodes)
            test_edges_labels.append(0)
            non_edge_num += 1
        
    for edge in edge_list:
        test_edges.append(edge)
        test_edges_labels.append(1)
    
    test_edges_features_mtx = generate_edge_features(test_edges, node_embeddings, edge_operator)
    
    return test_edges, test_edges_features_mtx, test_edges_labels

def build_clf(feature_mtx, response_vec):
   
    logistic_regression_model = LogisticRegression(random_state = 0,max_iter=5000,solver='liblinear',verbose=1,tol=1e-6)
    binary_clf = logistic_regression_model.fit(feature_mtx, response_vec)
    
    return binary_clf

def pred_links(feature_mtx, LR_clf):
    predict_edges_labels = LR_clf.predict(feature_mtx)
    
    return predict_edges_labels

def precision_recall(predict_labels, true_labels):
    true_positive  = false_positive = 0
    true_negative =  false_negative = 0
    
    for p_label, true_label in zip(predict_labels, true_labels):
        
        #print(p_label,true_label)
        if p_label == true_label and true_label == 1:
            true_positive += 1
        elif p_label == true_label and true_label == 0:
            true_negative += 1
        elif p_label != true_label and true_label == 1:
            false_negative += 1
        elif p_label != true_label and true_label == 0:
            false_positive += 1

    print("TP: ", true_positive)
    print("TN: ", true_negative)
    print("FP: ", false_positive)
    print("FN: ", false_negative)
    
    precision = true_positive / (true_positive + false_positive)
    recall = true_positive / (true_positive + false_negative)
    if (precision + recall) != 0.0:
        f1 = 2 * (precision * recall) / (precision + recall)
        print("F1: {}".format(f1))
    else:
        print("F1: Divide-by-zero")
    
    cm = metrics.confusion_matrix(true_labels, predict_labels)
    print(cm)
    print(metrics.classification_report(true_labels, predict_labels))
    map = metrics.average_precision_score(true_labels, predict_labels)
    print('Mean Average Precision: {}'.format(map))
    fpr, tpr, thresholds = metrics.roc_curve(true_labels, predict_labels)
    roc_auc = metrics.auc(fpr, tpr)
    print('Area Under ROC Curve: {}'.format(roc_auc))
    
    return precision, recall

# %% [markdown]
# ### College Message - Monthly
# ### load data

# %%
# load the training and testing graph
with open('./graphs/msg_1_month_dir.pkl', 'rb') as file:
    graphs = pickle.load(file)
graph_train = graphs[-2]
graph_test = graphs[-1]

# parameters
num_edge_sample = 400
edge_operator = 'Weighted-L2'
num_snapshots = 7

# %%
emb_list = []
for i in range(num_snapshots):
    file = './LINE/msg_month/em-msg-month-' + str(i) + '.npy'
    node_embedding = np.load(file)
    emb_list.append(node_embedding)
print(len(emb_list))
# Out:
# 7

# %% [markdown]
# ### independent / no combination

# %%
node_embeddings_training = emb_list[-3]
node_embeddings_testing = emb_list[-2]

# %%
for edge_operator in ['Average','Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  68
# TN:  504
# FP:  86
# FN:  522
# F1: 0.1827956989247312
# [[504  86]
#  [522  68]]
#               precision    recall  f1-score   support
#
#            0       0.49      0.85      0.62       590
#            1       0.44      0.12      0.18       590
#
#     accuracy                           0.48      1180
#    macro avg       0.47      0.48      0.40      1180
# weighted avg       0.47      0.48      0.40      1180
#
# Mean Average Precision: 0.4932643627558882
# Area Under ROC Curve: 0.48474576271186437
# Precision:  0.44155844155844154
# Recall:  0.1152542372881356
# [LibLinear]Edge Operator: Hadamard
# TP:  400
# TN:  206
# FP:  384
# FN:  190
# F1: 0.5822416302765648
# [[206 384]
#  [190 400]]
#               precision    recall  f1-score   support
#
#            0       0.52      0.35      0.42       590
#            1       0.51      0.68      0.58       590
#
#     accuracy                           0.51      1180
#    macro avg       0.52      0.51      0.50      1180
# weighted avg       0.52      0.51      0.50      1180
#
# Mean Average Precision: 0.5069180214458665
# Area Under ROC Curve: 0.5135593220338983
# Precision:  0.5102040816326531
# Recall:  0.6779661016949152
# [LibLinear]Edge Operator: Weighted-L1
# TP:  114
# TN:  443
# FP:  147
# FN:  476
# F1: 0.2679200940070506
# [[443 147]
#  [476 114]]
#               precision    recall  f1-score   support
#
#            0       0.48      0.75      0.59       590
#            1       0.44      0.19      0.27       590
#
#     accuracy                           0.47      1180
#    macro avg       0.46      0.47      0.43      1180
# weighted avg       0.46      0.47      0.43      1180
#
# Mean Average Precision: 0.48778492109877264
# Area Under ROC Curve: 0.4720338983050848
# Precision:  0.4367816091954023
# Recall:  0.19322033898305085
# [LibLinear]Edge Operator: Weighted-L2
# TP:  104
# TN:  530
# FP:  60
# FN:  486
# F1: 0.27586206896551724
# [[530  60]
#  [486 104]]
#               precision    recall  f1-score   support
#
#            0       0.52      0.90      0.66       590
#            1       0.63      0.18      0.28       590
#
#     accuracy                           0.54      1180
#    macro avg       0.58      0.54      0.47      1180
# weighted avg       0.58      0.54      0.47      1180
#
# Mean Average Precision: 0.5236461347664324
# Area Under ROC Curve: 0.5372881355932203
# Precision:  0.6341463414634146
# Recall:  0.17627118644067796
# [LibLinear]Edge Operator: Concat
# TP:  186
# TN:  433
# FP:  157
# FN:  404
# F1: 0.3987138263665595
# [[433 157]
#  [404 186]]
#               precision    recall  f1-score   support
#
#            0       0.52      0.73      0.61       590
#            1       0.54      0.32      0.40       590
#
#     accuracy                           0.52      1180
#    macro avg       0.53      0.52      0.50      1180
# weighted avg       0.53      0.52      0.50      1180
#
# Mean Average Precision: 0.5133270741710728
# Area Under ROC Curve: 0.5245762711864407
# Precision:  0.5422740524781341
# Recall:  0.3152542372881356

# %% [markdown]
# ### sum

# %%
for i in range(len(emb_list)):
    emb_list[i] = np.asfarray(emb_list[i],float)
node_embeddings_training = np.sum(np.asarray(emb_list[0:-2]),axis=0)
node_embeddings_testing = np.sum(np.asarray(emb_list[0:-1]),axis=0)

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  360
# TN:  396
# FP:  194
# FN:  230
# F1: 0.6293706293706294
# [[396 194]
#  [230 360]]
#               precision    recall  f1-score   support
#
#            0       0.63      0.67      0.65       590
#            1       0.65      0.61      0.63       590
#
#     accuracy                           0.64      1180
#    macro avg       0.64      0.64      0.64      1180
# weighted avg       0.64      0.64      0.64      1180
#
# Mean Average Precision: 0.5914152848314262
# Area Under ROC Curve: 0.640677966101695
# Precision:  0.6498194945848376
# Recall:  0.6101694915254238
# [LibLinear]Edge Operator: Hadamard
# TP:  402
# TN:  286
# FP:  304
# FN:  188
# F1: 0.6203703703703703
# [[286 304]
#  [188 402]]
#               precision    recall  f1-score   support
#
#            0       0.60      0.48      0.54       590
#            1       0.57      0.68      0.62       590
#
#     accuracy                           0.58      1180
#    macro avg       0.59      0.58      0.58      1180
# weighted avg       0.59      0.58      0.58      1180
#
# Mean Average Precision: 0.5472895760311134
# Area Under ROC Curve: 0.5830508474576271
# Precision:  0.5694050991501416
# Recall:  0.6813559322033899
# [LibLinear]Edge Operator: Weighted-L1
# TP:  334
# TN:  417
# FP:  173
# FN:  256
# F1: 0.6089334548769371
# [[417 173]
#  [256 334]]
#               precision    recall  f1-score   support
#
#            0       0.62      0.71      0.66       590
#            1       0.66      0.57      0.61       590
#
#     accuracy                           0.64      1180
#    macro avg       0.64      0.64      0.63      1180
# weighted avg       0.64      0.64      0.63      1180
#
# Mean Average Precision: 0.5898839969244141
# Area Under ROC Curve: 0.6364406779661018
# Precision:  0.6587771203155819
# Recall:  0.5661016949152542
# [LibLinear]Edge Operator: Weighted-L2
# TP:  352
# TN:  402
# FP:  188
# FN:  238
# F1: 0.6230088495575222
# [[402 188]
#  [238 352]]
#               precision    recall  f1-score   support
#
#            0       0.63      0.68      0.65       590
#            1       0.65      0.60      0.62       590
#
#     accuracy                           0.64      1180
#    macro avg       0.64      0.64      0.64      1180
# weighted avg       0.64      0.64      0.64      1180
#
# Mean Average Precision: 0.5905963590709353
# Area Under ROC Curve: 0.6389830508474575
# Precision:  0.6518518518518519
# Recall:  0.5966101694915255
# [LibLinear]Edge Operator: Concat
# TP:  382
# TN:  391
# FP:  199
# FN:  208
# F1: 0.6524338172502134
# [[391 199]
#  [208 382]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.66      0.66       590
#            1       0.66      0.65      0.65       590
#
#     accuracy                           0.66      1180
#    macro avg       0.66      0.66      0.66      1180
# weighted avg       0.66      0.66      0.66      1180
#
# Mean Average Precision: 0.6019662183844336
# Area Under ROC Curve: 0.6550847457627118
# Precision:  0.657487091222031
# Recall:  0.6474576271186441

# %% [markdown]
# ### expdecay

# %%
exps = [np.exp(-i * 0.3) for i in range(1,8)]
node_embeddings_training = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-2],exps[:-1]):
    node_embeddings_training += e * c

# %%
node_embeddings_testing = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-1],exps[:-1]):
    node_embeddings_testing += e * c

# %%
for edge_operator in [ 'Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  338
# TN:  419
# FP:  171
# FN:  252
# F1: 0.6151046405823476
# [[419 171]
#  [252 338]]
#               precision    recall  f1-score   support
#
#            0       0.62      0.71      0.66       590
#            1       0.66      0.57      0.62       590
#
#     accuracy                           0.64      1180
#    macro avg       0.64      0.64      0.64      1180
# weighted avg       0.64      0.64      0.64      1180
#
# Mean Average Precision: 0.593979554460391
# Area Under ROC Curve: 0.6415254237288136
# Precision:  0.6640471512770137
# Recall:  0.5728813559322034
# [LibLinear]Edge Operator: Hadamard
# TP:  470
# TN:  155
# FP:  435
# FN:  120
# F1: 0.6287625418060201
# [[155 435]
#  [120 470]]
#               precision    recall  f1-score   support
#
#            0       0.56      0.26      0.36       590
#            1       0.52      0.80      0.63       590
#
#     accuracy                           0.53      1180
#    macro avg       0.54      0.53      0.49      1180
# weighted avg       0.54      0.53      0.49      1180
#
# Mean Average Precision: 0.5154040640509411
# Area Under ROC Curve: 0.5296610169491526
# Precision:  0.5193370165745856
# Recall:  0.7966101694915254
# [LibLinear]Edge Operator: Weighted-L1
# TP:  352
# TN:  425
# FP:  165
# FN:  238
# F1: 0.6359530261969286
# [[425 165]
#  [238 352]]
#               precision    recall  f1-score   support
#
#            0       0.64      0.72      0.68       590
#            1       0.68      0.60      0.64       590
#
#     accuracy                           0.66      1180
#    macro avg       0.66      0.66      0.66      1180
# weighted avg       0.66      0.66      0.66      1180
#
# Mean Average Precision: 0.607897583844212
# Area Under ROC Curve: 0.6584745762711866
# Precision:  0.6808510638297872
# Recall:  0.5966101694915255
# [LibLinear]Edge Operator: Weighted-L2
# TP:  374
# TN:  382
# FP:  208
# FN:  216
# F1: 0.6382252559726963
# [[382 208]
#  [216 374]]
#               precision    recall  f1-score   support
#
#            0       0.64      0.65      0.64       590
#            1       0.64      0.63      0.64       590
#
#     accuracy                           0.64      1180
#    macro avg       0.64      0.64      0.64      1180
# weighted avg       0.64      0.64      0.64      1180
#
# Mean Average Precision: 0.5904013046770342
# Area Under ROC Curve: 0.6406779661016949
# Precision:  0.6426116838487973
# Recall:  0.6338983050847458
# [LibLinear]Edge Operator: Concat
# TP:  354
# TN:  410
# FP:  180
# FN:  236
# F1: 0.6298932384341637
# [[410 180]
#  [236 354]]
#               precision    recall  f1-score   support
#
#            0       0.63      0.69      0.66       590
#            1       0.66      0.60      0.63       590
#
#     accuracy                           0.65      1180
#    macro avg       0.65      0.65      0.65      1180
# weighted avg       0.65      0.65      0.65      1180
#
# Mean Average Precision: 0.597752808988764
# Area Under ROC Curve: 0.6474576271186441
# Precision:  0.6629213483146067
# Recall:  0.6

# %% [markdown]
# ### College Message - Weekly
# ### load data

# %%
# load the training and testing graph
with open('./graphs/msg_1_week_dir.pkl', 'rb') as file:
    graphs = pickle.load(file)
graph_train = graphs[-2]
graph_test = graphs[-1]

# parameters
num_edge_sample = 400
num_snapshots = 28

# %%
emb_list = []
for i in range(num_snapshots):
    file = './LINE/msg_week/em-msg-week-' + str(i) + '.npy'
    node_embedding = np.load(file)
    emb_list.append(node_embedding)
print(len(emb_list))
# Out:
# 28

# %% [markdown]
# ### independent / no combination

# %%
node_embeddings_training = emb_list[-3]
node_embeddings_testing = emb_list[-2]

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  2
# TN:  78
# FP:  8
# FN:  84
# F1: 0.041666666666666664
# [[78  8]
#  [84  2]]
#               precision    recall  f1-score   support
#
#            0       0.48      0.91      0.63        86
#            1       0.20      0.02      0.04        86
#
#     accuracy                           0.47       172
#    macro avg       0.34      0.47      0.34       172
# weighted avg       0.34      0.47      0.34       172
#
# Mean Average Precision: 0.49302325581395345
# Area Under ROC Curve: 0.4651162790697675
# Precision:  0.2
# Recall:  0.023255813953488372
# [LibLinear]Edge Operator: Hadamard
# TP:  22
# TN:  73
# FP:  13
# FN:  64
# F1: 0.36363636363636365
# [[73 13]
#  [64 22]]
#               precision    recall  f1-score   support
#
#            0       0.53      0.85      0.65        86
#            1       0.63      0.26      0.36        86
#
#     accuracy                           0.55       172
#    macro avg       0.58      0.55      0.51       172
# weighted avg       0.58      0.55      0.51       172
#
# Mean Average Precision: 0.532890365448505
# Area Under ROC Curve: 0.5523255813953488
# Precision:  0.6285714285714286
# Recall:  0.2558139534883721
# [LibLinear]Edge Operator: Weighted-L1
# TP:  14
# TN:  65
# FP:  21
# FN:  72
# F1: 0.231404958677686
# [[65 21]
#  [72 14]]
#               precision    recall  f1-score   support
#
#            0       0.47      0.76      0.58        86
#            1       0.40      0.16      0.23        86
#
#     accuracy                           0.46       172
#    macro avg       0.44      0.46      0.41       172
# weighted avg       0.44      0.46      0.41       172
#
# Mean Average Precision: 0.48372093023255813
# Area Under ROC Curve: 0.4593023255813954
# Precision:  0.4
# Recall:  0.16279069767441862
# [LibLinear]Edge Operator: Weighted-L2
# TP:  16
# TN:  74
# FP:  12
# FN:  70
# F1: 0.2807017543859649
# [[74 12]
#  [70 16]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.86      0.64        86
#            1       0.57      0.19      0.28        86
#
#     accuracy                           0.52       172
#    macro avg       0.54      0.52      0.46       172
# weighted avg       0.54      0.52      0.46       172
#
# Mean Average Precision: 0.5132890365448505
# Area Under ROC Curve: 0.5232558139534883
# Precision:  0.5714285714285714
# Recall:  0.18604651162790697
# [LibLinear]Edge Operator: Concat
# TP:  1
# TN:  79
# FP:  7
# FN:  85
# F1: 0.02127659574468085
# [[79  7]
#  [85  1]]
#               precision    recall  f1-score   support
#
#            0       0.48      0.92      0.63        86
#            1       0.12      0.01      0.02        86
#
#     accuracy                           0.47       172
#    macro avg       0.30      0.47      0.33       172
# weighted avg       0.30      0.47      0.33       172
#
# Mean Average Precision: 0.4956395348837209
# Area Under ROC Curve: 0.46511627906976744
# Precision:  0.125
# Recall:  0.011627906976744186

# %% [markdown]
# ### sum

# %%
for i in range(len(emb_list)):
    emb_list[i] = np.asfarray(emb_list[i],float)
node_embeddings_training = np.sum(np.asarray(emb_list[0:-2]),axis=0)
node_embeddings_testing = np.sum(np.asarray(emb_list[0:-1]),axis=0)

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  32
# TN:  73
# FP:  13
# FN:  54
# F1: 0.4885496183206108
# [[73 13]
#  [54 32]]
#               precision    recall  f1-score   support
#
#            0       0.57      0.85      0.69        86
#            1       0.71      0.37      0.49        86
#
#     accuracy                           0.61       172
#    macro avg       0.64      0.61      0.59       172
# weighted avg       0.64      0.61      0.59       172
#
# Mean Average Precision: 0.5785529715762274
# Area Under ROC Curve: 0.6104651162790697
# Precision:  0.7111111111111111
# Recall:  0.37209302325581395
# [LibLinear]Edge Operator: Hadamard
# TP:  28
# TN:  66
# FP:  20
# FN:  58
# F1: 0.41791044776119407
# [[66 20]
#  [58 28]]
#               precision    recall  f1-score   support
#
#            0       0.53      0.77      0.63        86
#            1       0.58      0.33      0.42        86
#
#     accuracy                           0.55       172
#    macro avg       0.56      0.55      0.52       172
# weighted avg       0.56      0.55      0.52       172
#
# Mean Average Precision: 0.5271317829457365
# Area Under ROC Curve: 0.5465116279069768
# Precision:  0.5833333333333334
# Recall:  0.32558139534883723
# [LibLinear]Edge Operator: Weighted-L1
# TP:  28
# TN:  71
# FP:  15
# FN:  58
# F1: 0.434108527131783
# [[71 15]
#  [58 28]]
#               precision    recall  f1-score   support
#
#            0       0.55      0.83      0.66        86
#            1       0.65      0.33      0.43        86
#
#     accuracy                           0.58       172
#    macro avg       0.60      0.58      0.55       172
# weighted avg       0.60      0.58      0.55       172
#
# Mean Average Precision: 0.549215792320173
# Area Under ROC Curve: 0.5755813953488373
# Precision:  0.6511627906976745
# Recall:  0.32558139534883723
# [LibLinear]Edge Operator: Weighted-L2
# TP:  26
# TN:  75
# FP:  11
# FN:  60
# F1: 0.4227642276422764
# [[75 11]
#  [60 26]]
#               precision    recall  f1-score   support
#
#            0       0.56      0.87      0.68        86
#            1       0.70      0.30      0.42        86
#
#     accuracy                           0.59       172
#    macro avg       0.63      0.59      0.55       172
# weighted avg       0.63      0.59      0.55       172
#
# Mean Average Precision: 0.5612822124450032
# Area Under ROC Curve: 0.5872093023255814
# Precision:  0.7027027027027027
# Recall:  0.3023255813953488
# [LibLinear]Edge Operator: Concat
# TP:  29
# TN:  70
# FP:  16
# FN:  57
# F1: 0.4427480916030534
# [[70 16]
#  [57 29]]
#               precision    recall  f1-score   support
#
#            0       0.55      0.81      0.66        86
#            1       0.64      0.34      0.44        86
#
#     accuracy                           0.58       172
#    macro avg       0.60      0.58      0.55       172
# weighted avg       0.60      0.58      0.55       172
#
# Mean Average Precision: 0.5487080103359173
# Area Under ROC Curve: 0.5755813953488372
# Precision:  0.6444444444444445
# Recall:  0.3372093023255814

# %% [markdown]
# ### expdecay

# %%
exps = [np.exp(-i * 0.3) for i in range(1,29)]
node_embeddings_training = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-2],exps[:-1]):
    node_embeddings_training += e * c 
node_embeddings_testing = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-1],exps[:-1]):
    node_embeddings_testing += e * c

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  32
# TN:  64
# FP:  22
# FN:  54
# F1: 0.45714285714285713
# [[64 22]
#  [54 32]]
#               precision    recall  f1-score   support
#
#            0       0.54      0.74      0.63        86
#            1       0.59      0.37      0.46        86
#
#     accuracy                           0.56       172
#    macro avg       0.57      0.56      0.54       172
# weighted avg       0.57      0.56      0.54       172
#
# Mean Average Precision: 0.5344530577088716
# Area Under ROC Curve: 0.5581395348837209
# Precision:  0.5925925925925926
# Recall:  0.37209302325581395
# [LibLinear]Edge Operator: Hadamard
# TP:  74
# TN:  38
# FP:  48
# FN:  12
# F1: 0.7115384615384615
# [[38 48]
#  [12 74]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.44      0.56        86
#            1       0.61      0.86      0.71        86
#
#     accuracy                           0.65       172
#    macro avg       0.68      0.65      0.64       172
# weighted avg       0.68      0.65      0.64       172
#
# Mean Average Precision: 0.5916889058330156
# Area Under ROC Curve: 0.6511627906976745
# Precision:  0.6065573770491803
# Recall:  0.8604651162790697
# [LibLinear]Edge Operator: Weighted-L1
# TP:  32
# TN:  77
# FP:  9
# FN:  54
# F1: 0.5039370078740157
# [[77  9]
#  [54 32]]
#               precision    recall  f1-score   support
#
#            0       0.59      0.90      0.71        86
#            1       0.78      0.37      0.50        86
#
#     accuracy                           0.63       172
#    macro avg       0.68      0.63      0.61       172
# weighted avg       0.68      0.63      0.61       172
#
# Mean Average Precision: 0.60436755530346
# Area Under ROC Curve: 0.6337209302325582
# Precision:  0.7804878048780488
# Recall:  0.37209302325581395
# [LibLinear]Edge Operator: Weighted-L2
# TP:  56
# TN:  52
# FP:  34
# FN:  30
# F1: 0.6363636363636364
# [[52 34]
#  [30 56]]
#               precision    recall  f1-score   support
#
#            0       0.63      0.60      0.62        86
#            1       0.62      0.65      0.64        86
#
#     accuracy                           0.63       172
#    macro avg       0.63      0.63      0.63       172
# weighted avg       0.63      0.63      0.63       172
#
# Mean Average Precision: 0.5795865633074935
# Area Under ROC Curve: 0.627906976744186
# Precision:  0.6222222222222222
# Recall:  0.6511627906976745
# [LibLinear]Edge Operator: Concat
# TP:  30
# TN:  64
# FP:  22
# FN:  56
# F1: 0.43478260869565216
# [[64 22]
#  [56 30]]
#               precision    recall  f1-score   support
#
#            0       0.53      0.74      0.62        86
#            1       0.58      0.35      0.43        86
#
#     accuracy                           0.55       172
#    macro avg       0.56      0.55      0.53       172
# weighted avg       0.56      0.55      0.53       172
#
# Mean Average Precision: 0.5268336314847943
# Area Under ROC Curve: 0.5465116279069767
# Precision:  0.5769230769230769
# Recall:  0.3488372093023256

# %% [markdown]
# ### RM -  Equal Edges
# ### load data

# %%
# load the training and testing graph
with open('../data/RM_sparse/graphs/RM_equal_num_edges_snapshots.pkl', 'rb') as file:
    graphs = pickle.load(file)
graph_train = graphs[-2]
graph_test = graphs[-1]

# parameters
num_edge_sample = 400
edge_operator = 'Weighted-L2'
num_snapshots = 51

# %%
emb_list = []
for i in range(num_snapshots):
    file = '../data/RM_sparse/embeddings/em-equal_edge-' + str(i) + '.npy'
    node_embedding = np.load(file)
    emb_list.append(node_embedding)
print(len(emb_list))
# Out:
# 51

# %% [markdown]
# ### independent / no combination

# %%
node_embeddings_training = emb_list[-3]
node_embeddings_testing = emb_list[-2]

# %%
for edge_operator in ['Average','Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  3
# TN:  317
# FP:  5
# FN:  319
# F1: 0.01818181818181818
# [[317   5]
#  [319   3]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.98      0.66       322
#            1       0.38      0.01      0.02       322
#
#    micro avg       0.50      0.50      0.50       644
#    macro avg       0.44      0.50      0.34       644
# weighted avg       0.44      0.50      0.34       644
#
# Mean Average Precision: 0.4988354037267081
# Area Under ROC Curve: 0.49689440993788825
# Precision:  0.375
# Recall:  0.009316770186335404
# [LibLinear]Edge Operator: Hadamard
# TP:  47
# TN:  269
# FP:  53
# FN:  275
# F1: 0.22274881516587677
# [[269  53]
#  [275  47]]
#               precision    recall  f1-score   support
#
#            0       0.49      0.84      0.62       322
#            1       0.47      0.15      0.22       322
#
#    micro avg       0.49      0.49      0.49       644
#    macro avg       0.48      0.49      0.42       644
# weighted avg       0.48      0.49      0.42       644
#
# Mean Average Precision: 0.49562111801242237
# Area Under ROC Curve: 0.4906832298136645
# Precision:  0.47
# Recall:  0.14596273291925466
# [LibLinear]Edge Operator: Weighted-L1
# TP:  48
# TN:  289
# FP:  33
# FN:  274
# F1: 0.23821339950372208
# [[289  33]
#  [274  48]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.90      0.65       322
#            1       0.59      0.15      0.24       322
#
#    micro avg       0.52      0.52      0.52       644
#    macro avg       0.55      0.52      0.45       644
# weighted avg       0.55      0.52      0.45       644
#
# Mean Average Precision: 0.5138026224982747
# Area Under ROC Curve: 0.5232919254658386
# Precision:  0.5925925925925926
# Recall:  0.14906832298136646
# [LibLinear]Edge Operator: Weighted-L2
# TP:  21
# TN:  312
# FP:  10
# FN:  301
# F1: 0.11898016997167139
# [[312  10]
#  [301  21]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.97      0.67       322
#            1       0.68      0.07      0.12       322
#
#    micro avg       0.52      0.52      0.52       644
#    macro avg       0.59      0.52      0.39       644
# weighted avg       0.59      0.52      0.39       644
#
# Mean Average Precision: 0.5115708274894811
# Area Under ROC Curve: 0.517080745341615
# Precision:  0.6774193548387096
# Recall:  0.06521739130434782
# [LibLinear]Edge Operator: Concat
# TP:  0
# TN:  321
# FP:  1
# FN:  322
# F1: Divide-by-zero
# [[321   1]
#  [322   0]]
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67       322
#            1       0.00      0.00      0.00       322
#
#    micro avg       0.50      0.50      0.50       644
#    macro avg       0.25      0.50      0.33       644
# weighted avg       0.25      0.50      0.33       644
#
# Mean Average Precision: 0.5
# Area Under ROC Curve: 0.4984472049689441
# Precision:  0.0
# Recall:  0.0

# %% [markdown]
# ### sum

# %%
for i in range(len(emb_list)):
    emb_list[i] = np.asfarray(emb_list[i],float)
node_embeddings_training = np.sum(np.asarray(emb_list[0:-2]),axis=0)
node_embeddings_testing = np.sum(np.asarray(emb_list[0:-1]),axis=0)

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  306
# TN:  317
# FP:  5
# FN:  16
# F1: 0.9668246445497631
# [[317   5]
#  [ 16 306]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97       322
#            1       0.98      0.95      0.97       322
#
#    micro avg       0.97      0.97      0.97       644
#    macro avg       0.97      0.97      0.97       644
# weighted avg       0.97      0.97      0.97       644
#
# Mean Average Precision: 0.9598769746959319
# Area Under ROC Curve: 0.967391304347826
# Precision:  0.9839228295819936
# Recall:  0.9503105590062112
# [LibLinear]Edge Operator: Hadamard
# TP:  118
# TN:  256
# FP:  66
# FN:  204
# F1: 0.46640316205533605
# [[256  66]
#  [204 118]]
#               precision    recall  f1-score   support
#
#            0       0.56      0.80      0.65       322
#            1       0.64      0.37      0.47       322
#
#    micro avg       0.58      0.58      0.58       644
#    macro avg       0.60      0.58      0.56       644
# weighted avg       0.60      0.58      0.56       644
#
# Mean Average Precision: 0.5517823386443425
# Area Under ROC Curve: 0.5807453416149068
# Precision:  0.6413043478260869
# Recall:  0.36645962732919257
# [LibLinear]Edge Operator: Weighted-L1
# TP:  275
# TN:  304
# FP:  18
# FN:  47
# F1: 0.8943089430894309
# [[304  18]
#  [ 47 275]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.94      0.90       322
#            1       0.94      0.85      0.89       322
#
#    micro avg       0.90      0.90      0.90       644
#    macro avg       0.90      0.90      0.90       644
# weighted avg       0.90      0.90      0.90       644
#
# Mean Average Precision: 0.8745521802726135
# Area Under ROC Curve: 0.8990683229813665
# Precision:  0.9385665529010239
# Recall:  0.8540372670807453
# [LibLinear]Edge Operator: Weighted-L2
# TP:  268
# TN:  299
# FP:  23
# FN:  54
# F1: 0.8743882544861338
# [[299  23]
#  [ 54 268]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.93      0.89       322
#            1       0.92      0.83      0.87       322
#
#    micro avg       0.88      0.88      0.88       644
#    macro avg       0.88      0.88      0.88       644
# weighted avg       0.88      0.88      0.88       644
#
# Mean Average Precision: 0.8503660540863588
# Area Under ROC Curve: 0.8804347826086957
# Precision:  0.9209621993127147
# Recall:  0.8322981366459627
# [LibLinear]Edge Operator: Concat
# TP:  322
# TN:  317
# FP:  5
# FN:  0
# F1: 0.9922958397534669
# [[317   5]
#  [  0 322]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       322
#            1       0.98      1.00      0.99       322
#
#    micro avg       0.99      0.99      0.99       644
#    macro avg       0.99      0.99      0.99       644
# weighted avg       0.99      0.99      0.99       644
#
# Mean Average Precision: 0.9847094801223242
# Area Under ROC Curve: 0.9922360248447205
# Precision:  0.9847094801223242
# Recall:  1.0

# %% [markdown]
# ### expdecay

# %%
exps = [np.exp(-i * 0.3) for i in range(1,51)]
node_embeddings_training = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-2],exps[:-1]):
    node_embeddings_training += e * c 
node_embeddings_testing = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-1],exps[:-1]):
    node_embeddings_testing += e * c

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  218
# TN:  318
# FP:  4
# FN:  104
# F1: 0.801470588235294
# [[318   4]
#  [104 218]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.99      0.85       322
#            1       0.98      0.68      0.80       322
#
#    micro avg       0.83      0.83      0.83       644
#    macro avg       0.87      0.83      0.83       644
# weighted avg       0.87      0.83      0.83       644
#
# Mean Average Precision: 0.826310782832522
# Area Under ROC Curve: 0.8322981366459626
# Precision:  0.9819819819819819
# Recall:  0.6770186335403726
# [LibLinear]Edge Operator: Hadamard
# TP:  75
# TN:  314
# FP:  8
# FN:  247
# F1: 0.3703703703703704
# [[314   8]
#  [247  75]]
#               precision    recall  f1-score   support
#
#            0       0.56      0.98      0.71       322
#            1       0.90      0.23      0.37       322
#
#    micro avg       0.60      0.60      0.60       644
#    macro avg       0.73      0.60      0.54       644
# weighted avg       0.73      0.60      0.54       644
#
# Mean Average Precision: 0.5940095786874204
# Area Under ROC Curve: 0.6040372670807453
# Precision:  0.9036144578313253
# Recall:  0.2329192546583851
# [LibLinear]Edge Operator: Weighted-L1
# TP:  194
# TN:  318
# FP:  4
# FN:  128
# F1: 0.7461538461538462
# [[318   4]
#  [128 194]]
#               precision    recall  f1-score   support
#
#            0       0.71      0.99      0.83       322
#            1       0.98      0.60      0.75       322
#
#    micro avg       0.80      0.80      0.80       644
#    macro avg       0.85      0.80      0.79       644
# weighted avg       0.85      0.80      0.79       644
#
# Mean Average Precision: 0.7890708325490934
# Area Under ROC Curve: 0.7950310559006211
# Precision:  0.9797979797979798
# Recall:  0.6024844720496895
# [LibLinear]Edge Operator: Weighted-L2
# TP:  162
# TN:  319
# FP:  3
# FN:  160
# F1: 0.6652977412731006
# [[319   3]
#  [160 162]]
#               precision    recall  f1-score   support
#
#            0       0.67      0.99      0.80       322
#            1       0.98      0.50      0.67       322
#
#    micro avg       0.75      0.75      0.75       644
#    macro avg       0.82      0.75      0.73       644
# weighted avg       0.82      0.75      0.73       644
#
# Mean Average Precision: 0.7424054206662902
# Area Under ROC Curve: 0.7468944099378881
# Precision:  0.9818181818181818
# Recall:  0.5031055900621118
# [LibLinear]Edge Operator: Concat
# TP:  298
# TN:  321
# FP:  1
# FN:  24
# F1: 0.9597423510466988
# [[321   1]
#  [ 24 298]]
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96       322
#            1       1.00      0.93      0.96       322
#
#    micro avg       0.96      0.96      0.96       644
#    macro avg       0.96      0.96      0.96       644
# weighted avg       0.96      0.96      0.96       644
#
# Mean Average Precision: 0.9596377157813831
# Area Under ROC Curve: 0.9611801242236024
# Precision:  0.9966555183946488
# Recall:  0.9254658385093167

# %% [markdown]
# ### College Message - Equal Edges
# ### load data

# %%
# load the training and testing graph
with open('../data/CollegeMsg/graphs/msg_equal_edge_undir.pkl', 'rb') as file:
    graphs = pickle.load(file)
graph_train = graphs[-2]
graph_test = graphs[-1]

# parameters
num_edge_sample = 400
edge_operator = 'Weighted-L2'
num_snapshots = 28

# %%
emb_list = []
for i in range(num_snapshots):
    file = '../data/CollegeMsg/embeddings/em-msg-equal-edge-' + str(i) + '.npy'
    node_embedding = np.load(file)
    emb_list.append(node_embedding)
print(len(emb_list))
# Out:
# 28

# %%
node_embeddings_training = emb_list[-3]
node_embeddings_testing = emb_list[-2]

# %%
for edge_operator in ['Average','Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  195
# TN:  352
# FP:  193
# FN:  350
# F1: 0.4180064308681672
# [[352 193]
#  [350 195]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.65      0.56       545
#            1       0.50      0.36      0.42       545
#
#    micro avg       0.50      0.50      0.50      1090
#    macro avg       0.50      0.50      0.49      1090
# weighted avg       0.50      0.50      0.49      1090
#
# Mean Average Precision: 0.5009221602194268
# Area Under ROC Curve: 0.5018348623853212
# Precision:  0.5025773195876289
# Recall:  0.3577981651376147
# [LibLinear]Edge Operator: Hadamard
# TP:  448
# TN:  101
# FP:  444
# FN:  97
# F1: 0.6235212247738343
# [[101 444]
#  [ 97 448]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.19      0.27       545
#            1       0.50      0.82      0.62       545
#
#    micro avg       0.50      0.50      0.50      1090
#    macro avg       0.51      0.50      0.45      1090
# weighted avg       0.51      0.50      0.45      1090
#
# Mean Average Precision: 0.5018430904677664
# Area Under ROC Curve: 0.5036697247706422
# Precision:  0.5022421524663677
# Recall:  0.8220183486238533
# [LibLinear]Edge Operator: Weighted-L1
# TP:  200
# TN:  361
# FP:  184
# FN:  345
# F1: 0.4305705059203445
# [[361 184]
#  [345 200]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.66      0.58       545
#            1       0.52      0.37      0.43       545
#
#    micro avg       0.51      0.51      0.51      1090
#    macro avg       0.52      0.51      0.50      1090
# weighted avg       0.52      0.51      0.50      1090
#
# Mean Average Precision: 0.5076452599388379
# Area Under ROC Curve: 0.5146788990825688
# Precision:  0.5208333333333334
# Recall:  0.3669724770642202
# [LibLinear]Edge Operator: Weighted-L2
# TP:  413
# TN:  121
# FP:  424
# FN:  132
# F1: 0.597684515195369
# [[121 424]
#  [132 413]]
#               precision    recall  f1-score   support
#
#            0       0.48      0.22      0.30       545
#            1       0.49      0.76      0.60       545
#
#    micro avg       0.49      0.49      0.49      1090
#    macro avg       0.49      0.49      0.45      1090
# weighted avg       0.49      0.49      0.45      1090
#
# Mean Average Precision: 0.49502044216456764
# Area Under ROC Curve: 0.4899082568807339
# Precision:  0.4934289127837515
# Recall:  0.7577981651376147
# [LibLinear]Edge Operator: Concat
# TP:  159
# TN:  395
# FP:  150
# FN:  386
# F1: 0.37236533957845436
# [[395 150]
#  [386 159]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.72      0.60       545
#            1       0.51      0.29      0.37       545
#
#    micro avg       0.51      0.51      0.51      1090
#    macro avg       0.51      0.51      0.48      1090
# weighted avg       0.51      0.51      0.48      1090
#
# Mean Average Precision: 0.5042486862029036
# Area Under ROC Curve: 0.5082568807339449
# Precision:  0.5145631067961165
# Recall:  0.29174311926605506

# %% [markdown]
# ### sum

# %%
for i in range(len(emb_list)):
    emb_list[i] = np.asfarray(emb_list[i],float)
node_embeddings_training = np.sum(np.asarray(emb_list[0:-2]),axis=0)
node_embeddings_testing = np.sum(np.asarray(emb_list[0:-1]),axis=0)

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  340
# TN:  364
# FP:  181
# FN:  205
# F1: 0.6378986866791745
# [[364 181]
#  [205 340]]
#               precision    recall  f1-score   support
#
#            0       0.64      0.67      0.65       545
#            1       0.65      0.62      0.64       545
#
#    micro avg       0.65      0.65      0.65      1090
#    macro avg       0.65      0.65      0.65      1090
# weighted avg       0.65      0.65      0.65      1090
#
# Mean Average Precision: 0.5951944918910352
# Area Under ROC Curve: 0.6458715596330276
# Precision:  0.6525911708253359
# Recall:  0.6238532110091743
# [LibLinear]Edge Operator: Hadamard
# TP:  316
# TN:  296
# FP:  249
# FN:  229
# F1: 0.5693693693693694
# [[296 249]
#  [229 316]]
#               precision    recall  f1-score   support
#
#            0       0.56      0.54      0.55       545
#            1       0.56      0.58      0.57       545
#
#    micro avg       0.56      0.56      0.56      1090
#    macro avg       0.56      0.56      0.56      1090
# weighted avg       0.56      0.56      0.56      1090
#
# Mean Average Precision: 0.5343785012584233
# Area Under ROC Curve: 0.5614678899082569
# Precision:  0.5592920353982301
# Recall:  0.5798165137614679
# [LibLinear]Edge Operator: Weighted-L1
# TP:  332
# TN:  337
# FP:  208
# FN:  213
# F1: 0.6119815668202765
# [[337 208]
#  [213 332]]
#               precision    recall  f1-score   support
#
#            0       0.61      0.62      0.62       545
#            1       0.61      0.61      0.61       545
#
#    micro avg       0.61      0.61      0.61      1090
#    macro avg       0.61      0.61      0.61      1090
# weighted avg       0.61      0.61      0.61      1090
#
# Mean Average Precision: 0.5699422358137954
# Area Under ROC Curve: 0.6137614678899083
# Precision:  0.6148148148148148
# Recall:  0.6091743119266055
# [LibLinear]Edge Operator: Weighted-L2
# TP:  308
# TN:  360
# FP:  185
# FN:  237
# F1: 0.5934489402697495
# [[360 185]
#  [237 308]]
#               precision    recall  f1-score   support
#
#            0       0.60      0.66      0.63       545
#            1       0.62      0.57      0.59       545
#
#    micro avg       0.61      0.61      0.61      1090
#    macro avg       0.61      0.61      0.61      1090
# weighted avg       0.61      0.61      0.61      1090
#
# Mean Average Precision: 0.5704989113646091
# Area Under ROC Curve: 0.6128440366972479
# Precision:  0.6247464503042597
# Recall:  0.5651376146788991
# [LibLinear]Edge Operator: Concat
# TP:  321
# TN:  364
# FP:  181
# FN:  224
# F1: 0.6131805157593123
# [[364 181]
#  [224 321]]
#               precision    recall  f1-score   support
#
#            0       0.62      0.67      0.64       545
#            1       0.64      0.59      0.61       545
#
#    micro avg       0.63      0.63      0.63      1090
#    macro avg       0.63      0.63      0.63      1090
# weighted avg       0.63      0.63      0.63      1090
#
# Mean Average Precision: 0.5821301948170621
# Area Under ROC Curve: 0.6284403669724771
# Precision:  0.6394422310756972
# Recall:  0.5889908256880734

# %% [markdown]
# ### expdecay

# %%
exps = [np.exp(-i * 0.3) for i in range(1,28)]
node_embeddings_training = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-2],exps[:-1]):
    node_embeddings_training += e * c 
node_embeddings_testing = np.zeros((emb_list[0]).shape) 
for c,e in zip(emb_list[0:-1],exps[:-1]):
    node_embeddings_testing += e * c

# %%
for edge_operator in ['Average', 'Hadamard','Weighted-L1','Weighted-L2', 'Concat']:
    # generate the training set
    train_edges, train_edges_features_mtx, train_edges_labels = generate_train_set(graph_train, num_edge_sample, node_embeddings_training, edge_operator)
    # generate the testing set
    test_edges, test_edges_features_mtx, test_edges_labels = generate_test_set(graph_test, node_embeddings_testing, edge_operator)

    LR_clf = build_clf(train_edges_features_mtx, train_edges_labels)

    print("Edge Operator: {}".format(edge_operator))
    predict_edges_labels = pred_links(test_edges_features_mtx, LR_clf)
    precision, recall = precision_recall(list(predict_edges_labels), list(test_edges_labels))
    print('Precision: ', precision)
    print('Recall: ', recall)
# Out:
# [LibLinear]Edge Operator: Average
# TP:  288
# TN:  432
# FP:  113
# FN:  257
# F1: 0.6088794926004227
# [[432 113]
#  [257 288]]
#               precision    recall  f1-score   support
#
#            0       0.63      0.79      0.70       545
#            1       0.72      0.53      0.61       545
#
#    micro avg       0.66      0.66      0.66      1090
#    macro avg       0.67      0.66      0.65      1090
# weighted avg       0.67      0.66      0.65      1090
#
# Mean Average Precision: 0.615308060124917
# Area Under ROC Curve: 0.6605504587155964
# Precision:  0.7182044887780549
# Recall:  0.5284403669724771
# [LibLinear]Edge Operator: Hadamard
# TP:  359
# TN:  219
# FP:  326
# FN:  186
# F1: 0.583739837398374
# [[219 326]
#  [186 359]]
#               precision    recall  f1-score   support
#
#            0       0.54      0.40      0.46       545
#            1       0.52      0.66      0.58       545
#
#    micro avg       0.53      0.53      0.53      1090
#    macro avg       0.53      0.53      0.52      1090
# weighted avg       0.53      0.53      0.52      1090
#
# Mean Average Precision: 0.5158668720283934
# Area Under ROC Curve: 0.5302752293577981
# Precision:  0.5240875912408759
# Recall:  0.6587155963302752
# [LibLinear]Edge Operator: Weighted-L1
# TP:  233
# TN:  402
# FP:  143
# FN:  312
# F1: 0.5059717698154179
# [[402 143]
#  [312 233]]
#               precision    recall  f1-score   support
#
#            0       0.56      0.74      0.64       545
#            1       0.62      0.43      0.51       545
#
#    micro avg       0.58      0.58      0.58      1090
#    macro avg       0.59      0.58      0.57      1090
# weighted avg       0.59      0.58      0.57      1090
#
# Mean Average Precision: 0.5511663088034355
# Area Under ROC Curve: 0.5825688073394495
# Precision:  0.6196808510638298
# Recall:  0.42752293577981654
# [LibLinear]Edge Operator: Weighted-L2
# TP:  430
# TN:  232
# FP:  313
# FN:  115
# F1: 0.6677018633540373
# [[232 313]
#  [115 430]]
#               precision    recall  f1-score   support
#
#            0       0.67      0.43      0.52       545
#            1       0.58      0.79      0.67       545
#
#    micro avg       0.61      0.61      0.61      1090
#    macro avg       0.62      0.61      0.59      1090
# weighted avg       0.62      0.61      0.59      1090
#
# Mean Average Precision: 0.5621210811611741
# Area Under ROC Curve: 0.6073394495412845
# Precision:  0.5787348586810229
# Recall:  0.7889908256880734
# [LibLinear]Edge Operator: Concat
# TP:  296
# TN:  412
# FP:  133
# FN:  249
# F1: 0.6078028747433265
# [[412 133]
#  [249 296]]
#               precision    recall  f1-score   support
#
#            0       0.62      0.76      0.68       545
#            1       0.69      0.54      0.61       545
#
#    micro avg       0.65      0.65      0.65      1090
#    macro avg       0.66      0.65      0.65      1090
# weighted avg       0.66      0.65      0.65      1090
#
# Mean Average Precision: 0.6031800004277068
# Area Under ROC Curve: 0.6495412844036698
# Precision:  0.6899766899766899
# Recall:  0.5431192660550459
